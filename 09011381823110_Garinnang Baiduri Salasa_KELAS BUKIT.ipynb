# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set(color_codes=True)

# %%
df = pd.read_csv("VideoGamesSales.csv")
df
# Out:
#                                 Name Platform  Year_of_Release         Genre  \
# 0                         Wii Sports      Wii           2006.0        Sports
# 1                  Super Mario Bros.      NES           1985.0      Platform
# 2                     Mario Kart Wii      Wii           2008.0        Racing
# 3                  Wii Sports Resort      Wii           2009.0        Sports
# 4           Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# ...                              ...      ...              ...           ...
# 16714  Samurai Warriors: Sanada Maru      PS3           2016.0        Action
# 16715               LMA Manager 2007     X360           2006.0        Sports
# 16716        Haitaka no Psychedelica      PSV           2016.0     Adventure
# 16717               Spirits & Spells      GBA           2003.0      Platform
# 16718            Winning Post 8 2016      PSV           2016.0    Simulation
#
# ...

# %%
df.dtypes
# Out:
# Name                object
# Platform            object
# Year_of_Release    float64
# Genre               object
# Publisher           object
# NA_Sales           float64
# EU_Sales           float64
# JP_Sales           float64
# Other_Sales        float64
# Global_Sales       float64
# Critic_Score       float64
# Critic_Count       float64
# User_Score          object
# User_Count         float64
# Developer           object
# Rating              object
# dtype: object

# %%
df = df.drop(['Other_Sales'], axis=1)
df
# Out:
#                                 Name Platform  Year_of_Release         Genre  \
# 0                         Wii Sports      Wii           2006.0        Sports
# 1                  Super Mario Bros.      NES           1985.0      Platform
# 2                     Mario Kart Wii      Wii           2008.0        Racing
# 3                  Wii Sports Resort      Wii           2009.0        Sports
# 4           Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# ...                              ...      ...              ...           ...
# 16714  Samurai Warriors: Sanada Maru      PS3           2016.0        Action
# 16715               LMA Manager 2007     X360           2006.0        Sports
# 16716        Haitaka no Psychedelica      PSV           2016.0     Adventure
# 16717               Spirits & Spells      GBA           2003.0      Platform
# 16718            Winning Post 8 2016      PSV           2016.0    Simulation
#
# ...

# %%
df = df.rename(columns={"Name" : "Game", "Year_of_Release" : "Time Published", "Critic_Score" : "Pro-Score"})
df
# Out:
#                                 Game Platform  Time Published         Genre  \
# 0                         Wii Sports      Wii          2006.0        Sports
# 1                  Super Mario Bros.      NES          1985.0      Platform
# 2                     Mario Kart Wii      Wii          2008.0        Racing
# 3                  Wii Sports Resort      Wii          2009.0        Sports
# 4           Pokemon Red/Pokemon Blue       GB          1996.0  Role-Playing
# ...                              ...      ...             ...           ...
# 16714  Samurai Warriors: Sanada Maru      PS3          2016.0        Action
# 16715               LMA Manager 2007     X360          2006.0        Sports
# 16716        Haitaka no Psychedelica      PSV          2016.0     Adventure
# 16717               Spirits & Spells      GBA          2003.0      Platform
# 16718            Winning Post 8 2016      PSV          2016.0    Simulation
#
# ...

# %%
df.shape
# Out:
# (16719, 15)

# %%
duplicate_rows_df = df[df.duplicated()]
print("Total duplicated lines: ", duplicate_rows_df.shape)
# Out:
# Total duplicated lines:  (0, 15)

# %%
df.count()
# Out:
# Game              16717
# Platform          16719
# Time Published    16450
# Genre             16717
# Publisher         16665
# NA_Sales          16719
# EU_Sales          16719
# JP_Sales          16719
# Global_Sales      16719
# Pro-Score          8137
# Critic_Count       8137
# User_Score        10015
# User_Count         7590
# Developer         10096
# Rating             9950
# dtype: int64

# %%
df = df.drop_duplicates()
df
# Out:
#                                 Game Platform  Time Published         Genre  \
# 0                         Wii Sports      Wii          2006.0        Sports
# 1                  Super Mario Bros.      NES          1985.0      Platform
# 2                     Mario Kart Wii      Wii          2008.0        Racing
# 3                  Wii Sports Resort      Wii          2009.0        Sports
# 4           Pokemon Red/Pokemon Blue       GB          1996.0  Role-Playing
# ...                              ...      ...             ...           ...
# 16714  Samurai Warriors: Sanada Maru      PS3          2016.0        Action
# 16715               LMA Manager 2007     X360          2006.0        Sports
# 16716        Haitaka no Psychedelica      PSV          2016.0     Adventure
# 16717               Spirits & Spells      GBA          2003.0      Platform
# 16718            Winning Post 8 2016      PSV          2016.0    Simulation
#
# ...

# %%
df.count()
# Out:
# Game              16717
# Platform          16719
# Time Published    16450
# Genre             16717
# Publisher         16665
# NA_Sales          16719
# EU_Sales          16719
# JP_Sales          16719
# Global_Sales      16719
# Pro-Score          8137
# Critic_Count       8137
# User_Score        10015
# User_Count         7590
# Developer         10096
# Rating             9950
# dtype: int64

# %%
print(df.isnull().sum())
# Out:
# Game                 2
# Platform             0
# Time Published     269
# Genre                2
# Publisher           54
# NA_Sales             0
# EU_Sales             0
# JP_Sales             0
# Global_Sales         0
# Pro-Score         8582
# Critic_Count      8582
# User_Score        6704
# User_Count        9129
# Developer         6623
# Rating            6769
# dtype: int64

# %%
df.dropna()
df.count()
# Out:
# Game              16717
# Platform          16719
# Time Published    16450
# Genre             16717
# Publisher         16665
# NA_Sales          16719
# EU_Sales          16719
# JP_Sales          16719
# Global_Sales      16719
# Pro-Score          8137
# Critic_Count       8137
# User_Score        10015
# User_Count         7590
# Developer         10096
# Rating             9950
# dtype: int64

# %%
print(df.isnull().sum())
# Out:
# Game                 2
# Platform             0
# Time Published     269
# Genre                2
# Publisher           54
# NA_Sales             0
# EU_Sales             0
# JP_Sales             0
# Global_Sales         0
# Pro-Score         8582
# Critic_Count      8582
# User_Score        6704
# User_Count        9129
# Developer         6623
# Rating            6769
# dtype: int64

# %%
sns.boxplot(x=df['JP_Sales'])

# %%
sns.boxplot(x=df['EU_Sales'])

# %%
sns.boxplot(x=df['NA_Sales'])

# %%
Q1= df.quantile(0.25)
Q2= df.quantile(0.50)
Q3= df.quantile(0.75)
IQR = Q3-Q2-Q1
print(IQR)
# Out:
# Time Published   -2000.00
# NA_Sales             0.16
# EU_Sales             0.09
# JP_Sales             0.04
# Global_Sales         0.24
# Pro-Score          -52.00
# Critic_Count         3.00
# User_Count          47.00
# dtype: float64

# %%
df = df[~((df < (Q1 - 1.5 * IQR)) |(df > (Q3 + 1.5 * IQR))).any(axis=1)]
df.shape
# Out:
# (92, 15)

# %%
fig, ax = plt.subplots(figsize=(10,6))
ax.scatter(df['JP_Sales'], df['EU_Sales'])
ax.set_xlabel('JP_Sales')
ax.set_ylabel('EU_Sales')
plt.show()
