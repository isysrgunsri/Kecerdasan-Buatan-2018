# %% [markdown]
# # Indikasi Bunga Menggunakan Support Vector Machine

# %% [markdown]
# Support Vector Machine adalah metode machine learning yang bekerja atas prinsip Structural Risk
# Minimization (SRM) dengan tujuan menemukan hyperplane terbaik yang memisahkan dua buah class pada input
# space.

# %%
 #MENGIMPOR PERPUSTAKAAN YANG DIBUTUHKAN
import numpy as np
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt 
# %matplotlib inline

# %% [markdown]
# Matplotlib adalah pustaka visualisasi data lain yang digunakan ketika kontrol  yang lebih besar atas grafik diperlukan.
#
# NumPydan Pandasmerupakan bagian integral dari Visualisasi Data.
#
# Seaborn adalah pustaka visualisasi data Python tingkat tinggi yang digunakan    untuk membuat plot statistik yang menarik dan informatif.

# %%
iris= sns.load_dataset('iris')

# %% [markdown]
# Import Iris data set

# %% [markdown]
# "melihat daftar isi dataset"

# %%
iris.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %% [raw]
# # fungsi sns.pairplot  hue adalah variabel untuk menambahkan pemetaan semantik dan mengubah plot marginal default menjadi estimasi kepadatan kernel berlapis(KDE)yang mana memvisualiasasikan distri pengamatan dalam kumpulan data yang di analogikan dengan histogram.
#
# sedangkan pallete digunakan untuk menambahkan jenis palet apa yang ingin digunakan untuk membuat palet sekuensial gelap.
#
# Pair Plot digunakan untuk melihat hubungan berpasangan antara semua variabel dalam dataset dan sumbu diagonal menunjukkan distribusi variabel univariat.
#
#
# Buat plot hubungan berpasangan dalam kumpulan data.

# %%
sns.pairplot(iris,hue='species', palette= 'Dark2')
# From this we can say that the setosa class is easily sepreable

# %% [markdown]
# jika kita meneruskan dataset dua dimensi penuh ke kdeplot, kita akan mendapatkan visualisasi data dua dimensi

# %%
setosa=iris[iris['species']=='setosa']
sns.kdeplot(setosa['sepal_width'], setosa['sepal_length'], cmap='plasma',shade=True,shade_lowest=False)

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# import train_test_split merupakan sublibrary dari model selection

# %%
X=iris.drop('species',axis=1)
y=iris['species']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %% [markdown]
# pada proses diatas merupakan proses pendefinisian x_train sebagai data X yang ingin kita latih
# X_test sebagai data X yang ingin kita tes, y_train adalah variabel dependen yang dilatih, dan y_test merupakan variabel dependen yang diuji. Kita mendefinisikan keempat variabel ini secara bersamaan. Pada perintah train_test_split diisi dengan parameter arrays X,y yang menunjukkan arrays yang dipakai adalah X sebagai variabel independen dan y sebagai variabel dependen

# %%
from sklearn.svm import SVC

# %%
model=SVC()

# %% [markdown]
# Model yang ingin dugunakan

# %%
model.fit(X_train, y_train)
# Out:
# SVC()

# %% [markdown]
# Menyesuaikan model SVM sesuai dengan data sset yang diguankan.

# %%
pred=model.predict(X_test)

# %% [markdown]
# mengharapkan parameter pertama menjadi X Test.

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %% [markdown]
# mengimport matriks untuk classification_report, confusion_matrix

# %%
print(classification_report(y_test,pred))
print(confusion_matrix(y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        13
#   versicolor       1.00      0.94      0.97        17
#    virginica       0.94      1.00      0.97        15
#
#     accuracy                           0.98        45
#    macro avg       0.98      0.98      0.98        45
# weighted avg       0.98      0.98      0.98        45
#
# [[13  0  0]
#  [ 0 16  1]
#  [ 0  0 15]]

# %% [markdown]
# Untuk memprediksi data testing dengan hasil model training untuk mengetahui acuray kita bisa menggunakan Classification_report.
# disana bisa kita lihat accuray nya mencaapai 98%.
#
# Untuk melihat detail hasil pelatihan kita menggunakan confusion_matrix
