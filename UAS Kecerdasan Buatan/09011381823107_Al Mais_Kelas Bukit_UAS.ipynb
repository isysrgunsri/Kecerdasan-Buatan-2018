# %% [markdown]
# # Support Vector Machine — (SVM)

# %% [markdown]
# Support Vector Machine (SVM) adalah model Machine Learning yang sangat andal dan serbaguna, yang mampu melakukan klasifikasi linear atau nonliner, regresi, dan bahkan deteksi outlier. Di notebook ini, kita akan menemukan algoritma support vector machine serta implementasinya pada scikit-learn. Kami juga akan menemukan Principal Component Analysis dan implementasinya dengan scikit-learn.

# %% [markdown]
# ## 1.1 Apa itu Support Vector Machine?

# %% [markdown]
# Tujuan dari algoritma support vector machine adalah untuk menemukan hyperplane dalam ruang dimensi-N (N - jumlah fitur) yang secara jelas mengklasifikasikan titik-titik data.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Untuk memisahkan kedua kelas titik data tersebut, ada banyak kemungkinan hyperplanes yang bisa dipilih. Tujuan kita adalah menemukan bidang yang memiliki margin maksimum, yaitu jarak maksimum antara titik data kedua kelas. Memaksimalkan jarak margin memberikan beberapa penguatan sehingga poin data di masa mendatang dapat diklasifikasikan dengan lebih yakin.

# %% [markdown]
# ## 1.2 Hyperplanes and Support Vectors

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Hyperplanes adalah batas keputusan yang membantu mengklasifikasikan titik data. Titik data yang berada di kedua sisi hyperplane dapat dikaitkan dengan kelas yang berbeda. Selain itu, dimensi hyperplane tergantung pada jumlah fitur. Jika jumlah fitur inputnya 2, maka hyperplane hanyalah sebuah garis. Jika jumlah fitur masukan adalah 3, maka hyperplane menjadi bidang dua dimensi. Sulit dibayangkan bila jumlah fitur melebihi 3.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Support vector machine adalah titik-titik data yang lebih dekat ke hyperplane dan mempengaruhi posisi dan orientasi hyperplane. Dengan menggunakan support machine ini, kami memaksimalkan margin pengklasifikasi. Menghapus support machine akan mengubah posisi hyperplane. Ini adalah poin yang membantu kami membangun SVM kami.

# %% [markdown]
# ## 1.3 Intuisi Margin Besar

# %% [markdown]
# Dalam regresi logistik, kami mengambil output dari fungsi linier dan menekan nilai dalam kisaran [0,1] menggunakan fungsi sigmoid. Jika nilai squashed lebih besar dari nilai ambang (0,5) kami memberinya label 1, jika tidak kami memberikan label 0. Dalam SVM, kami mengambil output dari fungsi linier dan jika output lebih besar dari 1, kami mengidentifikasi itu dengan satu kelas dan jika outputnya -1, kami mengidentifikasi dengan kelas lain. Karena nilai ambang batas diubah menjadi 1 dan -1 dalam SVM, kami memperoleh rentang nilai penguatan ini ([- 1,1]) yang bertindak sebagai margin.

# %% [markdown]
# # 2. Implementasi SVM pada phyton

# %% [markdown]
# Saya akan menggunakan SVM dalam memprediksi diagnosis kanker jinak atau ganas berdasarkan beberapa pengamatan / fitur.
#
# - 30 fitur digunakan, contoh:

# %% [raw]
#   - radius (rata-rata jarak dari pusat ke titik-titik di sekeliling)
#   - tekstur (deviasi standar nilai skala abu-abu)
#   - perimeter
#   - area
#   - smoothness / kehalusan (variasi lokal dalam panjang radius)
#   - compactness (perimeter ^ 2 / area - 1.0)
#   - concavity / cekung (tingkat keparahan bagian cekung dari kontur)
#   - concave point / titik cekung (jumlah bagian cekung dari kontur)
#   - symmetry / simetri
#   - fractal dimention / dimensi fraktal ("perkiraan garis pantai" - 1)

# %% [markdown]
# - Set data dapat dipisahkan secara linier menggunakan semua 30 fitur masukan
# - Jumlah Mesin: 569
# - Distribusi Kelas: 212 Ganas, 357 Jinak
# - Kelas sasaran : Ganas dan Jinak

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
sns.set_style('whitegrid')

# %%
from sklearn.datasets import load_breast_cancer

cancer = load_breast_cancer()

col_names = list(cancer.feature_names)
col_names.append('target')
df = pd.DataFrame(np.c_[cancer.data, cancer.target], columns=col_names)
df.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# ...

# %%
print(cancer.target_names)
# Out:
# ['malignant' 'benign']

# %%
df.describe()
# Out:
#        mean radius  mean texture  mean perimeter    mean area  \
# count   569.000000    569.000000      569.000000   569.000000
# mean     14.127292     19.289649       91.969033   654.889104
# std       3.524049      4.301036       24.298981   351.914129
# min       6.981000      9.710000       43.790000   143.500000
# 25%      11.700000     16.170000       75.170000   420.300000
# 50%      13.370000     18.840000       86.240000   551.100000
# 75%      15.780000     21.800000      104.100000   782.700000
# max      28.110000     39.280000      188.500000  2501.000000
#
#        mean smoothness  mean compactness  mean concavity  mean concave points  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# std           0.014064          0.052813        0.079720             0.038803
# min           0.052630          0.019380        0.000000             0.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 31 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   mean radius              569 non-null    float64
#  1   mean texture             569 non-null    float64
#  2   mean perimeter           569 non-null    float64
#  3   mean area                569 non-null    float64
#  4   mean smoothness          569 non-null    float64
#  5   mean compactness         569 non-null    float64
#  6   mean concavity           569 non-null    float64
#  7   mean concave points      569 non-null    float64
#  8   mean symmetry            569 non-null    float64
#  9   mean fractal dimension   569 non-null    float64
#  10  radius error             569 non-null    float64
#  11  texture error            569 non-null    float64
#  12  perimeter error          569 non-null    float64
# ...

# %% [markdown]
# ## 2.1 Visualisasi Data

# %%
df.columns
# Out:
# Index(['mean radius', 'mean texture', 'mean perimeter', 'mean area',
#        'mean smoothness', 'mean compactness', 'mean concavity',
#        'mean concave points', 'mean symmetry', 'mean fractal dimension',
#        'radius error', 'texture error', 'perimeter error', 'area error',
#        'smoothness error', 'compactness error', 'concavity error',
#        'concave points error', 'symmetry error', 'fractal dimension error',
#        'worst radius', 'worst texture', 'worst perimeter', 'worst area',
#        'worst smoothness', 'worst compactness', 'worst concavity',
#        'worst concave points', 'worst symmetry', 'worst fractal dimension',
#        'target'],
#       dtype='object')

# %%
sns.pairplot(df, hue='target', vars=['mean radius', 'mean texture', 'mean perimeter', 'mean area', 
                                     'mean smoothness', 'mean compactness', 'mean concavity',
                                     'mean concave points', 'mean symmetry', 'mean fractal dimension'])

# %%
sns.countplot(df['target'], label = "Count")

# %%
plt.figure(figsize=(10, 8))
sns.scatterplot(x = 'mean area', y = 'mean smoothness', hue = 'target', data = df)

# %%
# Let's check the correlation between the variables 
# Strong correlation between the mean radius and mean perimeter, mean area and mean primeter
plt.figure(figsize=(20,10)) 
sns.heatmap(df.corr(), annot=True)

# %% [markdown]
# ## 2.2 Model Training (Menemukan solusi dari masalah)

# %%
from sklearn.model_selection import cross_val_score, train_test_split
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, MinMaxScaler

X = df.drop('target', axis=1)
y = df.target

print(f"'X' shape: {X.shape}")
print(f"'y' shape: {y.shape}")

pipeline = Pipeline([
    ('min_max_scaler', MinMaxScaler()),
    ('std_scaler', StandardScaler())
])

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
# Out:
# 'X' shape: (569, 30)
# 'y' shape: (569,)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

def print_score(clf, X_train, y_train, X_test, y_test, train=True):
    if train:
        pred = clf.predict(X_train)
        clf_report = pd.DataFrame(classification_report(y_train, pred, output_dict=True))
        print("Train Result:\n================================================")
        print(f"Accuracy Score: {accuracy_score(y_train, pred) * 100:.2f}%")
        print("_______________________________________________")
        print(f"CLASSIFICATION REPORT:\n{clf_report}")
        print("_______________________________________________")
        print(f"Confusion Matrix: \n {confusion_matrix(y_train, pred)}\n")
        
    elif train==False:
        pred = clf.predict(X_test)
        clf_report = pd.DataFrame(classification_report(y_test, pred, output_dict=True))
        print("Test Result:\n================================================")        
        print(f"Accuracy Score: {accuracy_score(y_test, pred) * 100:.2f}%")
        print("_______________________________________________")
        print(f"CLASSIFICATION REPORT:\n{clf_report}")
        print("_______________________________________________")
        print(f"Confusion Matrix: \n {confusion_matrix(y_test, pred)}\n")

# %% [markdown]
# ## 2.3 Support Vector Machines (Kernels)

# %% [markdown]
# - Parameter C: Mengontrol trade-off antara mengklasifikasikan poin training dengan benar dan memiliki batasan keputusan yang mulus.
#     - C kecil (longgar) membuat biaya (penalti) kesalahan klasifikasi rendah (margin lunak)
#     - C besar (ketat) membuat biaya kesalahan klasifikasi menjadi tinggi (margin keras), memaksa model untuk menjelaskan data input lebih ketat dan berpotensi melebihi itu.
# - Parameter gamma: Mengontrol sejauh mana pengaruh satu set training tercapai.
#     - Gamma besar: jangkauan dekat (titik data yang lebih dekat memiliki bobot yang tinggi)
#     - Gamma kecil: jangkauan jauh (solusi yang lebih umum)
# - parameter derajat: Derajat fungsi kernel polinomial ('poli'). Diabaikan oleh semua kernel lainnya.
#
# Pendekatan umum untuk menemukan nilai hyperparameter yang tepat adalah dengan menggunakan pencarian grid. Seringkali lebih cepat untuk terlebih dahulu melakukan pencarian grid yang sangat kasar, kemudian pencarian grid yang lebih halus di sekitar nilai terbaik yang ditemukan. Memiliki pemahaman yang baik tentang apa yang sebenarnya dilakukan setiap hyperparameter juga dapat membantu Anda mencari di bagian kanan ruang hyperparameter.

# %% [markdown]
# ### 2.3.1 Linear Kernel SVM

# %%
from sklearn.svm import LinearSVC

model = LinearSVC(loss='hinge', dual=True)
model.fit(X_train, y_train)

print_score(model, X_train, y_train, X_test, y_test, train=True)
print_score(model, X_train, y_train, X_test, y_test, train=False)
# Out:
# C:\Users\asus\anaconda3\lib\site-packages\sklearn\svm\_base.py:976: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# Train Result:
# ...
# Accuracy Score: 84.67%
# _______________________________________________
# CLASSIFICATION REPORT:
#                   0.0         1.0  accuracy   macro avg  weighted avg
# precision    0.713592    0.989583  0.846734    0.851588      0.886260
# recall       0.986577    0.763052  0.846734    0.874815      0.846734
# f1-score     0.828169    0.861678  0.846734    0.844924      0.849133
# support    149.000000  249.000000  0.846734  398.000000    398.000000
# _______________________________________________
# Confusion Matrix:
#  [[147   2]
#  [ 59 190]]
#
# Test Result:
# ...
# Accuracy Score: 87.13%
# _______________________________________________
# CLASSIFICATION REPORT:
#                  0.0         1.0  accuracy   macro avg  weighted avg
# ...

# %% [markdown]
# ### 2. 3. 2. Polynomial Kernel SVM

# %% [markdown]
# Kode ini melatih pengklasifikasi SVM menggunakan kernel ploynomial derajat ke-2.

# %%
from sklearn.svm import SVC

# The hyperparameter coef0 controls how much the model is influenced by high degree ploynomials 
model = SVC(kernel='poly', degree=2, gamma='auto', coef0=1, C=5)
model.fit(X_train, y_train)

print_score(model, X_train, y_train, X_test, y_test, train=True)
print_score(model, X_train, y_train, X_test, y_test, train=False)
# Out:
# Train Result:
# ...
# Accuracy Score: 96.98%
# _______________________________________________
# CLASSIFICATION REPORT:
#                   0.0         1.0  accuracy   macro avg  weighted avg
# precision    0.985816    0.961089  0.969849    0.973453      0.970346
# recall       0.932886    0.991968  0.969849    0.962427      0.969849
# f1-score     0.958621    0.976285  0.969849    0.967453      0.969672
# support    149.000000  249.000000  0.969849  398.000000    398.000000
# _______________________________________________
# Confusion Matrix:
#  [[139  10]
#  [  2 247]]
#
# Test Result:
# ...
# Accuracy Score: 97.08%
# _______________________________________________
# CLASSIFICATION REPORT:
#                  0.0         1.0  accuracy   macro avg  weighted avg
# precision   0.967742    0.972477   0.97076    0.970109      0.970733
# recall      0.952381    0.981481   0.97076    0.966931      0.970760
# f1-score    0.960000    0.976959   0.97076    0.968479      0.970711
# ...

# %% [markdown]
# ### 2. 3. 3. Radial Kernel SVM

# %%
model = SVC(kernel='rbf', gamma=0.5, C=0.1)
model.fit(X_train, y_train)

print_score(model, X_train, y_train, X_test, y_test, train=True)
print_score(model, X_train, y_train, X_test, y_test, train=False)
# Out:
# Train Result:
# ...
# Accuracy Score: 62.56%
# _______________________________________________
# CLASSIFICATION REPORT:
#              0.0         1.0  accuracy   macro avg  weighted avg
# precision    0.0    0.625628  0.625628    0.312814      0.391411
# recall       0.0    1.000000  0.625628    0.500000      0.625628
# f1-score     0.0    0.769706  0.625628    0.384853      0.481550
# support    149.0  249.000000  0.625628  398.000000    398.000000
# _______________________________________________
# Confusion Matrix:
#  [[  0 149]
#  [  0 249]]
#
# Test Result:
# ...
# Accuracy Score: 63.16%
# _______________________________________________
# CLASSIFICATION REPORT:
#             0.0         1.0  accuracy   macro avg  weighted avg
# precision   0.0    0.631579  0.631579    0.315789      0.398892
# recall      0.0    1.000000  0.631579    0.500000      0.631579
# f1-score    0.0    0.774194  0.631579    0.387097      0.488964
# support    63.0  108.000000  0.631579  171.000000    171.000000
# ...

# %% [markdown]
# Kernel lain ada tetapi tidak lebih jarang digunakan. Misalnya, beberapa kernel dikhususkan untuk struktur data tertentu. Kernel string terkadang digunakan saat mengklasifikasikan dokumen teks pada urutan DNA.
#
# Dengan begitu banyak kernel untuk dipilih, bagaimana Anda bisa memutuskan mana yang akan digunakan? Sebagai aturan praktis, Anda harus selalu mencoba kernel linier terlebih dahulu, terutama jika set pelatihan sangat besar atau jika memiliki banyak fitur. Jika ukuran pelatihan tidak terlalu besar, Anda harus mencoba kernel RBF Gaussian juga.

# %% [markdown]
# ## 2. 4. Data Preparation for SVM

# %% [markdown]
# Bagian ini mencantumkan beberapa saran tentang cara terbaik mempersiapkan data training Anda saat mempelajari model SVM.
#
# - Input Numerik: SVM mengasumsikan bahwa input Anda adalah numerik. Jika Anda memiliki masukan kategorikal, Anda mungkin perlu mengubahnya menjadi variabel dummy biner (satu variabel untuk setiap kategori).
# - Klasifikasi Biner: SVM dasar seperti yang dijelaskan dalam posting ini ditujukan untuk masalah klasifikasi biner (dua kelas). Meskipun, ekstensi telah dikembangkan untuk regresi dan klasifikasi kelas jamak.

# %%
X_train = pipeline.fit_transform(X_train)
X_test = pipeline.transform(X_test)

# %%
print("=======================Linear Kernel SVM==========================")
model = SVC(kernel='linear')
model.fit(X_train, y_train)

print_score(model, X_train, y_train, X_test, y_test, train=True)
print_score(model, X_train, y_train, X_test, y_test, train=False)

print("=======================Polynomial Kernel SVM==========================")
from sklearn.svm import SVC

model = SVC(kernel='poly', degree=2, gamma='auto')
model.fit(X_train, y_train)

print_score(model, X_train, y_train, X_test, y_test, train=True)
print_score(model, X_train, y_train, X_test, y_test, train=False)

print("=======================Radial Kernel SVM==========================")
from sklearn.svm import SVC

model = SVC(kernel='rbf', gamma=1)
model.fit(X_train, y_train)

print_score(model, X_train, y_train, X_test, y_test, train=True)
print_score(model, X_train, y_train, X_test, y_test, train=False)
# Out:
# =======================Linear Kernel SVM==========================
# Train Result:
# ...
# Accuracy Score: 98.99%
# _______________________________________________
# CLASSIFICATION REPORT:
#                   0.0         1.0  accuracy   macro avg  weighted avg
# precision    1.000000    0.984190   0.98995    0.992095      0.990109
# recall       0.973154    1.000000   0.98995    0.986577      0.989950
# f1-score     0.986395    0.992032   0.98995    0.989213      0.989921
# support    149.000000  249.000000   0.98995  398.000000    398.000000
# _______________________________________________
# Confusion Matrix:
#  [[145   4]
#  [  0 249]]
#
# Test Result:
# ...
# Accuracy Score: 97.66%
# _______________________________________________
# CLASSIFICATION REPORT:
#                  0.0         1.0  accuracy   macro avg  weighted avg
# precision   0.968254    0.981481  0.976608    0.974868      0.976608
# recall      0.968254    0.981481  0.976608    0.974868      0.976608
# ...

# %% [markdown]
# # 3. Support Vector Machine Hyperparameter tuning

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {'C': [0.01, 0.1, 0.5, 1, 10, 100], 
              'gamma': [1, 0.75, 0.5, 0.25, 0.1, 0.01, 0.001], 
              'kernel': ['rbf', 'poly', 'linear']} 

grid = GridSearchCV(SVC(), param_grid, refit=True, verbose=1, cv=5, iid=True)
grid.fit(X_train, y_train)

best_params = grid.best_params_
print(f"Best params: {best_params}")

svm_clf = SVC(**best_params)
svm_clf.fit(X_train, y_train)
print_score(svm_clf, X_train, y_train, X_test, y_test, train=True)
print_score(svm_clf, X_train, y_train, X_test, y_test, train=False)
# Out:
# Fitting 5 folds for each of 126 candidates, totalling 630 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 630 out of 630 | elapsed:    6.6s finished
# C:\Users\asus\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:847: FutureWarning: The parameter 'iid' is deprecated in 0.22 and will be removed in 0.24.
#   warnings.warn(
# Best params: {'C': 0.1, 'gamma': 1, 'kernel': 'linear'}
# Train Result:
# ...
# Accuracy Score: 98.24%
# _______________________________________________
# CLASSIFICATION REPORT:
#                   0.0         1.0  accuracy   macro avg  weighted avg
# precision    0.986301    0.980159  0.982412    0.983230      0.982458
# recall       0.966443    0.991968  0.982412    0.979205      0.982412
# f1-score     0.976271    0.986028  0.982412    0.981150      0.982375
# support    149.000000  249.000000  0.982412  398.000000    398.000000
# _______________________________________________
# ...

# %% [markdown]
# # 4. Principal Component Analysis

# %% [markdown]
# PCA adalah:
#
# - Pengurangan dimensi linier menggunakan Dekomposisi Nilai Singular dari data untuk memproyeksikannya ke ruang dimensi yang lebih rendah.
# - Unsupervised Machine Leraning
# - Transformasi data Anda dan upaya untuk mencari tahu fitur apa yang paling menjelaskan variasi dalam data Anda. Sebagai contoh:

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# ...

# %% [markdown]
# ## 4. 1. PCA Visualization

# %% [markdown]
# Seperti yang telah kita perhatikan sebelumnya, sulit untuk memvisualisasikan data berdimensi tinggi, kita dapat menggunakan PCA untuk menemukan dua komponen utama pertama, dan memvisualisasikan data dalam ruang dua dimensi yang baru ini, dengan single scatter-plot. Sebelum kita melakukan ini, kita perlu menskalakan data kita sehingga setiap fitur memiliki satu unit varian.

# %%
scaler = StandardScaler()
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# PCA dengan Scikit Learn menggunakan proses yang sangat mirip dengan fungsi preprocessing lainnya yang disertakan dengan SciKit Learn. Kami membuat instance objek PCA, menemukan komponen utama menggunakan metode fit, kemudian menerapkan rotasi dan pengurangan dimensi dengan memanggil transform().
#
# Kami juga dapat menentukan berapa banyak komponen yang ingin kami simpan saat membuat objek PCA.

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=3)

X_train = pca.fit_transform(X_train)
X_test = pca.transform(X_test)

# %%
plt.figure(figsize=(8,6))
plt.scatter(X_train[:,0],X_train[:,1],c=y_train,cmap='plasma')
plt.xlabel('First principal component')
plt.ylabel('Second Principal Component')
# Out:
# Text(0, 0.5, 'Second Principal Component')

# %% [markdown]
# Jelas dengan menggunakan dua komponen ini kita dapat dengan mudah memisahkan kedua kelas ini.

# %% [markdown]
# ## 4. 2. Menginterpretasi Komponen

# %% [markdown]
# Sayangnya, dengan kekuatan pengurangan dimensi yang besar ini, timbul biaya untuk dapat dengan mudah memahami apa yang diwakili oleh komponen ini.
#
# Komponen sesuai dengan kombinasi fitur asli, komponen itu sendiri disimpan sebagai atribut dari objek PCA yang dipasang:

# %% [markdown]
# Catatan:
#
# Principal Component Analysis:
#
# - Digunakan dalam exploratory data analysis (EDA)
# - memvisualisasikan jarak genetik dan keterkaitan antar populasi.
# - Metode:
#
#     - Dekomposisi nilai eigen dari matriks kovarian data (atau korelasi)
#     - Dekomposisi nilai singular dari matriks data (Setelah mean centering / normalisasi) matriks data untuk setiap atribut.
# - Keluaran
#     - Skor komponen, terkadang disebut skor faktor (nilai variabel yang diubah)
#     - loading (berat)
# - Kompresi data dan penyimpanan informasi
# - Visualisasi
# - Penyaringan noise
# - Ekstraksi dan rekayasa fitur

# %%
param_grid = {'C': [0.01, 0.1, 0.5, 1, 10, 100], 
              'gamma': [1, 0.75, 0.5, 0.25, 0.1, 0.01, 0.001], 
              'kernel': ['rbf', 'poly', 'linear']} 

grid = GridSearchCV(SVC(), param_grid, refit=True, verbose=1, cv=5, iid=True)
grid.fit(X_train, y_train)
best_params = grid.best_params_
print(f"Best params: {best_params}")

svm_clf = SVC(**best_params)
svm_clf.fit(X_train, y_train)

print_score(svm_clf, X_train, y_train, X_test, y_test, train=True)
print_score(svm_clf, X_train, y_train, X_test, y_test, train=False)
# Out:
# Fitting 5 folds for each of 126 candidates, totalling 630 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# Best params: {'C': 1, 'gamma': 0.75, 'kernel': 'poly'}
# Train Result:
# ...
# Accuracy Score: 96.48%
# _______________________________________________
# CLASSIFICATION REPORT:
#                   0.0         1.0  accuracy   macro avg  weighted avg
# precision    0.978723    0.957198  0.964824    0.967961      0.965257
# recall       0.926174    0.987952  0.964824    0.957063      0.964824
# f1-score     0.951724    0.972332  0.964824    0.962028      0.964617
# support    149.000000  249.000000  0.964824  398.000000    398.000000
# _______________________________________________
# Confusion Matrix:
#  [[138  11]
#  [  3 246]]
#
# Test Result:
# ...
# Accuracy Score: 96.49%
# _______________________________________________
# CLASSIFICATION REPORT:
#                  0.0         1.0  accuracy   macro avg  weighted avg
# ...

# %% [markdown]
# # 5. Rangkuman

# %% [markdown]
# Di notebook ini Anda menemukan Algoritma Support Vector Machine untuk machine learning. Anda belajar tentang:
#
# - Apa itu support vector machine ?.
# - Mengimplementasikan Support Vector Machine dengan Python.
# - Kernel Support Vector Machine (Linear, Polinomial, Radial).
# - Bagaimana mempersiapkan data untuk algoritma support vektor machine.
# - Penyetelan hyperparameter support vector machine.
# - Principal Component Analysis dan bagaimana menggunakannya untuk mengurangi kompleksitas masalah.
# - Cara menghitung Principal Component Analysis untuk digunakan kembali pada lebih banyak data di scikit-learn.
