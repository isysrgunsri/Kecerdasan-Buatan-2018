# %% [markdown]
# # Occupancy Detection
#
# # Nama : Caezar Alfillail
#
# # NIM : 09011281823044
#
# # Kelas : SK 2018 B Indralaya

# %%
from __future__ import division
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import cross_val_score

from sklearn.preprocessing import MinMaxScaler

# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

import warnings
warnings.filterwarnings("ignore")

from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC, LinearSVC
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from mlxtend.classifier import StackingClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

from sklearn.pipeline import make_pipeline

from sklearn.metrics import accuracy_score, f1_score, recall_score, precision_score, roc_auc_score
from sklearn.metrics import roc_curve, average_precision_score, matthews_corrcoef, make_scorer

from sklearn.feature_selection import SelectKBest,chi2, f_classif, mutual_info_classif, VarianceThreshold

# %% [markdown]
# ### 1. Download the dataset(s) for your project. If a train set and a test set are not already available, randomly split the dataset into a train and a test set using stratified sampling so that 80% of the samples go to train set and 20% to test set.
#
# Data was retrieved from: https://archive.ics.uci.edu/ml/datasets/Occupancy+Detection+
#
# ### 2. Randomly split your train set into a validation and a new train set (called train set 2) such that the validation set contains 1/5 of the samples in original train set and the train set 2 contains the remaining. Use stratified sampling to assign features to train set 2 and validation set. This should ensure that your validation set contains samples from both classes (i.e. ciliary and non-ciliary with equal proportions)

# %%
train_data = pd.read_csv("datatraining.csv")

y_train = train_data['Occupancy']
X_train = train_data.loc[:, train_data.columns != 'Occupancy']

X_train_two, X_validation, y_train_two, y_validation = train_test_split(X_train, y_train, test_size=0.20, stratify=y_train, random_state=42)

test_data = pd.read_csv("datatest.csv") # My dataset has two test sets. This is test1.

y_test = test_data['Occupancy']
X_test = test_data.loc[:, test_data.columns != 'Occupancy']

test_data2 = pd.read_csv("datatest2.csv") # My dataset has two test sets. This is test1.

y_test2 = test_data2['Occupancy']
X_test2 = test_data2.loc[:, test_data2.columns != 'Occupancy']

# %% [markdown]
# ### 3. Normalize features in your train set 2 and validation set using min-max scaling to interval [0,1]. For this purpose you can first normalize features in your train set 2 and use the same scaling coefficients to normalize validation set. Save the normalized versions as separate files. Repeat normalizing your original train set and use the same normalization coefficients to normalize the two test sets.

# %%
scaler = MinMaxScaler()

scaler.fit(X_train_two)
normalized_x_train_two = scaler.transform(X_train_two)
normalized_x_validation_train_two = scaler.transform(X_validation)

np.savetxt("normalized_x_train_two.csv", normalized_x_train_two, delimiter=",")
np.savetxt("normalized_x_validation.csv", normalized_x_validation_train_two, delimiter=",")

scaler.fit(X_train)
normalized_x_train = scaler.transform(X_train)
normalized_x_test = scaler.transform(X_test)
normalized_x_test2 = scaler.transform(X_test2)
normalized_x_validation_with_orig = scaler.transform(X_validation)

# %% [markdown]
# ### 4. Perform a 10-fold cross-validation experiment for the random forest classifier on normalized and unnormalized versions of train set 2. You can set the number of trees to 100. Do you get better accuracy when you perform data normalization?

# %%
clf = RandomForestClassifier(n_estimators=100, random_state=42)
kfold = StratifiedKFold(n_splits=10, random_state=42)

unnormalized_accuracy = cross_val_score(clf, X_train_two, y_train_two, cv=kfold).mean()
normalized_accuracy = cross_val_score(clf, normalized_x_train_two, y_train_two, cv=kfold).mean()

if unnormalized_accuracy >= normalized_accuracy:
    print("No, I did not. Unnormalized Accuracy: {}, Normalized Accuracy: {}"
          .format(unnormalized_accuracy,normalized_accuracy))
else:
    print("Yes, I did. Unnormalized Accuracy: {}, Normalized Accuracy: {}"
          .format(unnormalized_accuracy,normalized_accuracy))
# Out:
# Yes, I did. Unnormalized Accuracy: 0.99416494608, Normalized Accuracy: 0.994471930145

# %% [markdown]
# ### 5. Perform a 10-fold cross-validation experiment on train set 2 that corresponds to the best performing normalization strategy (i.e. normalized or unnormalized) for the following classifiers:
#
# Logistic regression
#
# k-nearest neighbor (with k=1)
#
# Naïve Bayes
#
# Decision tree
#
# Random forest (number of trees=100)
#
# SVM (RBF kernel C=1.0 gamma=0.125)
#
# Linear Discriminant Analysis (This model is used instead of RBF Network)
#
# Adaboost (number of iterations=10)
#
# You can use default values for other hyper-parameters of the classifiers
# Report the following accuracy measures for each of these classifiers: overall
# accuracy, F-measure, sensitivity, specificity, precision, area under the ROC curve,
# area under the precision recall curve, MCC scores. These will be cross-validation
# accuracies.

# %%
models = [
    ("Logistic Regression",LogisticRegression(random_state=42)),
    ("K-Nearest Neighbour",KNeighborsClassifier(n_neighbors=1)),
    ("Naive Bayes",GaussianNB()),
    ("Decision Tree",DecisionTreeClassifier(random_state=42)),
    ("Random Forest",RandomForestClassifier(n_estimators=100, random_state=42)),
    ("Support Vector Machine",SVC(kernel="rbf", C=1,gamma=0.125, random_state=42)),
    ("Linear Discriminant Analysis", LinearDiscriminantAnalysis()),
    ("AdaBoostClassifier",AdaBoostClassifier(n_estimators=10, random_state=42))
]

metrics = [
    ("Accuracy Score", accuracy_score),
    ("F-Measure", f1_score),
    ("Sensitivity", recall_score),
    ("Specificity", recall_score),
    ("Precision", precision_score),
    ("Area Under ROC Curve", roc_auc_score),
    ("Area Under Precision Recall Curve", average_precision_score),
    ("MCC", matthews_corrcoef)
]

def dump_metrics_with_cv(features, label, name, model):
    accuracy = 0.0
    
    for metric_name, metric in metrics:
        kfold = StratifiedKFold(n_splits=10, random_state=42)
        scorer = make_scorer(metric,pos_label=0) if metric_name == "Specificity" else make_scorer(metric)

        cv_result = cross_val_score(model,features,label.values.ravel(), cv = kfold,scoring = scorer)
        
        if metric_name == "Accuracy Score":
            accuracy = cv_result

        print("{} {}: {}".format(name, metric_name, cv_result.mean()))
    print("")
    
    return accuracy.mean()

for name,model in models:
    print("Unnormalized Results for {}:\n".format(name))
    dump_metrics_with_cv(X_train_two, y_train_two, name, model)
    
    print("\nNormalized Results for {}:\n".format(name))
    dump_metrics_with_cv(normalized_x_train_two, y_train_two, name, model)
# Out:
# Unnormalized Results for Logistic Regression:
#
# Logistic Regression Accuracy Score: 0.982649389021
# Logistic Regression F-Measure: 0.96063221029
# Logistic Regression Sensitivity: 0.99133041393
# Logistic Regression Specificity: 0.980313787062
# Logistic Regression Precision: 0.932265962074
# Logistic Regression Area Under ROC Curve: 0.985822100496
# Logistic Regression Area Under Precision Recall Curve: 0.925995821007
# Logistic Regression MCC: 0.950474980812
#
#
# Normalized Results for Logistic Regression:
#
# Logistic Regression Accuracy Score: 0.988945271712
# Logistic Regression F-Measure: 0.974631060518
# Logistic Regression Sensitivity: 0.997826086957
# Logistic Regression Specificity: 0.986551603826
# Logistic Regression Precision: 0.952632448389
# Logistic Regression Area Under ROC Curve: 0.992188845391
# Logistic Regression Area Under Precision Recall Curve: 0.951010106793
# Logistic Regression MCC: 0.968055905242
#
# Unnormalized Results for K-Nearest Neighbour:
#
# K-Nearest Neighbour Accuracy Score: 0.993398543946
# K-Nearest Neighbour F-Measure: 0.98445991284
# K-Nearest Neighbour Sensitivity: 0.985543738922
# K-Nearest Neighbour Specificity: 0.995517706935
# K-Nearest Neighbour Precision: 0.983501777729
# K-Nearest Neighbour Area Under ROC Curve: 0.990530722928
# K-Nearest Neighbour Area Under Precision Recall Curve: 0.972319984519
# K-Nearest Neighbour MCC: 0.980319749123
#
#
# Normalized Results for K-Nearest Neighbour:
#
# K-Nearest Neighbour Accuracy Score: 0.993706940876
# K-Nearest Neighbour F-Measure: 0.985086637998
# K-Nearest Neighbour Sensitivity: 0.981221978939
# K-Nearest Neighbour Specificity: 0.997077161126
# K-Nearest Neighbour Precision: 0.989155665262
# K-Nearest Neighbour Area Under ROC Curve: 0.989149570032
# K-Nearest Neighbour Area Under Precision Recall Curve: 0.974525374825
# K-Nearest Neighbour MCC: 0.98118028929
#
# Unnormalized Results for Naive Bayes:
#
# Naive Bayes Accuracy Score: 0.9788093774
# Naive Bayes F-Measure: 0.952521719428
# Naive Bayes Sensitivity: 0.997101449275
# Naive Bayes Specificity: 0.973881797013
# Naive Bayes Precision: 0.912119800735
# Naive Bayes Area Under ROC Curve: 0.985491623144
# Naive Bayes Area Under Precision Recall Curve: 0.910104028771
# Naive Bayes MCC: 0.940630372536
#
#
# Normalized Results for Naive Bayes:
#
# Naive Bayes Accuracy Score: 0.989405865607
# Naive Bayes F-Measure: 0.975666131904
# Naive Bayes Sensitivity: 0.997826086957
# Naive Bayes Specificity: 0.987136399147
# Naive Bayes Precision: 0.954620247581
# Naive Bayes Area Under ROC Curve: 0.992481243052
# Naive Bayes Area Under Precision Recall Curve: 0.952988461982
# Naive Bayes MCC: 0.969353111156
#
# Unnormalized Results for Decision Tree:
#
# Decision Tree Accuracy Score: 0.991249419899
# Decision Tree F-Measure: 0.979375261706
# Decision Tree Sensitivity: 0.979777916797
# Decision Tree Specificity: 0.994348116292
# Decision Tree Precision: 0.979241945317
# Decision Tree Area Under ROC Curve: 0.987063016544
# Decision Tree Area Under Precision Recall Curve: 0.963669231603
# Decision Tree MCC: 0.973930345142
#
#
# Normalized Results for Decision Tree:
#
# Decision Tree Accuracy Score: 0.991095810068
# Decision Tree F-Measure: 0.979009158276
# Decision Tree Sensitivity: 0.979053279116
# Decision Tree Specificity: 0.994348116292
# Decision Tree Precision: 0.979216972787
# Decision Tree Area Under ROC Curve: 0.986700697704
# Decision Tree Area Under Precision Recall Curve: 0.963099108555
# Decision Tree MCC: 0.97345996652
#
# Unnormalized Results for Random Forest:
#
# Random Forest Accuracy Score: 0.99416494608
# Random Forest F-Measure: 0.986254839634
# Random Forest Sensitivity: 0.986263163382
# Random Forest Specificity: 0.996296675541
# Random Forest Precision: 0.986355589415
# Random Forest Area Under ROC Curve: 0.991279919462
# Random Forest Area Under Precision Recall Curve: 0.975708013286
# Random Forest MCC: 0.982595044853
#
#
# Normalized Results for Random Forest:
#
# Random Forest Accuracy Score: 0.994471930145
# Random Forest F-Measure: 0.986979384422
# Random Forest Sensitivity: 0.987707225524
# Random Forest Specificity: 0.996296675541
# Random Forest Precision: 0.986380706185
# Random Forest Area Under ROC Curve: 0.992001950532
# Random Forest Area Under Precision Recall Curve: 0.976844475321
# Random Forest MCC: 0.983522506563
#
# Unnormalized Results for Support Vector Machine:
#
# Support Vector Machine Accuracy Score: 0.787688495819
# Support Vector Machine F-Measure: 0.0
# Support Vector Machine Sensitivity: 0.0
# Support Vector Machine Specificity: 1.0
# Support Vector Machine Precision: 0.0
# Support Vector Machine Area Under ROC Curve: 0.5
# Support Vector Machine Area Under Precision Recall Curve: 0.212311504181
# Support Vector Machine MCC: 0.0
#
#
# Normalized Results for Support Vector Machine:
#
# Support Vector Machine Accuracy Score: 0.988792132355
# Support Vector Machine F-Measure: 0.974310144264
# Support Vector Machine Sensitivity: 0.998550724638
# Support Vector Machine Specificity: 0.986162119523
# Support Vector Machine Precision: 0.951353025314
# Support Vector Machine Area Under ROC Curve: 0.99235642208
# Support Vector Machine Area Under Precision Recall Curve: 0.950280821792
# Support Vector Machine MCC: 0.967670688953
#
# Unnormalized Results for Linear Discriminant Analysis:
#
# Linear Discriminant Analysis Accuracy Score: 0.988791897479
# Linear Discriminant Analysis F-Measure: 0.974307691132
# Linear Discriminant Analysis Sensitivity: 0.998550724638
# Linear Discriminant Analysis Specificity: 0.986161740278
# Linear Discriminant Analysis Precision: 0.951343714701
# Linear Discriminant Analysis Area Under ROC Curve: 0.992356232458
# Linear Discriminant Analysis Area Under Precision Recall Curve: 0.950271511179
# Linear Discriminant Analysis MCC: 0.96766639464
#
#
# Normalized Results for Linear Discriminant Analysis:
#
# Linear Discriminant Analysis Accuracy Score: 0.988791897479
# Linear Discriminant Analysis F-Measure: 0.974307691132
# Linear Discriminant Analysis Sensitivity: 0.998550724638
# Linear Discriminant Analysis Specificity: 0.986161740278
# Linear Discriminant Analysis Precision: 0.951343714701
# Linear Discriminant Analysis Area Under ROC Curve: 0.992356232458
# Linear Discriminant Analysis Area Under Precision Recall Curve: 0.950271511179
# Linear Discriminant Analysis MCC: 0.96766639464
#
# Unnormalized Results for AdaBoostClassifier:
#
# AdaBoostClassifier Accuracy Score: 0.990941021526
# AdaBoostClassifier F-Measure: 0.979023886831
# AdaBoostClassifier Sensitivity: 0.992044625169
# AdaBoostClassifier Specificity: 0.990645171077
# AdaBoostClassifier Precision: 0.966554368179
# AdaBoostClassifier Area Under ROC Curve: 0.991344898123
# AdaBoostClassifier Area Under Precision Recall Curve: 0.960527205399
# AdaBoostClassifier MCC: 0.973473086519
#
#
# Normalized Results for AdaBoostClassifier:
#
# AdaBoostClassifier Accuracy Score: 0.990941021526
# AdaBoostClassifier F-Measure: 0.979023886831
# AdaBoostClassifier Sensitivity: 0.992044625169
# AdaBoostClassifier Specificity: 0.990645171077
# AdaBoostClassifier Precision: 0.966554368179
# AdaBoostClassifier Area Under ROC Curve: 0.991344898123
# AdaBoostClassifier Area Under Precision Recall Curve: 0.960527205399
# AdaBoostClassifier MCC: 0.973473086519

# %% [markdown]
# ### 6. Use three feature selection methods to select feature subsets on train set 2 and compute accuracy measures in step 5 for all the classifiers. Repeat for normalized version of train set 2. Do you get improvement in accuracy when you perform feature selection or is it better to use all of the features? Which feature selection strategy gives the best accuracy?

# %%
for name, model in models:
    selectors = [
        ("VarianceThreshold", VarianceThreshold()),
        ("SelectKBest with f_classif 1", SelectKBest(f_classif,k=1)),
        ("SelectKBest with chi2 1", SelectKBest(chi2,k=1)),
        ("SelectKBest with f_classif 2", SelectKBest(f_classif,k=2)),
        ("SelectKBest with chi2 2", SelectKBest(chi2,k=2)),
        ("SelectKBest with f_classif 3", SelectKBest(f_classif,k=3)),
        ("SelectKBest with chi2 3", SelectKBest(chi2,k=3)),
        ("SelectKBest with f_classif 4", SelectKBest(f_classif,k=4)),
        ("SelectKBest with chi2 4", SelectKBest(chi2,k=4)),
        ("SelectKBest with f_classif 5", SelectKBest(f_classif,k=5)),
        ("SelectKBest with chi2 5", SelectKBest(chi2,k=5)),
        ("SelectKBest with f_classif 6", SelectKBest(f_classif,k=6)),
        ("SelectKBest with chi2 7", SelectKBest(chi2,k=6)),
        ("SelectKBest with f_classif 7", SelectKBest(f_classif,k=7)),
        ("SelectKBest with chi2 7", SelectKBest(chi2,k=7))
    ]
    
    for selector_name, selector in selectors:  
        selected_x_train_two = selector.fit_transform(X_train_two, y=y_train_two)
        normalized_selected_x_train_two  = selector.fit_transform(normalized_x_train_two, y=y_train_two)

        print("{} unnormalized results:\n".format(selector_name))
        dump_metrics_with_cv(selected_x_train_two, y_train_two, name, model)

        print("{} normalized results:\n".format(selector_name))
        dump_metrics_with_cv(normalized_selected_x_train_two, y_train_two, name, model)

print("Yes, I did get improvement when I performed feature selection.")
print("SelectKBest that uses chi2 with 4 features gave the best accuracy.")
# Out:
# VarianceThreshold unnormalized results:
#
# Logistic Regression Accuracy Score: 0.982649389021
# Logistic Regression F-Measure: 0.96063221029
# Logistic Regression Sensitivity: 0.99133041393
# Logistic Regression Specificity: 0.980313787062
# Logistic Regression Precision: 0.932265962074
# Logistic Regression Area Under ROC Curve: 0.985822100496
# Logistic Regression Area Under Precision Recall Curve: 0.925995821007
# Logistic Regression MCC: 0.950474980812
#
# VarianceThreshold normalized results:
#
# Logistic Regression Accuracy Score: 0.988945271712
# Logistic Regression F-Measure: 0.974631060518
# Logistic Regression Sensitivity: 0.997826086957
# Logistic Regression Specificity: 0.986551603826
# Logistic Regression Precision: 0.952632448389
# Logistic Regression Area Under ROC Curve: 0.992188845391
# Logistic Regression Area Under Precision Recall Curve: 0.951010106793
# Logistic Regression MCC: 0.968055905242
#
# SelectKBest with f_classif 1 unnormalized results:
#
# Logistic Regression Accuracy Score: 0.981881103546
# Logistic Regression F-Measure: 0.959031651804
# Logistic Regression Sensitivity: 0.995657387134
# Logistic Regression Specificity: 0.978169916794
# Logistic Regression Precision: 0.925319355591
# Logistic Regression Area Under ROC Curve: 0.986913651964
# Logistic Regression Area Under Precision Recall Curve: 0.922179291081
# Logistic Regression MCC: 0.948612031873
#
# SelectKBest with f_classif 1 normalized results:
#
# Logistic Regression Accuracy Score: 0.97804179944
# Logistic Regression F-Measure: 0.950810745091
# Logistic Regression Sensitivity: 0.996376811594
# Logistic Regression Specificity: 0.973102069918
# Logistic Regression Precision: 0.909541331191
# Logistic Regression Area Under ROC Curve: 0.984739440756
# Logistic Regression Area Under Precision Recall Curve: 0.907022388472
# Logistic Regression MCC: 0.938474708419
#
# SelectKBest with chi2 1 unnormalized results:
#
# Logistic Regression Accuracy Score: 0.981881103546
# Logistic Regression F-Measure: 0.959031651804
# Logistic Regression Sensitivity: 0.995657387134
# Logistic Regression Specificity: 0.978169916794
# Logistic Regression Precision: 0.925319355591
# Logistic Regression Area Under ROC Curve: 0.986913651964
# Logistic Regression Area Under Precision Recall Curve: 0.922179291081
# Logistic Regression MCC: 0.948612031873
#
# SelectKBest with chi2 1 normalized results:
#
# Logistic Regression Accuracy Score: 0.97804179944
# Logistic Regression F-Measure: 0.950810745091
# Logistic Regression Sensitivity: 0.996376811594
# Logistic Regression Specificity: 0.973102069918
# Logistic Regression Precision: 0.909541331191
# Logistic Regression Area Under ROC Curve: 0.984739440756
# Logistic Regression Area Under Precision Recall Curve: 0.907022388472
# Logistic Regression MCC: 0.938474708419
#
# SelectKBest with f_classif 2 unnormalized results:
#
# Logistic Regression Accuracy Score: 0.98863805205
# Logistic Regression F-Measure: 0.97390423569
# Logistic Regression Sensitivity: 0.996376811594
# Logistic Regression Specificity: 0.986551603826
# Logistic Regression Precision: 0.952569785956
# Logistic Regression Area Under ROC Curve: 0.99146420771
# Logistic Regression Area Under Precision Recall Curve: 0.949871018481
# Logistic Regression MCC: 0.967110414133
#
# SelectKBest with f_classif 2 normalized results:
#
# Logistic Regression Accuracy Score: 0.988177458155
# Logistic Regression F-Measure: 0.972688221225
# Logistic Regression Sensitivity: 0.989865498905
# Logistic Regression Specificity: 0.987720815224
# Logistic Regression Precision: 0.956280887294
# Logistic Regression Area Under ROC Curve: 0.988793157065
# Logistic Regression Area Under Precision Recall Curve: 0.948697691294
# Logistic Regression MCC: 0.965460295992
#
# SelectKBest with chi2 2 unnormalized results:
#
# Logistic Regression Accuracy Score: 0.968987766357
# Logistic Regression F-Measure: 0.927487491358
# Logistic Regression Sensitivity: 0.933515796059
# Logistic Regression Specificity: 0.978559401097
# Logistic Regression Precision: 0.922096766528
# Logistic Regression Area Under ROC Curve: 0.956037598578
# Logistic Regression Area Under Precision Recall Curve: 0.874790692138
# Logistic Regression MCC: 0.908022144666
#
# SelectKBest with chi2 2 normalized results:
#
# Logistic Regression Accuracy Score: 0.988177458155
# Logistic Regression F-Measure: 0.972688221225
# Logistic Regression Sensitivity: 0.989865498905
# Logistic Regression Specificity: 0.987720815224
# Logistic Regression Precision: 0.956280887294
# Logistic Regression Area Under ROC Curve: 0.988793157065
# Logistic Regression Area Under Precision Recall Curve: 0.948697691294
# Logistic Regression MCC: 0.965460295992
#
# SelectKBest with f_classif 3 unnormalized results:
#
# Logistic Regression Accuracy Score: 0.98863805205
# Logistic Regression F-Measure: 0.97390423569
# Logistic Regression Sensitivity: 0.996376811594
# Logistic Regression Specificity: 0.986551603826
# Logistic Regression Precision: 0.952569785956
# Logistic Regression Area Under ROC Curve: 0.99146420771
# Logistic Regression Area Under Precision Recall Curve: 0.949871018481
# Logistic Regression MCC: 0.967110414133
#
# SelectKBest with f_classif 3 normalized results:
#
# Logistic Regression Accuracy Score: 0.98863805205
# Logistic Regression F-Measure: 0.97390423569
# Logistic Regression Sensitivity: 0.996376811594
# Logistic Regression Specificity: 0.986551603826
# Logistic Regression Precision: 0.952569785956
# Logistic Regression Area Under ROC Curve: 0.99146420771
# Logistic Regression Area Under Precision Recall Curve: 0.949871018481
# Logistic Regression MCC: 0.967110414133
#
# SelectKBest with chi2 3 unnormalized results:
#
# Logistic Regression Accuracy Score: 0.972054311514
# Logistic Regression F-Measure: 0.937859916438
# Logistic Regression Sensitivity: 0.989870712126
# Logistic Regression Specificity: 0.967255254435
# Logistic Regression Precision: 0.891470871838
# Logistic Regression Area Under ROC Curve: 0.978562983281
# Logistic Regression Area Under Precision Recall Curve: 0.884592238968
# Logistic Regression MCC: 0.922203425319
#
# SelectKBest with chi2 3 normalized results:
#
# Logistic Regression Accuracy Score: 0.988791661881
# Logistic Regression F-Measure: 0.97426761689
# Logistic Regression Sensitivity: 0.997101449275
# Logistic Regression Specificity: 0.986551603826
# Logistic Regression Precision: 0.95260331086
# Logistic Regression Area Under ROC Curve: 0.991826526551
# Logistic Regression Area Under Precision Recall Curve: 0.950440345792
# Logistic Regression MCC: 0.967584072762
#
# SelectKBest with f_classif 4 unnormalized results:
#
# Logistic Regression Accuracy Score: 0.98863805205
# Logistic Regression F-Measure: 0.97390423569
# Logistic Regression Sensitivity: 0.996376811594
# Logistic Regression Specificity: 0.986551603826
# Logistic Regression Precision: 0.952569785956
# Logistic Regression Area Under ROC Curve: 0.99146420771
# Logistic Regression Area Under Precision Recall Curve: 0.949871018481
# Logistic Regression MCC: 0.967110414133
#
# SelectKBest with f_classif 4 normalized results:
#
# Logistic Regression Accuracy Score: 0.988791661881
# Logistic Regression F-Measure: 0.97426761689
# Logistic Regression Sensitivity: 0.997101449275
# Logistic Regression Specificity: 0.986551603826
# Logistic Regression Precision: 0.95260331086
# Logistic Regression Area Under ROC Curve: 0.991826526551
# Logistic Regression Area Under Precision Recall Curve: 0.950440345792
# Logistic Regression MCC: 0.967584072762
#
# SelectKBest with chi2 4 unnormalized results:
#
# Logistic Regression Accuracy Score: 0.972054311514
# Logistic Regression F-Measure: 0.937859916438
# Logistic Regression Sensitivity: 0.989870712126
# Logistic Regression Specificity: 0.967255254435
# Logistic Regression Precision: 0.891470871838
# Logistic Regression Area Under ROC Curve: 0.978562983281
# Logistic Regression Area Under Precision Recall Curve: 0.884592238968
# Logistic Regression MCC: 0.922203425319
#
# SelectKBest with chi2 4 normalized results:
#
# Logistic Regression Accuracy Score: 0.988791661881
# Logistic Regression F-Measure: 0.97426761689
# Logistic Regression Sensitivity: 0.997101449275
# Logistic Regression Specificity: 0.986551603826
# Logistic Regression Precision: 0.95260331086
# Logistic Regression Area Under ROC Curve: 0.991826526551
# Logistic Regression Area Under Precision Recall Curve: 0.950440345792
# Logistic Regression MCC: 0.967584072762
#
# SelectKBest with f_classif 5 unnormalized results:
# Logistic Regression Accuracy Score: 0.98863805205
# Logistic Regression F-Measure: 0.97390423569
# Logistic Regression Sensitivity: 0.996376811594
# Logistic Regression Specificity: 0.986551603826
# Logistic Regression Precision: 0.952569785956
# Logistic Regression Area Under ROC Curve: 0.99146420771
# Logistic Regression Area Under Precision Recall Curve: 0.949871018481
# Logistic Regression MCC: 0.967110414133
#
# SelectKBest with f_classif 5 normalized results:
#
# Logistic Regression Accuracy Score: 0.988945271712
# Logistic Regression F-Measure: 0.974631060518
# Logistic Regression Sensitivity: 0.997826086957
# Logistic Regression Specificity: 0.986551603826
# Logistic Regression Precision: 0.952632448389
# Logistic Regression Area Under ROC Curve: 0.992188845391
# Logistic Regression Area Under Precision Recall Curve: 0.951010106793
# Logistic Regression MCC: 0.968055905242
#
# SelectKBest with chi2 5 unnormalized results:
#
# Logistic Regression Accuracy Score: 0.968371914167
# Logistic Regression F-Measure: 0.929181523093
# Logistic Regression Sensitivity: 0.975456156814
# Logistic Regression Specificity: 0.966475148095
# Logistic Regression Precision: 0.887903710452
# Logistic Regression Area Under ROC Curve: 0.970965652454
# Logistic Regression Area Under Precision Recall Curve: 0.871197565725
# Logistic Regression MCC: 0.910929195028
#
# SelectKBest with chi2 5 normalized results:
#
# Logistic Regression Accuracy Score: 0.988945271712
# Logistic Regression F-Measure: 0.974631060518
# Logistic Regression Sensitivity: 0.997826086957
# Logistic Regression Specificity: 0.986551603826
# Logistic Regression Precision: 0.952632448389
# Logistic Regression Area Under ROC Curve: 0.992188845391
# Logistic Regression Area Under Precision Recall Curve: 0.951010106793
# Logistic Regression MCC: 0.968055905242
#
# SelectKBest with f_classif 6 unnormalized results:
#
# Logistic Regression Accuracy Score: 0.988791661881
# Logistic Regression F-Measure: 0.97426761689
# Logistic Regression Sensitivity: 0.997101449275
# Logistic Regression Specificity: 0.986551603826
# Logistic Regression Precision: 0.95260331086
# Logistic Regression Area Under ROC Curve: 0.991826526551
# Logistic Regression Area Under Precision Recall Curve: 0.950440345792
# Logistic Regression MCC: 0.967584072762
#
# SelectKBest with f_classif 6 normalized results:
#
# Logistic Regression Accuracy Score: 0.988945271712
# Logistic Regression F-Measure: 0.974631060518
# Logistic Regression Sensitivity: 0.997826086957
# Logistic Regression Specificity: 0.986551603826
# Logistic Regression Precision: 0.952632448389
# Logistic Regression Area Under ROC Curve: 0.992188845391
# Logistic Regression Area Under Precision Recall Curve: 0.951010106793
# Logistic Regression MCC: 0.968055905242
#
# SelectKBest with chi2 7 unnormalized results:
#
# Logistic Regression Accuracy Score: 0.980959680879
# Logistic Regression F-Measure: 0.956675444569
# Logistic Regression Sensitivity: 0.98481388802
# Logistic Regression Specificity: 0.979923923514
# Logistic Regression Precision: 0.930646580397
# Logistic Regression Area Under ROC Curve: 0.982368905767
# Logistic Regression Area Under Precision Recall Curve: 0.919720890719
# Logistic Regression MCC: 0.945352343911
#
# SelectKBest with chi2 7 normalized results:
#
# Logistic Regression Accuracy Score: 0.988945271712
# Logistic Regression F-Measure: 0.974631060518
# Logistic Regression Sensitivity: 0.997826086957
# Logistic Regression Specificity: 0.986551603826
# Logistic Regression Precision: 0.952632448389
# Logistic Regression Area Under ROC Curve: 0.992188845391
# Logistic Regression Area Under Precision Recall Curve: 0.951010106793
# Logistic Regression MCC: 0.968055905242
#
# SelectKBest with f_classif 7 unnormalized results:
#
# Logistic Regression Accuracy Score: 0.982649389021
# Logistic Regression F-Measure: 0.96063221029
# Logistic Regression Sensitivity: 0.99133041393
# Logistic Regression Specificity: 0.980313787062
# Logistic Regression Precision: 0.932265962074
# Logistic Regression Area Under ROC Curve: 0.985822100496
# Logistic Regression Area Under Precision Recall Curve: 0.925995821007
# Logistic Regression MCC: 0.950474980812
#
# SelectKBest with f_classif 7 normalized results:
#
# Logistic Regression Accuracy Score: 0.988945271712
# Logistic Regression F-Measure: 0.974631060518
# Logistic Regression Sensitivity: 0.997826086957
# Logistic Regression Specificity: 0.986551603826
# Logistic Regression Precision: 0.952632448389
# Logistic Regression Area Under ROC Curve: 0.992188845391
# Logistic Regression Area Under Precision Recall Curve: 0.951010106793
# Logistic Regression MCC: 0.968055905242
#
# SelectKBest with chi2 7 unnormalized results:
#
# Logistic Regression Accuracy Score: 0.982649389021
# Logistic Regression F-Measure: 0.96063221029
# Logistic Regression Sensitivity: 0.99133041393
# Logistic Regression Specificity: 0.980313787062
# Logistic Regression Precision: 0.932265962074
# Logistic Regression Area Under ROC Curve: 0.985822100496
# Logistic Regression Area Under Precision Recall Curve: 0.925995821007
# Logistic Regression MCC: 0.950474980812
#
# SelectKBest with chi2 7 normalized results:
#
# Logistic Regression Accuracy Score: 0.988945271712
# Logistic Regression F-Measure: 0.974631060518
# Logistic Regression Sensitivity: 0.997826086957
# Logistic Regression Specificity: 0.986551603826
# Logistic Regression Precision: 0.952632448389
# Logistic Regression Area Under ROC Curve: 0.992188845391
# Logistic Regression Area Under Precision Recall Curve: 0.951010106793
# Logistic Regression MCC: 0.968055905242
#
# VarianceThreshold unnormalized results:
#
# K-Nearest Neighbour Accuracy Score: 0.993398543946
# K-Nearest Neighbour F-Measure: 0.98445991284
# K-Nearest Neighbour Sensitivity: 0.985543738922
# K-Nearest Neighbour Specificity: 0.995517706935
# K-Nearest Neighbour Precision: 0.983501777729
# K-Nearest Neighbour Area Under ROC Curve: 0.990530722928
# K-Nearest Neighbour Area Under Precision Recall Curve: 0.972319984519
# K-Nearest Neighbour MCC: 0.980319749123
#
# VarianceThreshold normalized results:
#
# K-Nearest Neighbour Accuracy Score: 0.993706940876
# K-Nearest Neighbour F-Measure: 0.985086637998
# K-Nearest Neighbour Sensitivity: 0.981221978939
# K-Nearest Neighbour Specificity: 0.997077161126
# K-Nearest Neighbour Precision: 0.989155665262
# K-Nearest Neighbour Area Under ROC Curve: 0.989149570032
# K-Nearest Neighbour Area Under Precision Recall Curve: 0.974525374825
# K-Nearest Neighbour MCC: 0.98118028929
#
# SelectKBest with f_classif 1 unnormalized results:
#
# K-Nearest Neighbour Accuracy Score: 0.98188251569
# K-Nearest Neighbour F-Measure: 0.957454995547
# K-Nearest Neighbour Sensitivity: 0.961656761547
# K-Nearest Neighbour Specificity: 0.987330951677
# K-Nearest Neighbour Precision: 0.953634375236
# K-Nearest Neighbour Area Under ROC Curve: 0.974493856612
# K-Nearest Neighbour Area Under Precision Recall Curve: 0.92531876613
# K-Nearest Neighbour MCC: 0.946100750182
#
# SelectKBest with f_classif 1 normalized results:
#
# K-Nearest Neighbour Accuracy Score: 0.981728905859
# K-Nearest Neighbour F-Measure: 0.957075672573
# K-Nearest Neighbour Sensitivity: 0.960932123866
# K-Nearest Neighbour Specificity: 0.987330951677
# K-Nearest Neighbour Precision: 0.953597882691
# K-Nearest Neighbour Area Under ROC Curve: 0.974131537771
# K-Nearest Neighbour Area Under Precision Recall Curve: 0.924749589351
# K-Nearest Neighbour MCC: 0.945624187709
#
# SelectKBest with chi2 1 unnormalized results:
#
# K-Nearest Neighbour Accuracy Score: 0.98188251569
# K-Nearest Neighbour F-Measure: 0.957454995547
# K-Nearest Neighbour Sensitivity: 0.961656761547
# K-Nearest Neighbour Specificity: 0.987330951677
# K-Nearest Neighbour Precision: 0.953634375236
# K-Nearest Neighbour Area Under ROC Curve: 0.974493856612
# K-Nearest Neighbour Area Under Precision Recall Curve: 0.92531876613
# K-Nearest Neighbour MCC: 0.946100750182
#
# SelectKBest with chi2 1 normalized results:
#
# K-Nearest Neighbour Accuracy Score: 0.981728905859
# K-Nearest Neighbour F-Measure: 0.957075672573
# K-Nearest Neighbour Sensitivity: 0.960932123866
# K-Nearest Neighbour Specificity: 0.987330951677
# K-Nearest Neighbour Precision: 0.953597882691
# K-Nearest Neighbour Area Under ROC Curve: 0.974131537771
# K-Nearest Neighbour Area Under Precision Recall Curve: 0.924749589351
# K-Nearest Neighbour MCC: 0.945624187709
#
# SelectKBest with f_classif 2 unnormalized results:
#
# K-Nearest Neighbour Accuracy Score: 0.986335318172
# K-Nearest Neighbour F-Measure: 0.967829843397
# K-Nearest Neighbour Sensitivity: 0.968183713898
# K-Nearest Neighbour Specificity: 0.99122920791
# K-Nearest Neighbour Precision: 0.967550011385
# K-Nearest Neighbour Area Under ROC Curve: 0.979706460904
# K-Nearest Neighbour Area Under Precision Recall Curve: 0.943638331349
# K-Nearest Neighbour MCC: 0.959184981901
#
# SelectKBest with f_classif 2 normalized results:
#
# K-Nearest Neighbour Accuracy Score: 0.986642537112
# K-Nearest Neighbour F-Measure: 0.968584946594
# K-Nearest Neighbour Sensitivity: 0.969632989261
# K-Nearest Neighbour Specificity: 0.99122920791
# K-Nearest Neighbour Precision: 0.967665609231
# K-Nearest Neighbour Area Under ROC Curve: 0.980431098585
# K-Nearest Neighbour Area Under Precision Recall Curve: 0.944788671862
# K-Nearest Neighbour MCC: 0.960154943419
#
# SelectKBest with chi2 2 unnormalized results:
#
# K-Nearest Neighbour Accuracy Score: 0.982958492023
# K-Nearest Neighbour F-Measure: 0.960185840518
# K-Nearest Neighbour Sensitivity: 0.966744864978
# K-Nearest Neighbour Specificity: 0.987331330921
# K-Nearest Neighbour Precision: 0.954103813365
# K-Nearest Neighbour Area Under ROC Curve: 0.977038097949
# K-Nearest Neighbour Area Under Precision Recall Curve: 0.929393728838
# K-Nearest Neighbour MCC: 0.949539402769
#
# SelectKBest with chi2 2 normalized results:
#
# K-Nearest Neighbour Accuracy Score: 0.986642537112
# K-Nearest Neighbour F-Measure: 0.968584946594
# K-Nearest Neighbour Sensitivity: 0.969632989261
# K-Nearest Neighbour Specificity: 0.99122920791
# K-Nearest Neighbour Precision: 0.967665609231
# K-Nearest Neighbour Area Under ROC Curve: 0.980431098585
# K-Nearest Neighbour Area Under Precision Recall Curve: 0.944788671862
# K-Nearest Neighbour MCC: 0.960154943419
#
# SelectKBest with f_classif 3 unnormalized results:
#
# K-Nearest Neighbour Accuracy Score: 0.987103131729
# K-Nearest Neighbour F-Measure: 0.969640131657
# K-Nearest Neighbour Sensitivity: 0.969632989261
# K-Nearest Neighbour Specificity: 0.991814003231
# K-Nearest Neighbour Precision: 0.969733912419
# K-Nearest Neighbour Area Under ROC Curve: 0.980723496246
# K-Nearest Neighbour Area Under Precision Recall Curve: 0.946827379333
# K-Nearest Neighbour MCC: 0.96148760687
#
# SelectKBest with f_classif 3 normalized results:
#
# K-Nearest Neighbour Accuracy Score: 0.992478062228
# K-Nearest Neighbour F-Measure: 0.982179954431
# K-Nearest Neighbour Sensitivity: 0.979042852674
# K-Nearest Neighbour Specificity: 0.996102502257
# K-Nearest Neighbour Precision: 0.985526348595
# K-Nearest Neighbour Area Under ROC Curve: 0.987572677465
# K-Nearest Neighbour Area Under Precision Recall Curve: 0.969289357287
# K-Nearest Neighbour MCC: 0.977496450584
#
# SelectKBest with chi2 3 unnormalized results:
#
# K-Nearest Neighbour Accuracy Score: 0.993551918179
# K-Nearest Neighbour F-Measure: 0.984831512044
# K-Nearest Neighbour Sensitivity: 0.986263163382
# K-Nearest Neighbour Specificity: 0.995517706935
# K-Nearest Neighbour Precision: 0.983507224352
# K-Nearest Neighbour Area Under ROC Curve: 0.990890435159
# K-Nearest Neighbour Area Under Precision Recall Curve: 0.972885995562
# K-Nearest Neighbour MCC: 0.98078060835
#
# SelectKBest with chi2 3 normalized results:
#
# K-Nearest Neighbour Accuracy Score: 0.987103366605
# K-Nearest Neighbour F-Measure: 0.969626310959
# K-Nearest Neighbour Sensitivity: 0.969632989261
# K-Nearest Neighbour Specificity: 0.991814003231
# K-Nearest Neighbour Precision: 0.969730938334
# K-Nearest Neighbour Area Under ROC Curve: 0.980723496246
# K-Nearest Neighbour Area Under Precision Recall Curve: 0.946784461134
# K-Nearest Neighbour MCC: 0.961484959131
#
# SelectKBest with f_classif 4 unnormalized results:
#
# K-Nearest Neighbour Accuracy Score: 0.987103131729
# K-Nearest Neighbour F-Measure: 0.969640131657
# K-Nearest Neighbour Sensitivity: 0.969632989261
# K-Nearest Neighbour Specificity: 0.991814003231
# K-Nearest Neighbour Precision: 0.969733912419
# K-Nearest Neighbour Area Under ROC Curve: 0.980723496246
# K-Nearest Neighbour Area Under Precision Recall Curve: 0.946827379333
# K-Nearest Neighbour MCC: 0.96148760687
#
# SelectKBest with f_classif 4 normalized results:
#
# K-Nearest Neighbour Accuracy Score: 0.992785046292
# K-Nearest Neighbour F-Measure: 0.982891404253
# K-Nearest Neighbour Sensitivity: 0.979042852674
# K-Nearest Neighbour Specificity: 0.996492365804
# K-Nearest Neighbour Precision: 0.986959896435
# K-Nearest Neighbour Area Under ROC Curve: 0.987767609239
# K-Nearest Neighbour Area Under Precision Recall Curve: 0.970691556941
# K-Nearest Neighbour MCC: 0.978407849225
#
# SelectKBest with chi2 4 unnormalized results:
#
# K-Nearest Neighbour Accuracy Score: 0.993551918179
# K-Nearest Neighbour F-Measure: 0.984831512044
# K-Nearest Neighbour Sensitivity: 0.986263163382
# K-Nearest Neighbour Specificity: 0.995517706935
# K-Nearest Neighbour Precision: 0.983507224352
# K-Nearest Neighbour Area Under ROC Curve: 0.990890435159
# K-Nearest Neighbour Area Under Precision Recall Curve: 0.972885995562
# K-Nearest Neighbour MCC: 0.98078060835
#
# SelectKBest with chi2 4 normalized results:
#
# K-Nearest Neighbour Accuracy Score: 0.992785046292
# K-Nearest Neighbour F-Measure: 0.982891404253
# K-Nearest Neighbour Sensitivity: 0.979042852674
# K-Nearest Neighbour Specificity: 0.996492365804
# K-Nearest Neighbour Precision: 0.986959896435
# K-Nearest Neighbour Area Under ROC Curve: 0.987767609239
# K-Nearest Neighbour Area Under Precision Recall Curve: 0.970691556941
# K-Nearest Neighbour MCC: 0.978407849225
#
# SelectKBest with f_classif 5 unnormalized results:
#
# K-Nearest Neighbour Accuracy Score: 0.987103131729
# K-Nearest Neighbour F-Measure: 0.969640131657
# K-Nearest Neighbour Sensitivity: 0.969632989261
# K-Nearest Neighbour Specificity: 0.991814003231
# K-Nearest Neighbour Precision: 0.969733912419
# K-Nearest Neighbour Area Under ROC Curve: 0.980723496246
# K-Nearest Neighbour Area Under Precision Recall Curve: 0.946827379333
# K-Nearest Neighbour MCC: 0.96148760687
#
# SelectKBest with f_classif 5 normalized results:
#
# K-Nearest Neighbour Accuracy Score: 0.993399485616
# K-Nearest Neighbour F-Measure: 0.984369916418
# K-Nearest Neighbour Sensitivity: 0.981216765718
# K-Nearest Neighbour Specificity: 0.996687297578
# K-Nearest Neighbour Precision: 0.987716748485
# K-Nearest Neighbour Area Under ROC Curve: 0.988952031648
# K-Nearest Neighbour Area Under Precision Recall Curve: 0.973112983818
# K-Nearest Neighbour MCC: 0.980263602854
#
# SelectKBest with chi2 5 unnormalized results:
#
# K-Nearest Neighbour Accuracy Score: 0.993398543946
# K-Nearest Neighbour F-Measure: 0.98445991284
# K-Nearest Neighbour Sensitivity: 0.985543738922
# K-Nearest Neighbour Specificity: 0.995517706935
# K-Nearest Neighbour Precision: 0.983501777729
# K-Nearest Neighbour Area Under ROC Curve: 0.990530722928
# K-Nearest Neighbour Area Under Precision Recall Curve: 0.972319984519
# K-Nearest Neighbour MCC: 0.980319749123
#
# SelectKBest with chi2 5 normalized results:
#
# K-Nearest Neighbour Accuracy Score: 0.993399485616
# K-Nearest Neighbour F-Measure: 0.984369916418
# K-Nearest Neighbour Sensitivity: 0.981216765718
# K-Nearest Neighbour Specificity: 0.996687297578
# K-Nearest Neighbour Precision: 0.987716748485
# K-Nearest Neighbour Area Under ROC Curve: 0.988952031648
# K-Nearest Neighbour Area Under Precision Recall Curve: 0.973112983818
# K-Nearest Neighbour MCC: 0.980263602854
#
# SelectKBest with f_classif 6 unnormalized results:
#
# K-Nearest Neighbour Accuracy Score: 0.990173444288
# K-Nearest Neighbour F-Measure: 0.976956770258
# K-Nearest Neighbour Sensitivity: 0.980481701595
# K-Nearest Neighbour Specificity: 0.992788662101
# K-Nearest Neighbour Precision: 0.973572438557
# K-Nearest Neighbour Area Under ROC Curve: 0.986635181848
# K-Nearest Neighbour Area Under Precision Recall Curve: 0.958738534078
# K-Nearest Neighbour MCC: 0.970768981284
#
# SelectKBest with f_classif 6 normalized results:
#
# K-Nearest Neighbour Accuracy Score: 0.993399721214
# K-Nearest Neighbour F-Measure: 0.984383043879
# K-Nearest Neighbour Sensitivity: 0.98194661662
# K-Nearest Neighbour Specificity: 0.996492365804
# K-Nearest Neighbour Precision: 0.987018253013
# K-Nearest Neighbour Area Under ROC Curve: 0.989219491212
# K-Nearest Neighbour Area Under Precision Recall Curve: 0.972979612679
# K-Nearest Neighbour MCC: 0.98027803497
#
# SelectKBest with chi2 7 unnormalized results:
#
# K-Nearest Neighbour Accuracy Score: 0.993398543946
# K-Nearest Neighbour F-Measure: 0.98445991284
# K-Nearest Neighbour Sensitivity: 0.985543738922
# K-Nearest Neighbour Specificity: 0.995517706935
# K-Nearest Neighbour Precision: 0.983501777729
# K-Nearest Neighbour Area Under ROC Curve: 0.990530722928
# K-Nearest Neighbour Area Under Precision Recall Curve: 0.972319984519
# K-Nearest Neighbour MCC: 0.980319749123
#
# SelectKBest with chi2 7 normalized results:
#
# K-Nearest Neighbour Accuracy Score: 0.993399721214
# K-Nearest Neighbour F-Measure: 0.984383043879
# K-Nearest Neighbour Sensitivity: 0.98194661662
# K-Nearest Neighbour Specificity: 0.996492365804
# K-Nearest Neighbour Precision: 0.987018253013
# K-Nearest Neighbour Area Under ROC Curve: 0.989219491212
# K-Nearest Neighbour Area Under Precision Recall Curve: 0.972979612679
# K-Nearest Neighbour MCC: 0.98027803497
#
# SelectKBest with f_classif 7 unnormalized results:
#
# K-Nearest Neighbour Accuracy Score: 0.993398543946
# K-Nearest Neighbour F-Measure: 0.98445991284
# K-Nearest Neighbour Sensitivity: 0.985543738922
# K-Nearest Neighbour Specificity: 0.995517706935
# K-Nearest Neighbour Precision: 0.983501777729
# K-Nearest Neighbour Area Under ROC Curve: 0.990530722928
# K-Nearest Neighbour Area Under Precision Recall Curve: 0.972319984519
# K-Nearest Neighbour MCC: 0.980319749123
#
# SelectKBest with f_classif 7 normalized results:
#
# K-Nearest Neighbour Accuracy Score: 0.993706940876
# K-Nearest Neighbour F-Measure: 0.985086637998
# K-Nearest Neighbour Sensitivity: 0.981221978939
# K-Nearest Neighbour Specificity: 0.997077161126
# K-Nearest Neighbour Precision: 0.989155665262
# K-Nearest Neighbour Area Under ROC Curve: 0.989149570032
# K-Nearest Neighbour Area Under Precision Recall Curve: 0.974525374825
# K-Nearest Neighbour MCC: 0.98118028929
#
# SelectKBest with chi2 7 unnormalized results:
#
# K-Nearest Neighbour Accuracy Score: 0.993398543946
# K-Nearest Neighbour F-Measure: 0.98445991284
# K-Nearest Neighbour Sensitivity: 0.985543738922
# K-Nearest Neighbour Specificity: 0.995517706935
# K-Nearest Neighbour Precision: 0.983501777729
# K-Nearest Neighbour Area Under ROC Curve: 0.990530722928
# K-Nearest Neighbour Area Under Precision Recall Curve: 0.972319984519
# K-Nearest Neighbour MCC: 0.980319749123
#
# SelectKBest with chi2 7 normalized results:
#
# K-Nearest Neighbour Accuracy Score: 0.993706940876
# K-Nearest Neighbour F-Measure: 0.985086637998
# K-Nearest Neighbour Sensitivity: 0.981221978939
# K-Nearest Neighbour Specificity: 0.997077161126
# K-Nearest Neighbour Precision: 0.989155665262
# K-Nearest Neighbour Area Under ROC Curve: 0.989149570032
# K-Nearest Neighbour Area Under Precision Recall Curve: 0.974525374825
# K-Nearest Neighbour MCC: 0.98118028929
#
# VarianceThreshold unnormalized results:
#
# Naive Bayes Accuracy Score: 0.9788093774
# Naive Bayes F-Measure: 0.952521719428
# Naive Bayes Sensitivity: 0.997101449275
# Naive Bayes Specificity: 0.973881797013
# Naive Bayes Precision: 0.912119800735
# Naive Bayes Area Under ROC Curve: 0.985491623144
# Naive Bayes Area Under Precision Recall Curve: 0.910104028771
# Naive Bayes MCC: 0.940630372536
#
# VarianceThreshold normalized results:
#
# Naive Bayes Accuracy Score: 0.989405865607
# Naive Bayes F-Measure: 0.975666131904
# Naive Bayes Sensitivity: 0.997826086957
# Naive Bayes Specificity: 0.987136399147
# Naive Bayes Precision: 0.954620247581
# Naive Bayes Area Under ROC Curve: 0.992481243052
# Naive Bayes Area Under Precision Recall Curve: 0.952988461982
# Naive Bayes MCC: 0.969353111156
#
# SelectKBest with f_classif 1 unnormalized results:
#
# Naive Bayes Accuracy Score: 0.977581204824
# Naive Bayes F-Measure: 0.949845455169
# Naive Bayes Sensitivity: 0.996376811594
# Naive Bayes Specificity: 0.972517653841
# Naive Bayes Precision: 0.9078079542
# Naive Bayes Area Under ROC Curve: 0.984447232717
# Naive Bayes Area Under Precision Recall Curve: 0.905297605635
# Naive Bayes MCC: 0.937291852803
#
# SelectKBest with f_classif 1 normalized results:
#
# Naive Bayes Accuracy Score: 0.977581204824
# Naive Bayes F-Measure: 0.949845455169
# Naive Bayes Sensitivity: 0.996376811594
# Naive Bayes Specificity: 0.972517653841
# Naive Bayes Precision: 0.9078079542
# Naive Bayes Area Under ROC Curve: 0.984447232717
# Naive Bayes Area Under Precision Recall Curve: 0.905297605635
# Naive Bayes MCC: 0.937291852803
#
# SelectKBest with chi2 1 unnormalized results:
#
# Naive Bayes Accuracy Score: 0.977581204824
# Naive Bayes F-Measure: 0.949845455169
# Naive Bayes Sensitivity: 0.996376811594
# Naive Bayes Specificity: 0.972517653841
# Naive Bayes Precision: 0.9078079542
# Naive Bayes Area Under ROC Curve: 0.984447232717
# Naive Bayes Area Under Precision Recall Curve: 0.905297605635
# Naive Bayes MCC: 0.937291852803
#
# SelectKBest with chi2 1 normalized results:
#
# Naive Bayes Accuracy Score: 0.977581204824
# Naive Bayes F-Measure: 0.949845455169
# Naive Bayes Sensitivity: 0.996376811594
# Naive Bayes Specificity: 0.972517653841
# Naive Bayes Precision: 0.9078079542
# Naive Bayes Area Under ROC Curve: 0.984447232717
# Naive Bayes Area Under Precision Recall Curve: 0.905297605635
# Naive Bayes MCC: 0.937291852803
#
# SelectKBest with f_classif 2 unnormalized results:
#
# Naive Bayes Accuracy Score: 0.981727258117
# Naive Bayes F-Measure: 0.958770701306
# Naive Bayes Sensitivity: 0.997101449275
# Naive Bayes Specificity: 0.977585121472
# Naive Bayes Precision: 0.923571420078
# Naive Bayes Area Under ROC Curve: 0.987343285374
# Naive Bayes Area Under Precision Recall Curve: 0.921511143583
# Naive Bayes MCC: 0.948336914248
#
# SelectKBest with f_classif 2 normalized results:
#
# Naive Bayes Accuracy Score: 0.981727258117
# Naive Bayes F-Measure: 0.958770701306
# Naive Bayes Sensitivity: 0.997101449275
# Naive Bayes Specificity: 0.977585121472
# Naive Bayes Precision: 0.923571420078
# Naive Bayes Area Under ROC Curve: 0.987343285374
# Naive Bayes Area Under Precision Recall Curve: 0.921511143583
# Naive Bayes MCC: 0.948336914248
#
# SelectKBest with chi2 2 unnormalized results:
#
# Naive Bayes Accuracy Score: 0.975892438352
# Naive Bayes F-Measure: 0.946249369171
# Naive Bayes Sensitivity: 0.996376811594
# Naive Bayes Specificity: 0.970373783573
# Naive Bayes Precision: 0.901232318591
# Naive Bayes Area Under ROC Curve: 0.983375297583
# Naive Bayes Area Under Precision Recall Curve: 0.898760960335
# Naive Bayes MCC: 0.932855876518
#
# SelectKBest with chi2 2 normalized results:
#
# Naive Bayes Accuracy Score: 0.981727258117
# Naive Bayes F-Measure: 0.958770701306
# Naive Bayes Sensitivity: 0.997101449275
# Naive Bayes Specificity: 0.977585121472
# Naive Bayes Precision: 0.923571420078
# Naive Bayes Area Under ROC Curve: 0.987343285374
# Naive Bayes Area Under Precision Recall Curve: 0.921511143583
# Naive Bayes MCC: 0.948336914248
#
# SelectKBest with f_classif 3 unnormalized results:
#
# Naive Bayes Accuracy Score: 0.978041563842
# Naive Bayes F-Measure: 0.950890243257
# Naive Bayes Sensitivity: 0.997101449275
# Naive Bayes Specificity: 0.972907138144
# Naive Bayes Precision: 0.909146439299
# Naive Bayes Area Under ROC Curve: 0.98500429371
# Naive Bayes Area Under Precision Recall Curve: 0.907143358172
# Naive Bayes MCC: 0.938620991197
#
# SelectKBest with f_classif 3 normalized results:
#
# Naive Bayes Accuracy Score: 0.978041563842
# Naive Bayes F-Measure: 0.950890243257
# Naive Bayes Sensitivity: 0.997101449275
# Naive Bayes Specificity: 0.972907138144
# Naive Bayes Precision: 0.909146439299
# Naive Bayes Area Under ROC Curve: 0.98500429371
# Naive Bayes Area Under Precision Recall Curve: 0.907143358172
# Naive Bayes MCC: 0.938620991197
#
# SelectKBest with chi2 3 unnormalized results:
#
# Naive Bayes Accuracy Score: 0.979270206893
# Naive Bayes F-Measure: 0.953516226651
# Naive Bayes Sensitivity: 0.997101449275
# Naive Bayes Specificity: 0.974466592335
# Naive Bayes Precision: 0.913958891482
# Naive Bayes Area Under ROC Curve: 0.985784020805
# Naive Bayes Area Under Precision Recall Curve: 0.911929792772
# Naive Bayes MCC: 0.941861394552
#
# SelectKBest with chi2 3 normalized results:
#
# Naive Bayes Accuracy Score: 0.989405865607
# Naive Bayes F-Measure: 0.975686297035
# Naive Bayes Sensitivity: 0.998550724638
# Naive Bayes Specificity: 0.986941467374
# Naive Bayes Precision: 0.953988740576
# Naive Bayes Area Under ROC Curve: 0.992746096006
# Naive Bayes Area Under Precision Recall Curve: 0.952907221983
# Naive Bayes MCC: 0.969393451809
#
# SelectKBest with f_classif 4 unnormalized results:
#
# Naive Bayes Accuracy Score: 0.989405865607
# Naive Bayes F-Measure: 0.975666131904
# Naive Bayes Sensitivity: 0.997826086957
# Naive Bayes Specificity: 0.987136399147
# Naive Bayes Precision: 0.954620247581
# Naive Bayes Area Under ROC Curve: 0.992481243052
# Naive Bayes Area Under Precision Recall Curve: 0.952988461982
# Naive Bayes MCC: 0.969353111156
#
# SelectKBest with f_classif 4 normalized results:
#
# Naive Bayes Accuracy Score: 0.989405865607
# Naive Bayes F-Measure: 0.975666131904
# Naive Bayes Sensitivity: 0.997826086957
# Naive Bayes Specificity: 0.987136399147
# Naive Bayes Precision: 0.954620247581
# Naive Bayes Area Under ROC Curve: 0.992481243052
# Naive Bayes Area Under Precision Recall Curve: 0.952988461982
# Naive Bayes MCC: 0.969353111156
#
# SelectKBest with chi2 4 unnormalized results:
#
# Naive Bayes Accuracy Score: 0.980959208962
# Naive Bayes F-Measure: 0.957135228878
# Naive Bayes Sensitivity: 0.997101449275
# Naive Bayes Specificity: 0.976610462603
# Naive Bayes Precision: 0.920594183587
# Naive Bayes Area Under ROC Curve: 0.986855955939
# Naive Bayes Area Under Precision Recall Curve: 0.918542801533
# Naive Bayes MCC: 0.946325088191
#
# SelectKBest with chi2 4 normalized results:
#
# Naive Bayes Accuracy Score: 0.989405865607
# Naive Bayes F-Measure: 0.975666131904
# Naive Bayes Sensitivity: 0.997826086957
# Naive Bayes Specificity: 0.987136399147
# Naive Bayes Precision: 0.954620247581
# Naive Bayes Area Under ROC Curve: 0.992481243052
# Naive Bayes Area Under Precision Recall Curve: 0.952988461982
# Naive Bayes MCC: 0.969353111156
#
# SelectKBest with f_classif 5 unnormalized results:
#
# Naive Bayes Accuracy Score: 0.989405865607
# Naive Bayes F-Measure: 0.975666131904
# Naive Bayes Sensitivity: 0.997826086957
# Naive Bayes Specificity: 0.987136399147
# Naive Bayes Precision: 0.954620247581
# Naive Bayes Area Under ROC Curve: 0.992481243052
# Naive Bayes Area Under Precision Recall Curve: 0.952988461982
# Naive Bayes MCC: 0.969353111156
#
# SelectKBest with f_classif 5 normalized results:
#
# Naive Bayes Accuracy Score: 0.989405865607
# Naive Bayes F-Measure: 0.975666131904
# Naive Bayes Sensitivity: 0.997826086957
# Naive Bayes Specificity: 0.987136399147
# Naive Bayes Precision: 0.954620247581
# Naive Bayes Area Under ROC Curve: 0.992481243052
# Naive Bayes Area Under Precision Recall Curve: 0.952988461982
# Naive Bayes MCC: 0.969353111156
#
# SelectKBest with chi2 5 unnormalized results:
#
# Naive Bayes Accuracy Score: 0.981727258117
# Naive Bayes F-Measure: 0.958770701306
# Naive Bayes Sensitivity: 0.997101449275
# Naive Bayes Specificity: 0.977585121472
# Naive Bayes Precision: 0.923571420078
# Naive Bayes Area Under ROC Curve: 0.987343285374
# Naive Bayes Area Under Precision Recall Curve: 0.921511143583
# Naive Bayes MCC: 0.948336914248
#
# SelectKBest with chi2 5 normalized results:
#
# Naive Bayes Accuracy Score: 0.989405865607
# Naive Bayes F-Measure: 0.975666131904
# Naive Bayes Sensitivity: 0.997826086957
# Naive Bayes Specificity: 0.987136399147
# Naive Bayes Precision: 0.954620247581
# Naive Bayes Area Under ROC Curve: 0.992481243052
# Naive Bayes Area Under Precision Recall Curve: 0.952988461982
# Naive Bayes MCC: 0.969353111156
#
# SelectKBest with f_classif 6 unnormalized results:
#
# Naive Bayes Accuracy Score: 0.989405865607
# Naive Bayes F-Measure: 0.975666131904
# Naive Bayes Sensitivity: 0.997826086957
# Naive Bayes Specificity: 0.987136399147
# Naive Bayes Precision: 0.954620247581
# Naive Bayes Area Under ROC Curve: 0.992481243052
# Naive Bayes Area Under Precision Recall Curve: 0.952988461982
# Naive Bayes MCC: 0.969353111156
#
# SelectKBest with f_classif 6 normalized results:
#
# Naive Bayes Accuracy Score: 0.989405865607
# Naive Bayes F-Measure: 0.975666131904
# Naive Bayes Sensitivity: 0.997826086957
# Naive Bayes Specificity: 0.987136399147
# Naive Bayes Precision: 0.954620247581
# Naive Bayes Area Under ROC Curve: 0.992481243052
# Naive Bayes Area Under Precision Recall Curve: 0.952988461982
# Naive Bayes MCC: 0.969353111156
#
# SelectKBest with chi2 7 unnormalized results:
#
# Naive Bayes Accuracy Score: 0.9788093774
# Naive Bayes F-Measure: 0.952521719428
# Naive Bayes Sensitivity: 0.997101449275
# Naive Bayes Specificity: 0.973881797013
# Naive Bayes Precision: 0.912119800735
# Naive Bayes Area Under ROC Curve: 0.985491623144
# Naive Bayes Area Under Precision Recall Curve: 0.910104028771
# Naive Bayes MCC: 0.940630372536
#
# SelectKBest with chi2 7 normalized results:
#
# Naive Bayes Accuracy Score: 0.989405865607
# Naive Bayes F-Measure: 0.975666131904
# Naive Bayes Sensitivity: 0.997826086957
# Naive Bayes Specificity: 0.987136399147
# Naive Bayes Precision: 0.954620247581
# Naive Bayes Area Under ROC Curve: 0.992481243052
# Naive Bayes Area Under Precision Recall Curve: 0.952988461982
# Naive Bayes MCC: 0.969353111156
#
# SelectKBest with f_classif 7 unnormalized results:
#
# Naive Bayes Accuracy Score: 0.9788093774
# Naive Bayes F-Measure: 0.952521719428
# Naive Bayes Sensitivity: 0.997101449275
# Naive Bayes Specificity: 0.973881797013
# Naive Bayes Precision: 0.912119800735
# Naive Bayes Area Under ROC Curve: 0.985491623144
# Naive Bayes Area Under Precision Recall Curve: 0.910104028771
# Naive Bayes MCC: 0.940630372536
#
# SelectKBest with f_classif 7 normalized results:
#
# Naive Bayes Accuracy Score: 0.989405865607
# Naive Bayes F-Measure: 0.975666131904
# Naive Bayes Sensitivity: 0.997826086957
# Naive Bayes Specificity: 0.987136399147
# Naive Bayes Precision: 0.954620247581
# Naive Bayes Area Under ROC Curve: 0.992481243052
# Naive Bayes Area Under Precision Recall Curve: 0.952988461982
# Naive Bayes MCC: 0.969353111156
#
# SelectKBest with chi2 7 unnormalized results:
#
# Naive Bayes Accuracy Score: 0.9788093774
# Naive Bayes F-Measure: 0.952521719428
# Naive Bayes Sensitivity: 0.997101449275
# Naive Bayes Specificity: 0.973881797013
# Naive Bayes Precision: 0.912119800735
# Naive Bayes Area Under ROC Curve: 0.985491623144
# Naive Bayes Area Under Precision Recall Curve: 0.910104028771
# Naive Bayes MCC: 0.940630372536
#
# SelectKBest with chi2 7 normalized results:
#
# Naive Bayes Accuracy Score: 0.989405865607
# Naive Bayes F-Measure: 0.975666131904
# Naive Bayes Sensitivity: 0.997826086957
# Naive Bayes Specificity: 0.987136399147
# Naive Bayes Precision: 0.954620247581
# Naive Bayes Area Under ROC Curve: 0.992481243052
# Naive Bayes Area Under Precision Recall Curve: 0.952988461982
# Naive Bayes MCC: 0.969353111156
#
# VarianceThreshold unnormalized results:
#
# Decision Tree Accuracy Score: 0.991249419899
# Decision Tree F-Measure: 0.979375261706
# Decision Tree Sensitivity: 0.979777916797
# Decision Tree Specificity: 0.994348116292
# Decision Tree Precision: 0.979241945317
# Decision Tree Area Under ROC Curve: 0.987063016544
# Decision Tree Area Under Precision Recall Curve: 0.963669231603
# Decision Tree MCC: 0.973930345142
#
# VarianceThreshold normalized results:
#
# Decision Tree Accuracy Score: 0.991095810068
# Decision Tree F-Measure: 0.979009158276
# Decision Tree Sensitivity: 0.979053279116
# Decision Tree Specificity: 0.994348116292
# Decision Tree Precision: 0.979216972787
# Decision Tree Area Under ROC Curve: 0.986700697704
# Decision Tree Area Under Precision Recall Curve: 0.963099108555
# Decision Tree MCC: 0.97345996652
#
# SelectKBest with f_classif 1 unnormalized results:
#
# Decision Tree Accuracy Score: 0.983573165502
# Decision Tree F-Measure: 0.961737659569
# Decision Tree Sensitivity: 0.970362840163
# Decision Tree Specificity: 0.987136399147
# Decision Tree Precision: 0.953456855347
# Decision Tree Area Under ROC Curve: 0.978749619655
# Decision Tree Area Under Precision Recall Curve: 0.931517170342
# Decision Tree MCC: 0.95142007348
#
# SelectKBest with f_classif 1 normalized results:
#
# Decision Tree Accuracy Score: 0.983573165502
# Decision Tree F-Measure: 0.961737659569
# Decision Tree Sensitivity: 0.970362840163
# Decision Tree Specificity: 0.987136399147
# Decision Tree Precision: 0.953456855347
# Decision Tree Area Under ROC Curve: 0.978749619655
# Decision Tree Area Under Precision Recall Curve: 0.931517170342
# Decision Tree MCC: 0.95142007348
#
# SelectKBest with chi2 1 unnormalized results:
#
# Decision Tree Accuracy Score: 0.983573165502
# Decision Tree F-Measure: 0.961737659569
# Decision Tree Sensitivity: 0.970362840163
# Decision Tree Specificity: 0.987136399147
# Decision Tree Precision: 0.953456855347
# Decision Tree Area Under ROC Curve: 0.978749619655
# Decision Tree Area Under Precision Recall Curve: 0.931517170342
# Decision Tree MCC: 0.95142007348
#
# SelectKBest with chi2 1 normalized results:
#
# Decision Tree Accuracy Score: 0.983573165502
# Decision Tree F-Measure: 0.961737659569
# Decision Tree Sensitivity: 0.970362840163
# Decision Tree Specificity: 0.987136399147
# Decision Tree Precision: 0.953456855347
# Decision Tree Area Under ROC Curve: 0.978749619655
# Decision Tree Area Under Precision Recall Curve: 0.931517170342
# Decision Tree MCC: 0.95142007348
#
# SelectKBest with f_classif 2 unnormalized results:
# Decision Tree Accuracy Score: 0.984339802513
# Decision Tree F-Measure: 0.963083038821
# Decision Tree Sensitivity: 0.962397038891
# Decision Tree Specificity: 0.99025454904
# Decision Tree Precision: 0.963865226224
# Decision Tree Area Under ROC Curve: 0.976325793965
# Decision Tree Area Under Precision Recall Curve: 0.935786876693
# Decision Tree MCC: 0.953183794563
#
# SelectKBest with f_classif 2 normalized results:
#
# Decision Tree Accuracy Score: 0.984339802513
# Decision Tree F-Measure: 0.963083038821
# Decision Tree Sensitivity: 0.962397038891
# Decision Tree Specificity: 0.99025454904
# Decision Tree Precision: 0.963865226224
# Decision Tree Area Under ROC Curve: 0.976325793965
# Decision Tree Area Under Precision Recall Curve: 0.935786876693
# Decision Tree MCC: 0.953183794563
#
# SelectKBest with chi2 2 unnormalized results:
#
# Decision Tree Accuracy Score: 0.991556167643
# Decision Tree F-Measure: 0.980161580238
# Decision Tree Sensitivity: 0.983375039099
# Decision Tree Specificity: 0.99376332097
# Decision Tree Precision: 0.977075339411
# Decision Tree Area Under ROC Curve: 0.988569180035
# Decision Tree Area Under Precision Recall Curve: 0.964384259968
# Decision Tree MCC: 0.974849994652
#
# SelectKBest with chi2 2 normalized results:
#
# Decision Tree Accuracy Score: 0.984339802513
# Decision Tree F-Measure: 0.963083038821
# Decision Tree Sensitivity: 0.962397038891
# Decision Tree Specificity: 0.99025454904
# Decision Tree Precision: 0.963865226224
# Decision Tree Area Under ROC Curve: 0.976325793965
# Decision Tree Area Under Precision Recall Curve: 0.935786876693
# Decision Tree MCC: 0.953183794563
#
# SelectKBest with f_classif 3 unnormalized results:
#
# Decision Tree Accuracy Score: 0.991095102552
# Decision Tree F-Measure: 0.978949749052
# Decision Tree Sensitivity: 0.976139088729
# Decision Tree Specificity: 0.995127464142
# Decision Tree Precision: 0.981921099169
# Decision Tree Area Under ROC Curve: 0.985633276436
# Decision Tree Area Under Precision Recall Curve: 0.963605607955
# Decision Tree MCC: 0.973367463857
#
# SelectKBest with f_classif 3 normalized results:
#
# Decision Tree Accuracy Score: 0.990941492721
# Decision Tree F-Measure: 0.978575752221
# Decision Tree Sensitivity: 0.975414451048
# Decision Tree Specificity: 0.995127464142
# Decision Tree Precision: 0.981890266692
# Decision Tree Area Under ROC Curve: 0.985270957595
# Decision Tree Area Under Precision Recall Curve: 0.963035920647
# Decision Tree MCC: 0.972893818197
#
# SelectKBest with chi2 3 unnormalized results:
#
# Decision Tree Accuracy Score: 0.993704587062
# Decision Tree F-Measure: 0.98513992865
# Decision Tree Sensitivity: 0.984803461579
# Decision Tree Specificity: 0.996102123012
# Decision Tree Precision: 0.985582046666
# Decision Tree Area Under ROC Curve: 0.990452792295
# Decision Tree Area Under Precision Recall Curve: 0.97383173302
# Decision Tree MCC: 0.981188827938
#
# SelectKBest with chi2 3 normalized results:
#
# Decision Tree Accuracy Score: 0.985721820518
# Decision Tree F-Measure: 0.966309126118
# Decision Tree Sensitivity: 0.964576165155
# Decision Tree Specificity: 0.991423760439
# Decision Tree Precision: 0.968151200733
# Decision Tree Area Under ROC Curve: 0.977999962797
# Decision Tree Area Under Precision Recall Curve: 0.941562319991
# Decision Tree MCC: 0.957294468627
#
# SelectKBest with f_classif 4 unnormalized results:
#
# Decision Tree Accuracy Score: 0.990942434391
# Decision Tree F-Measure: 0.978506040596
# Decision Tree Sensitivity: 0.972531539985
# Decision Tree Specificity: 0.995907191238
# Decision Tree Precision: 0.984760995813
# Decision Tree Area Under ROC Curve: 0.984219365612
# Decision Tree Area Under Precision Recall Curve: 0.963528341062
# Decision Tree MCC: 0.972880681187
#
# SelectKBest with f_classif 4 normalized results:
#
# Decision Tree Accuracy Score: 0.99078882456
# Decision Tree F-Measure: 0.978131949663
# Decision Tree Sensitivity: 0.971806902304
# Decision Tree Specificity: 0.995907191238
# Decision Tree Precision: 0.984734929709
# Decision Tree Area Under ROC Curve: 0.983857046771
# Decision Tree Area Under Precision Recall Curve: 0.962958257635
# Decision Tree MCC: 0.972408957575
#
# SelectKBest with chi2 4 unnormalized results:
#
# Decision Tree Accuracy Score: 0.992783634147
# Decision Tree F-Measure: 0.983021027858
# Decision Tree Sensitivity: 0.984803461579
# Decision Tree Specificity: 0.994932911613
# Decision Tree Precision: 0.981337798613
# Decision Tree Area Under ROC Curve: 0.989868186596
# Decision Tree Area Under Precision Recall Curve: 0.969680093359
# Decision Tree MCC: 0.97847925188
#
# SelectKBest with chi2 4 normalized results:
#
# Decision Tree Accuracy Score: 0.99078882456
# Decision Tree F-Measure: 0.978131949663
# Decision Tree Sensitivity: 0.971806902304
# Decision Tree Specificity: 0.995907191238
# Decision Tree Precision: 0.984734929709
# Decision Tree Area Under ROC Curve: 0.983857046771
# Decision Tree Area Under Precision Recall Curve: 0.962958257635
# Decision Tree MCC: 0.972408957575
#
# SelectKBest with f_classif 5 unnormalized results:
#
# Decision Tree Accuracy Score: 0.991403028287
# Decision Tree F-Measure: 0.979730275599
# Decision Tree Sensitivity: 0.977598790533
# Decision Tree Specificity: 0.995127464142
# Decision Tree Precision: 0.981985462236
# Decision Tree Area Under ROC Curve: 0.986363127338
# Decision Tree Area Under Precision Recall Curve: 0.964744590022
# Decision Tree MCC: 0.974324710928
#
# SelectKBest with f_classif 5 normalized results:
#
# Decision Tree Accuracy Score: 0.991403028287
# Decision Tree F-Measure: 0.979730275599
# Decision Tree Sensitivity: 0.977598790533
# Decision Tree Specificity: 0.995127464142
# Decision Tree Precision: 0.981985462236
# Decision Tree Area Under ROC Curve: 0.986363127338
# Decision Tree Area Under Precision Recall Curve: 0.964744590022
# Decision Tree MCC: 0.974324710928
#
# SelectKBest with chi2 5 unnormalized results:
#
# Decision Tree Accuracy Score: 0.992937009102
# Decision Tree F-Measure: 0.983441736067
# Decision Tree Sensitivity: 0.986977374622
# Decision Tree Specificity: 0.994542668821
# Decision Tree Precision: 0.980046587378
# Decision Tree Area Under ROC Curve: 0.990760021721
# Decision Tree Area Under Precision Recall Curve: 0.970042490005
# Decision Tree MCC: 0.979009882454
#
# SelectKBest with chi2 5 normalized results:
#
# Decision Tree Accuracy Score: 0.991403028287
# Decision Tree F-Measure: 0.979730275599
# Decision Tree Sensitivity: 0.977598790533
# Decision Tree Specificity: 0.995127464142
# Decision Tree Precision: 0.981985462236
# Decision Tree Area Under ROC Curve: 0.986363127338
# Decision Tree Area Under Precision Recall Curve: 0.964744590022
# Decision Tree MCC: 0.974324710928
#
# SelectKBest with f_classif 6 unnormalized results:
#
# Decision Tree Accuracy Score: 0.990482782166
# ...
# Linear Discriminant Analysis Sensitivity: 0.998550724638
# Linear Discriminant Analysis Specificity: 0.986161740278
# Linear Discriminant Analysis Precision: 0.951343714701
# Linear Discriminant Analysis Area Under ROC Curve: 0.992356232458
# Linear Discriminant Analysis Area Under Precision Recall Curve: 0.950271511179
# Linear Discriminant Analysis MCC: 0.96766639464
#
# SelectKBest with f_classif 7 unnormalized results:
#
# Linear Discriminant Analysis Accuracy Score: 0.988791897479
# Linear Discriminant Analysis F-Measure: 0.974307691132
# Linear Discriminant Analysis Sensitivity: 0.998550724638
# Linear Discriminant Analysis Specificity: 0.986161740278
# Linear Discriminant Analysis Precision: 0.951343714701
# Linear Discriminant Analysis Area Under ROC Curve: 0.992356232458
# Linear Discriminant Analysis Area Under Precision Recall Curve: 0.950271511179
# Linear Discriminant Analysis MCC: 0.96766639464
#
# SelectKBest with f_classif 7 normalized results:
#
# Linear Discriminant Analysis Accuracy Score: 0.988791897479
# Linear Discriminant Analysis F-Measure: 0.974307691132
# Linear Discriminant Analysis Sensitivity: 0.998550724638
# Linear Discriminant Analysis Specificity: 0.986161740278
# Linear Discriminant Analysis Precision: 0.951343714701
# Linear Discriminant Analysis Area Under ROC Curve: 0.992356232458
# Linear Discriminant Analysis Area Under Precision Recall Curve: 0.950271511179
# Linear Discriminant Analysis MCC: 0.96766639464
#
# SelectKBest with chi2 7 unnormalized results:
#
# Linear Discriminant Analysis Accuracy Score: 0.988791897479
# Linear Discriminant Analysis F-Measure: 0.974307691132
# Linear Discriminant Analysis Sensitivity: 0.998550724638
# Linear Discriminant Analysis Specificity: 0.986161740278
# Linear Discriminant Analysis Precision: 0.951343714701
# Linear Discriminant Analysis Area Under ROC Curve: 0.992356232458
# Linear Discriminant Analysis Area Under Precision Recall Curve: 0.950271511179
# Linear Discriminant Analysis MCC: 0.96766639464
#
# SelectKBest with chi2 7 normalized results:
#
# Linear Discriminant Analysis Accuracy Score: 0.988791897479
# Linear Discriminant Analysis F-Measure: 0.974307691132
# Linear Discriminant Analysis Sensitivity: 0.998550724638
# Linear Discriminant Analysis Specificity: 0.986161740278
# Linear Discriminant Analysis Precision: 0.951343714701
# Linear Discriminant Analysis Area Under ROC Curve: 0.992356232458
# Linear Discriminant Analysis Area Under Precision Recall Curve: 0.950271511179
# Linear Discriminant Analysis MCC: 0.96766639464
#
# VarianceThreshold unnormalized results:
#
# AdaBoostClassifier Accuracy Score: 0.990941021526
# AdaBoostClassifier F-Measure: 0.979023886831
# AdaBoostClassifier Sensitivity: 0.992044625169
# AdaBoostClassifier Specificity: 0.990645171077
# AdaBoostClassifier Precision: 0.966554368179
# AdaBoostClassifier Area Under ROC Curve: 0.991344898123
# AdaBoostClassifier Area Under Precision Recall Curve: 0.960527205399
# AdaBoostClassifier MCC: 0.973473086519
#
# VarianceThreshold normalized results:
#
# AdaBoostClassifier Accuracy Score: 0.990941021526
# AdaBoostClassifier F-Measure: 0.979023886831
# AdaBoostClassifier Sensitivity: 0.992044625169
# AdaBoostClassifier Specificity: 0.990645171077
# AdaBoostClassifier Precision: 0.966554368179
# AdaBoostClassifier Area Under ROC Curve: 0.991344898123
# AdaBoostClassifier Area Under Precision Recall Curve: 0.960527205399
# AdaBoostClassifier MCC: 0.973473086519
#
# SelectKBest with f_classif 1 unnormalized results:
#
# AdaBoostClassifier Accuracy Score: 0.988023848324
# AdaBoostClassifier F-Measure: 0.972472650529
# AdaBoostClassifier Sensitivity: 0.994208111771
# AdaBoostClassifier Specificity: 0.986356672052
# AdaBoostClassifier Precision: 0.951857229371
# AdaBoostClassifier Area Under ROC Curve: 0.990282391912
# AdaBoostClassifier Area Under Precision Recall Curve: 0.947531957021
# AdaBoostClassifier MCC: 0.965280719743
#
# SelectKBest with f_classif 1 normalized results:
#
# AdaBoostClassifier Accuracy Score: 0.988023848324
# AdaBoostClassifier F-Measure: 0.972472650529
# AdaBoostClassifier Sensitivity: 0.994208111771
# AdaBoostClassifier Specificity: 0.986356672052
# AdaBoostClassifier Precision: 0.951857229371
# AdaBoostClassifier Area Under ROC Curve: 0.990282391912
# AdaBoostClassifier Area Under Precision Recall Curve: 0.947531957021
# AdaBoostClassifier MCC: 0.965280719743
#
# SelectKBest with chi2 1 unnormalized results:
#
# AdaBoostClassifier Accuracy Score: 0.988023848324
# AdaBoostClassifier F-Measure: 0.972472650529
# AdaBoostClassifier Sensitivity: 0.994208111771
# AdaBoostClassifier Specificity: 0.986356672052
# AdaBoostClassifier Precision: 0.951857229371
# AdaBoostClassifier Area Under ROC Curve: 0.990282391912
# AdaBoostClassifier Area Under Precision Recall Curve: 0.947531957021
# AdaBoostClassifier MCC: 0.965280719743
#
# SelectKBest with chi2 1 normalized results:
#
# AdaBoostClassifier Accuracy Score: 0.988023848324
# AdaBoostClassifier F-Measure: 0.972472650529
# AdaBoostClassifier Sensitivity: 0.994208111771
# AdaBoostClassifier Specificity: 0.986356672052
# AdaBoostClassifier Precision: 0.951857229371
# AdaBoostClassifier Area Under ROC Curve: 0.990282391912
# AdaBoostClassifier Area Under Precision Recall Curve: 0.947531957021
# AdaBoostClassifier MCC: 0.965280719743
#
# SelectKBest with f_classif 2 unnormalized results:
#
# AdaBoostClassifier Accuracy Score: 0.988791661881
# AdaBoostClassifier F-Measure: 0.974172455106
# AdaBoostClassifier Sensitivity: 0.99348347409
# AdaBoostClassifier Specificity: 0.987526262695
# AdaBoostClassifier Precision: 0.955756360945
# AdaBoostClassifier Area Under ROC Curve: 0.990504868393
# AdaBoostClassifier Area Under Precision Recall Curve: 0.950889935275
# AdaBoostClassifier MCC: 0.967382879858
#
# SelectKBest with f_classif 2 normalized results:
#
# AdaBoostClassifier Accuracy Score: 0.988791661881
# AdaBoostClassifier F-Measure: 0.974172455106
# AdaBoostClassifier Sensitivity: 0.99348347409
# AdaBoostClassifier Specificity: 0.987526262695
# AdaBoostClassifier Precision: 0.955756360945
# AdaBoostClassifier Area Under ROC Curve: 0.990504868393
# AdaBoostClassifier Area Under Precision Recall Curve: 0.950889935275
# AdaBoostClassifier MCC: 0.967382879858
#
# SelectKBest with chi2 2 unnormalized results:
#
# AdaBoostClassifier Accuracy Score: 0.985414365258
# AdaBoostClassifier F-Measure: 0.96610597536
# AdaBoostClassifier Sensitivity: 0.979032426233
# AdaBoostClassifier Specificity: 0.987136399147
# AdaBoostClassifier Precision: 0.953796418902
# AdaBoostClassifier Area Under ROC Curve: 0.98308441269
# AdaBoostClassifier Area Under Precision Recall Curve: 0.938239498091
# AdaBoostClassifier MCC: 0.957067328381
#
# SelectKBest with chi2 2 normalized results:
#
# AdaBoostClassifier Accuracy Score: 0.988791661881
# AdaBoostClassifier F-Measure: 0.974172455106
# AdaBoostClassifier Sensitivity: 0.99348347409
# AdaBoostClassifier Specificity: 0.987526262695
# AdaBoostClassifier Precision: 0.955756360945
# AdaBoostClassifier Area Under ROC Curve: 0.990504868393
# AdaBoostClassifier Area Under Precision Recall Curve: 0.950889935275
# AdaBoostClassifier MCC: 0.967382879858
#
# SelectKBest with f_classif 3 unnormalized results:
#
# AdaBoostClassifier Accuracy Score: 0.988945271712
# AdaBoostClassifier F-Measure: 0.97444645613
# AdaBoostClassifier Sensitivity: 0.990590136586
# AdaBoostClassifier Specificity: 0.988500921565
# AdaBoostClassifier Precision: 0.959068869257
# AdaBoostClassifier Area Under ROC Curve: 0.989545529075
# AdaBoostClassifier Area Under Precision Recall Curve: 0.951977835068
# AdaBoostClassifier MCC: 0.967708165795
#
# SelectKBest with f_classif 3 normalized results:
#
# AdaBoostClassifier Accuracy Score: 0.988945271712
# AdaBoostClassifier F-Measure: 0.97444645613
# AdaBoostClassifier Sensitivity: 0.990590136586
# AdaBoostClassifier Specificity: 0.988500921565
# AdaBoostClassifier Precision: 0.959068869257
# AdaBoostClassifier Area Under ROC Curve: 0.989545529075
# AdaBoostClassifier Area Under Precision Recall Curve: 0.951977835068
# AdaBoostClassifier MCC: 0.967708165795
#
# SelectKBest with chi2 3 unnormalized results:
#
# AdaBoostClassifier Accuracy Score: 0.987102424935
# AdaBoostClassifier F-Measure: 0.970020612393
# AdaBoostClassifier Sensitivity: 0.982629548535
# AdaBoostClassifier Specificity: 0.988305989791
# AdaBoostClassifier Precision: 0.957968162301
# AdaBoostClassifier Area Under ROC Curve: 0.985467769163
# AdaBoostClassifier Area Under Precision Recall Curve: 0.945009774207
# AdaBoostClassifier MCC: 0.962032704718
#
# SelectKBest with chi2 3 normalized results:
#
# AdaBoostClassifier Accuracy Score: 0.988791661881
# AdaBoostClassifier F-Measure: 0.974172455106
# AdaBoostClassifier Sensitivity: 0.99348347409
# AdaBoostClassifier Specificity: 0.987526262695
# AdaBoostClassifier Precision: 0.955756360945
# AdaBoostClassifier Area Under ROC Curve: 0.990504868393
# AdaBoostClassifier Area Under Precision Recall Curve: 0.950889935275
# AdaBoostClassifier MCC: 0.967382879858
#
# SelectKBest with f_classif 4 unnormalized results:
#
# AdaBoostClassifier Accuracy Score: 0.988945271712
# AdaBoostClassifier F-Measure: 0.97444645613
# AdaBoostClassifier Sensitivity: 0.990590136586
# AdaBoostClassifier Specificity: 0.988500921565
# AdaBoostClassifier Precision: 0.959068869257
# AdaBoostClassifier Area Under ROC Curve: 0.989545529075
# AdaBoostClassifier Area Under Precision Recall Curve: 0.951977835068
# AdaBoostClassifier MCC: 0.967708165795
#
# SelectKBest with f_classif 4 normalized results:
#
# AdaBoostClassifier Accuracy Score: 0.988945271712
# AdaBoostClassifier F-Measure: 0.97444645613
# AdaBoostClassifier Sensitivity: 0.990590136586
# AdaBoostClassifier Specificity: 0.988500921565
# AdaBoostClassifier Precision: 0.959068869257
# AdaBoostClassifier Area Under ROC Curve: 0.989545529075
# AdaBoostClassifier Area Under Precision Recall Curve: 0.951977835068
# AdaBoostClassifier MCC: 0.967708165795
#
# SelectKBest with chi2 4 unnormalized results:
#
# AdaBoostClassifier Accuracy Score: 0.987102424935
# AdaBoostClassifier F-Measure: 0.970020612393
# AdaBoostClassifier Sensitivity: 0.982629548535
# AdaBoostClassifier Specificity: 0.988305989791
# AdaBoostClassifier Precision: 0.957968162301
# AdaBoostClassifier Area Under ROC Curve: 0.985467769163
# AdaBoostClassifier Area Under Precision Recall Curve: 0.945009774207
# AdaBoostClassifier MCC: 0.962032704718
#
# SelectKBest with chi2 4 normalized results:
#
# AdaBoostClassifier Accuracy Score: 0.988945271712
# AdaBoostClassifier F-Measure: 0.97444645613
# AdaBoostClassifier Sensitivity: 0.990590136586
# AdaBoostClassifier Specificity: 0.988500921565
# AdaBoostClassifier Precision: 0.959068869257
# AdaBoostClassifier Area Under ROC Curve: 0.989545529075
# AdaBoostClassifier Area Under Precision Recall Curve: 0.951977835068
# AdaBoostClassifier MCC: 0.967708165795
#
# SelectKBest with f_classif 5 unnormalized results:
#
# AdaBoostClassifier Accuracy Score: 0.988791661881
# AdaBoostClassifier F-Measure: 0.974103176287
# AdaBoostClassifier Sensitivity: 0.990590136586
# AdaBoostClassifier Specificity: 0.988305989791
# AdaBoostClassifier Precision: 0.958413132234
# AdaBoostClassifier Area Under ROC Curve: 0.989448063189
# AdaBoostClassifier Area Under Precision Recall Curve: 0.951326849763
# AdaBoostClassifier MCC: 0.967278686257
#
# SelectKBest with f_classif 5 normalized results:
#
# AdaBoostClassifier Accuracy Score: 0.988791661881
# AdaBoostClassifier F-Measure: 0.974103176287
# AdaBoostClassifier Sensitivity: 0.990590136586
# AdaBoostClassifier Specificity: 0.988305989791
# AdaBoostClassifier Precision: 0.958413132234
# AdaBoostClassifier Area Under ROC Curve: 0.989448063189
# AdaBoostClassifier Area Under Precision Recall Curve: 0.951326849763
# AdaBoostClassifier MCC: 0.967278686257
#
# SelectKBest with chi2 5 unnormalized results:
#
# AdaBoostClassifier Accuracy Score: 0.988484677817
# AdaBoostClassifier F-Measure: 0.97334815995
# AdaBoostClassifier Sensitivity: 0.989135648003
# AdaBoostClassifier Specificity: 0.988305989791
# AdaBoostClassifier Precision: 0.958328174255
# AdaBoostClassifier Area Under ROC Curve: 0.988720818897
# AdaBoostClassifier Area Under Precision Recall Curve: 0.950179409893
# AdaBoostClassifier MCC: 0.966318734912
#
# SelectKBest with chi2 5 normalized results:
#
# AdaBoostClassifier Accuracy Score: 0.988791661881
# AdaBoostClassifier F-Measure: 0.974103176287
# AdaBoostClassifier Sensitivity: 0.990590136586
# AdaBoostClassifier Specificity: 0.988305989791
# AdaBoostClassifier Precision: 0.958413132234
# AdaBoostClassifier Area Under ROC Curve: 0.989448063189
# AdaBoostClassifier Area Under Precision Recall Curve: 0.951326849763
# AdaBoostClassifier MCC: 0.967278686257
#
# SelectKBest with f_classif 6 unnormalized results:
#
# AdaBoostClassifier Accuracy Score: 0.988791661881
# AdaBoostClassifier F-Measure: 0.974101584023
# AdaBoostClassifier Sensitivity: 0.991309561047
# AdaBoostClassifier Specificity: 0.988111058017
# AdaBoostClassifier Precision: 0.957665440941
# AdaBoostClassifier Area Under ROC Curve: 0.989710309532
# AdaBoostClassifier Area Under Precision Recall Curve: 0.9511552088
# AdaBoostClassifier MCC: 0.967266630833
#
# SelectKBest with f_classif 6 normalized results:
#
# AdaBoostClassifier Accuracy Score: 0.988791661881
# AdaBoostClassifier F-Measure: 0.974101584023
# AdaBoostClassifier Sensitivity: 0.991309561047
# AdaBoostClassifier Specificity: 0.988111058017
# AdaBoostClassifier Precision: 0.957665440941
# AdaBoostClassifier Area Under ROC Curve: 0.989710309532
# AdaBoostClassifier Area Under Precision Recall Curve: 0.9511552088
# AdaBoostClassifier MCC: 0.967266630833
#
# SelectKBest with chi2 7 unnormalized results:
#
# AdaBoostClassifier Accuracy Score: 0.990633801864
# AdaBoostClassifier F-Measure: 0.97830203946
# AdaBoostClassifier Sensitivity: 0.991319987488
# AdaBoostClassifier Specificity: 0.990450239303
# AdaBoostClassifier Precision: 0.96582587332
# AdaBoostClassifier Area Under ROC Curve: 0.990885113396
# AdaBoostClassifier Area Under Precision Recall Curve: 0.959268933015
# AdaBoostClassifier MCC: 0.97255222215
#
# SelectKBest with chi2 7 normalized results:
#
# AdaBoostClassifier Accuracy Score: 0.988791661881
# AdaBoostClassifier F-Measure: 0.974101584023
# AdaBoostClassifier Sensitivity: 0.991309561047
# AdaBoostClassifier Specificity: 0.988111058017
# AdaBoostClassifier Precision: 0.957665440941
# AdaBoostClassifier Area Under ROC Curve: 0.989710309532
# AdaBoostClassifier Area Under Precision Recall Curve: 0.9511552088
# AdaBoostClassifier MCC: 0.967266630833
#
# SelectKBest with f_classif 7 unnormalized results:
#
# AdaBoostClassifier Accuracy Score: 0.990941021526
# AdaBoostClassifier F-Measure: 0.979023886831
# AdaBoostClassifier Sensitivity: 0.992044625169
# AdaBoostClassifier Specificity: 0.990645171077
# AdaBoostClassifier Precision: 0.966554368179
# AdaBoostClassifier Area Under ROC Curve: 0.991344898123
# AdaBoostClassifier Area Under Precision Recall Curve: 0.960527205399
# AdaBoostClassifier MCC: 0.973473086519
#
# SelectKBest with f_classif 7 normalized results:
#
# AdaBoostClassifier Accuracy Score: 0.990941021526
# AdaBoostClassifier F-Measure: 0.979023886831
# AdaBoostClassifier Sensitivity: 0.992044625169
# AdaBoostClassifier Specificity: 0.990645171077
# AdaBoostClassifier Precision: 0.966554368179
# AdaBoostClassifier Area Under ROC Curve: 0.991344898123
# AdaBoostClassifier Area Under Precision Recall Curve: 0.960527205399
# AdaBoostClassifier MCC: 0.973473086519
#
# SelectKBest with chi2 7 unnormalized results:
#
# AdaBoostClassifier Accuracy Score: 0.990941021526
# AdaBoostClassifier F-Measure: 0.979023886831
# AdaBoostClassifier Sensitivity: 0.992044625169
# AdaBoostClassifier Specificity: 0.990645171077
# AdaBoostClassifier Precision: 0.966554368179
# AdaBoostClassifier Area Under ROC Curve: 0.991344898123
# AdaBoostClassifier Area Under Precision Recall Curve: 0.960527205399
# AdaBoostClassifier MCC: 0.973473086519
#
# SelectKBest with chi2 7 normalized results:
#
# AdaBoostClassifier Accuracy Score: 0.990941021526
# AdaBoostClassifier F-Measure: 0.979023886831
# AdaBoostClassifier Sensitivity: 0.992044625169
# AdaBoostClassifier Specificity: 0.990645171077
# AdaBoostClassifier Precision: 0.966554368179
# AdaBoostClassifier Area Under ROC Curve: 0.991344898123
# AdaBoostClassifier Area Under Precision Recall Curve: 0.960527205399
# AdaBoostClassifier MCC: 0.973473086519
#
# Yes, I did get improvement when I performed feature selection.
# SelectKBest that uses chi2 with 4 features gave the best accuracy.

# %% [markdown]
# ### 7. Choose the version of train set 2 that contains the optimum feature set you found in step 6 and the data for the best normalization strategy. Optimize the following hyperparameters:
#
# k parameter in k-NN
# number of trees in random forest
# Number of iterations in Adaboost
# C, gamma parameter in SVM
#
# Try a grid of values and choose the best value(s) that maximize the overall cross validation accuracy.
#
# * For k-NN you can choose 1 5 10 15 ... 100 (with increments of 5 after k=5)
# * For number of trees in random forest you can try 5 10 25 50 75 100 150 200 250 300 350 400 450 500
# * For the number of iterations in Adaboost you can try 5 10 15 20 25 30 40 50 75 100 125 150 175 200
#
# To optimize C and gamma parameters of the SVM you can consider the
# following parameter grid:
#
# C ∈ {2^-5, 2^-3, 2^-1, 2^1, 2^3, 2^5, ... 2^13, 2^15}
# γ ∈ {2^-15, 2^-13, ... , 2^-1, 2^1, 2^3, 2^5}
#
# There are a total of 11 values for the C parameter and 11 values for the gamma parameter (a total of 121 values to consider for the (C, gamma) pair).
#
# Report the best cross-validation accuracies and optimum parameter values you found.
#
# Compute predictions on the validation set using the models trained by optimum
# hyper-parameters. Report the same accuracy measures as in step 5.

# %%
best_selector = SelectKBest(chi2,k=4)
best_selector.fit(normalized_x_train_two, y=y_train_two)
optimum_x_train_two = best_selector.transform(normalized_x_train_two)

hyper_parameters = {
    "K-Nearest Neighbour": [1] + [i*5 for i in range(1,21)],
    "Random Forest": [5,10,25,50,75,100,150,200,250,300,350,400,450,500],
    "AdaBoostClassifier": [5,10,15,20,25,30,40,50,75,100,125,150,175,200],
    "Support Vector Machine": ([2**i for i in range(-5,16,2)], [2**i for i in range(-15,6,2)])
}

opt_params = dict()

for model_name, parameters in hyper_parameters.items():
    model = None
    optimum_accuracy = 0.0
    optimum_parameters = ""
    
    if model_name == "K-Nearest Neighbour":
        for parameter in parameters:
            print("n_neighbors: {}".format(parameter))
            model = KNeighborsClassifier(n_neighbors=parameter)
            accuracy = dump_metrics_with_cv(optimum_x_train_two, y_train_two, model_name, model)
            
            if accuracy > optimum_accuracy:
                optimum_accuracy = accuracy
                optimum_parameters = "n_neighbors=" + str(parameter)
                opt_params["n_neighbors"] = parameter
    elif model_name == "Random Forest":
        for parameter in parameters:
            print("n_estimators: {}".format(parameter))
            model = RandomForestClassifier(n_estimators=parameter)
            accuracy = dump_metrics_with_cv(optimum_x_train_two, y_train_two, model_name, model)
            
            if accuracy > optimum_accuracy:
                optimum_accuracy = accuracy
                optimum_parameters = "n_estimators=" + str(parameter)
                opt_params["rf_estimators"] = parameter
    elif model_name == "Support Vector Machine":
        C_values = parameters[0]
        gamma_values = parameters[1]
        
        for C in C_values:
            for gamma in gamma_values:
                print("C: {}, gamma: {}".format(C, gamma))
                model = SVC(kernel="rbf", C=C,gamma=gamma)
                accuracy = dump_metrics_with_cv(optimum_x_train_two, y_train_two, model_name, model)
                
                if accuracy > optimum_accuracy:
                    optimum_accuracy = accuracy
                    optimum_parameters = "C:" + str(C) + ", " + "gamma:" + str(gamma)
                    opt_params["svm_c"] = C
                    opt_params["svm_gamma"] = gamma
    elif model_name == "AdaBoostClassifier":
        for parameter in parameters:
            print("n_estimators: {}".format(parameter))
            model = AdaBoostClassifier(n_estimators=parameter)
            accuracy = dump_metrics_with_cv(optimum_x_train_two, y_train_two, model_name, model)
            
            if accuracy > optimum_accuracy:
                optimum_accuracy = accuracy
                optimum_parameters = "n_estimators=" + str(parameter)
                opt_params["ab_estimators"] = parameter
    
    print("Optimum Accuracy for {}: {}".format(model_name, optimum_accuracy))
    print("Optimum Parameters:{}\n\n".format(optimum_parameters))
# Out:
# n_estimators: 5
# AdaBoostClassifier Accuracy Score: 0.988023848324
# AdaBoostClassifier F-Measure: 0.97243963184
# AdaBoostClassifier Sensitivity: 0.99276404963
# AdaBoostClassifier Specificity: 0.9867465356
# AdaBoostClassifier Precision: 0.953167032635
# AdaBoostClassifier Area Under ROC Curve: 0.989755292615
# AdaBoostClassifier Area Under Precision Recall Curve: 0.947741260751
# AdaBoostClassifier MCC: 0.965222247128
#
# n_estimators: 10
# AdaBoostClassifier Accuracy Score: 0.988945271712
# AdaBoostClassifier F-Measure: 0.97444645613
# AdaBoostClassifier Sensitivity: 0.990590136586
# AdaBoostClassifier Specificity: 0.988500921565
# AdaBoostClassifier Precision: 0.959068869257
# AdaBoostClassifier Area Under ROC Curve: 0.989545529075
# AdaBoostClassifier Area Under Precision Recall Curve: 0.951977835068
# AdaBoostClassifier MCC: 0.967708165795
#
# n_estimators: 15
# AdaBoostClassifier Accuracy Score: 0.989866460224
# AdaBoostClassifier F-Measure: 0.976480354757
# AdaBoostClassifier Sensitivity: 0.988421436764
# AdaBoostClassifier Specificity: 0.99025454904
# AdaBoostClassifier Precision: 0.965085735999
# AdaBoostClassifier Area Under ROC Curve: 0.989337992902
# AdaBoostClassifier Area Under Precision Recall Curve: 0.956294064696
# AdaBoostClassifier MCC: 0.970246643039
#
# n_estimators: 20
# AdaBoostClassifier Accuracy Score: 0.989712143599
# AdaBoostClassifier F-Measure: 0.976163313666
# AdaBoostClassifier Sensitivity: 0.989865498905
# AdaBoostClassifier Specificity: 0.989670132963
# AdaBoostClassifier Precision: 0.963074156505
# AdaBoostClassifier Area Under ROC Curve: 0.989767815934
# AdaBoostClassifier Area Under Precision Recall Curve: 0.955432811654
# AdaBoostClassifier MCC: 0.969855375033
#
# n_estimators: 25
# AdaBoostClassifier Accuracy Score: 0.990633566987
# AdaBoostClassifier F-Measure: 0.978178781478
# AdaBoostClassifier Sensitivity: 0.988411010322
# AdaBoostClassifier Specificity: 0.991229587154
# AdaBoostClassifier Precision: 0.968225636019
# AdaBoostClassifier Area Under ROC Curve: 0.989820298738
# AdaBoostClassifier Area Under Precision Recall Curve: 0.95949507175
# AdaBoostClassifier MCC: 0.972329593529
#
# n_estimators: 30
# AdaBoostClassifier Accuracy Score: 0.990786941942
# AdaBoostClassifier F-Measure: 0.978584227414
# AdaBoostClassifier Sensitivity: 0.990579710145
# AdaBoostClassifier Specificity: 0.990839344362
# AdaBoostClassifier Precision: 0.967032368568
# AdaBoostClassifier Area Under ROC Curve: 0.990709527253
# AdaBoostClassifier Area Under Precision Recall Curve: 0.959908478382
# AdaBoostClassifier MCC: 0.972896723499
#
# n_estimators: 40
# AdaBoostClassifier Accuracy Score: 0.991708129011
# AdaBoostClassifier F-Measure: 0.980669657879
# AdaBoostClassifier Sensitivity: 0.989865498905
# AdaBoostClassifier Specificity: 0.992203866779
# AdaBoostClassifier Precision: 0.971749281542
# AdaBoostClassifier Area Under ROC Curve: 0.991034682842
# AdaBoostClassifier Area Under Precision Recall Curve: 0.964074464582
# AdaBoostClassifier MCC: 0.97550416973
#
# n_estimators: 50
# AdaBoostClassifier Accuracy Score: 0.992322803933
# AdaBoostClassifier F-Measure: 0.982085826466
# AdaBoostClassifier Sensitivity: 0.990595349807
# AdaBoostClassifier Specificity: 0.992788662101
# AdaBoostClassifier Precision: 0.973809909772
# AdaBoostClassifier Area Under ROC Curve: 0.991692005954
# AdaBoostClassifier Area Under Precision Recall Curve: 0.966638697087
# AdaBoostClassifier MCC: 0.977295540399
#
# n_estimators: 75
# AdaBoostClassifier Accuracy Score: 0.992169665298
# AdaBoostClassifier F-Measure: 0.981709443561
# AdaBoostClassifier Sensitivity: 0.989151287666
# AdaBoostClassifier Specificity: 0.992983593874
# AdaBoostClassifier Precision: 0.974464867537
# AdaBoostClassifier Area Under ROC Curve: 0.99106744077
# AdaBoostClassifier Area Under Precision Recall Curve: 0.966187414283
# AdaBoostClassifier MCC: 0.976808201422
#
# n_estimators: 100
# AdaBoostClassifier Accuracy Score: 0.992016291786
# AdaBoostClassifier F-Measure: 0.981324955961
# AdaBoostClassifier Sensitivity: 0.987717651965
# AdaBoostClassifier Specificity: 0.993178525648
# AdaBoostClassifier Precision: 0.975148712257
# AdaBoostClassifier Area Under ROC Curve: 0.990448088807
# AdaBoostClassifier Area Under Precision Recall Curve: 0.965744541143
# AdaBoostClassifier MCC: 0.976335650643
#
# n_estimators: 125
# AdaBoostClassifier Accuracy Score: 0.991402558534
# AdaBoostClassifier F-Measure: 0.979873287806
# AdaBoostClassifier Sensitivity: 0.985554165363
# AdaBoostClassifier Specificity: 0.992983593874
# AdaBoostClassifier Precision: 0.974388974998
# AdaBoostClassifier Area Under ROC Curve: 0.989268879619
# AdaBoostClassifier Area Under Precision Recall Curve: 0.963343845086
# AdaBoostClassifier MCC: 0.974486778432
#
# n_estimators: 150
# AdaBoostClassifier Accuracy Score: 0.991402794132
# AdaBoostClassifier F-Measure: 0.979857704605
# AdaBoostClassifier Sensitivity: 0.984834740903
# AdaBoostClassifier Specificity: 0.993178525648
# AdaBoostClassifier Precision: 0.975072204811
# AdaBoostClassifier Area Under ROC Curve: 0.989006633276
# AdaBoostClassifier Area Under Precision Recall Curve: 0.963466873338
# AdaBoostClassifier MCC: 0.974470482246
#
# n_estimators: 175
# AdaBoostClassifier Accuracy Score: 0.991556639561
# AdaBoostClassifier F-Measure: 0.980205950665
# AdaBoostClassifier Sensitivity: 0.984834740903
# AdaBoostClassifier Specificity: 0.993373457422
# AdaBoostClassifier Precision: 0.975736828178
# AdaBoostClassifier Area Under ROC Curve: 0.989104099163
# AdaBoostClassifier Area Under Precision Recall Curve: 0.964131779435
# AdaBoostClassifier MCC: 0.974904414299
#
# n_estimators: 200
# AdaBoostClassifier Accuracy Score: 0.991403500204
# AdaBoostClassifier F-Measure: 0.979847601799
# AdaBoostClassifier Sensitivity: 0.984115316442
# AdaBoostClassifier Specificity: 0.993373457422
# AdaBoostClassifier Precision: 0.975731908102
# AdaBoostClassifier Area Under ROC Curve: 0.988744386932
# AdaBoostClassifier Area Under Precision Recall Curve: 0.963586079422
# AdaBoostClassifier MCC: 0.974445594308
#
# Optimum Accuracy for AdaBoostClassifier: 0.992322803933
# Optimum Parameters:n_estimators=50
#
#
# C: 0.03125, gamma: 3.0517578125e-05
# Support Vector Machine Accuracy Score: 0.787688495819
# Support Vector Machine F-Measure: 0.0
# Support Vector Machine Sensitivity: 0.0
# Support Vector Machine Specificity: 1.0
# Support Vector Machine Precision: 0.0
# Support Vector Machine Area Under ROC Curve: 0.5
# Support Vector Machine Area Under Precision Recall Curve: 0.212311504181
# Support Vector Machine MCC: 0.0
#
# C: 0.03125, gamma: 0.0001220703125
# Support Vector Machine Accuracy Score: 0.787688495819
# Support Vector Machine F-Measure: 0.0
# Support Vector Machine Sensitivity: 0.0
# Support Vector Machine Specificity: 1.0
# Support Vector Machine Precision: 0.0
# Support Vector Machine Area Under ROC Curve: 0.5
# Support Vector Machine Area Under Precision Recall Curve: 0.212311504181
# Support Vector Machine MCC: 0.0
#
# C: 0.03125, gamma: 0.00048828125
# Support Vector Machine Accuracy Score: 0.787688495819
# Support Vector Machine F-Measure: 0.0
# Support Vector Machine Sensitivity: 0.0
# Support Vector Machine Specificity: 1.0
# Support Vector Machine Precision: 0.0
# Support Vector Machine Area Under ROC Curve: 0.5
# Support Vector Machine Area Under Precision Recall Curve: 0.212311504181
# Support Vector Machine MCC: 0.0
#
# C: 0.03125, gamma: 0.001953125
# Support Vector Machine Accuracy Score: 0.787688495819
# Support Vector Machine F-Measure: 0.0
# Support Vector Machine Sensitivity: 0.0
# Support Vector Machine Specificity: 1.0
# Support Vector Machine Precision: 0.0
# Support Vector Machine Area Under ROC Curve: 0.5
# Support Vector Machine Area Under Precision Recall Curve: 0.212311504181
# Support Vector Machine MCC: 0.0
#
# C: 0.03125, gamma: 0.0078125
# Support Vector Machine Accuracy Score: 0.787688495819
# Support Vector Machine F-Measure: 0.0
# Support Vector Machine Sensitivity: 0.0
# Support Vector Machine Specificity: 1.0
# Support Vector Machine Precision: 0.0
# Support Vector Machine Area Under ROC Curve: 0.5
# Support Vector Machine Area Under Precision Recall Curve: 0.212311504181
# Support Vector Machine MCC: 0.0
#
# C: 0.03125, gamma: 0.03125
# Support Vector Machine Accuracy Score: 0.787688495819
# Support Vector Machine F-Measure: 0.0
# Support Vector Machine Sensitivity: 0.0
# Support Vector Machine Specificity: 1.0
# Support Vector Machine Precision: 0.0
# Support Vector Machine Area Under ROC Curve: 0.5
# Support Vector Machine Area Under Precision Recall Curve: 0.212311504181
# Support Vector Machine MCC: 0.0
#
# C: 0.03125, gamma: 0.125
# Support Vector Machine Accuracy Score: 0.960701782429
# Support Vector Machine F-Measure: 0.904458468819
# Support Vector Machine Sensitivity: 0.875669898864
# Support Vector Machine Specificity: 0.983627627218
# Support Vector Machine Precision: 0.935695277446
# Support Vector Machine Area Under ROC Curve: 0.929648763041
# Support Vector Machine Area Under Precision Recall Curve: 0.845806377285
# Support Vector Machine MCC: 0.880699835908
#
# C: 0.03125, gamma: 0.5
# Support Vector Machine Accuracy Score: 0.989252491374
# Support Vector Machine F-Measure: 0.975328063111
# Support Vector Machine Sensitivity: 0.998550724638
# Support Vector Machine Specificity: 0.9867465356
# Support Vector Machine Precision: 0.953276096776
# Support Vector Machine Area Under ROC Curve: 0.992648630119
# Support Vector Machine Area Under Precision Recall Curve: 0.95219478193
# Support Vector Machine MCC: 0.968939096296
#
# C: 0.03125, gamma: 2
# Support Vector Machine Accuracy Score: 0.989559475438
# Support Vector Machine F-Measure: 0.976049840301
# Support Vector Machine Sensitivity: 0.999275362319
# Support Vector Machine Specificity: 0.986941467374
# Support Vector Machine Precision: 0.954008718601
# Support Vector Machine Area Under ROC Curve: 0.993108414846
# Support Vector Machine Area Under Precision Recall Curve: 0.95347767076
# Support Vector Machine MCC: 0.96986150473
#
# C: 0.03125, gamma: 8
# Support Vector Machine Accuracy Score: 0.98925272625
# Support Vector Machine F-Measure: 0.975340405431
# Support Vector Machine Sensitivity: 0.998550724638
# Support Vector Machine Specificity: 0.986746914844
# Support Vector Machine Precision: 0.953323031764
# Support Vector Machine Area Under ROC Curve: 0.992648819741
# Support Vector Machine Area Under Precision Recall Curve: 0.952241513171
# Support Vector Machine MCC: 0.968959976155
#
# C: 0.03125, gamma: 32
# Support Vector Machine Accuracy Score: 0.989099116419
# Support Vector Machine F-Measure: 0.974976907718
# Support Vector Machine Sensitivity: 0.997826086957
# Support Vector Machine Specificity: 0.986746914844
# Support Vector Machine Precision: 0.9532984085
# Support Vector Machine Area Under ROC Curve: 0.9922865009
# Support Vector Machine Area Under Precision Recall Curve: 0.951671377468
# Support Vector Machine MCC: 0.968490011825
#
# C: 0.125, gamma: 3.0517578125e-05
# Support Vector Machine Accuracy Score: 0.787688495819
# Support Vector Machine F-Measure: 0.0
# Support Vector Machine Sensitivity: 0.0
# Support Vector Machine Specificity: 1.0
# Support Vector Machine Precision: 0.0
# Support Vector Machine Area Under ROC Curve: 0.5
# Support Vector Machine Area Under Precision Recall Curve: 0.212311504181
# Support Vector Machine MCC: 0.0
#
# C: 0.125, gamma: 0.0001220703125
# Support Vector Machine Accuracy Score: 0.787688495819
# Support Vector Machine F-Measure: 0.0
# Support Vector Machine Sensitivity: 0.0
# Support Vector Machine Specificity: 1.0
# Support Vector Machine Precision: 0.0
# Support Vector Machine Area Under ROC Curve: 0.5
# Support Vector Machine Area Under Precision Recall Curve: 0.212311504181
# Support Vector Machine MCC: 0.0
#
# C: 0.125, gamma: 0.00048828125
# Support Vector Machine Accuracy Score: 0.787688495819
# Support Vector Machine F-Measure: 0.0
# Support Vector Machine Sensitivity: 0.0
# Support Vector Machine Specificity: 1.0
# Support Vector Machine Precision: 0.0
# Support Vector Machine Area Under ROC Curve: 0.5
# Support Vector Machine Area Under Precision Recall Curve: 0.212311504181
# Support Vector Machine MCC: 0.0
#
# C: 0.125, gamma: 0.001953125
# Support Vector Machine Accuracy Score: 0.787688495819
# Support Vector Machine F-Measure: 0.0
# Support Vector Machine Sensitivity: 0.0
# Support Vector Machine Specificity: 1.0
# Support Vector Machine Precision: 0.0
# Support Vector Machine Area Under ROC Curve: 0.5
# Support Vector Machine Area Under Precision Recall Curve: 0.212311504181
# Support Vector Machine MCC: 0.0
#
# C: 0.125, gamma: 0.0078125
# Support Vector Machine Accuracy Score: 0.787688495819
# Support Vector Machine F-Measure: 0.0
# Support Vector Machine Sensitivity: 0.0
# Support Vector Machine Specificity: 1.0
# Support Vector Machine Precision: 0.0
# Support Vector Machine Area Under ROC Curve: 0.5
# Support Vector Machine Area Under Precision Recall Curve: 0.212311504181
# Support Vector Machine MCC: 0.0
#
# C: 0.125, gamma: 0.03125
# Support Vector Machine Accuracy Score: 0.961009002091
# Support Vector Machine F-Measure: 0.905264958548
# Support Vector Machine Sensitivity: 0.877119174226
# Support Vector Machine Specificity: 0.983627627218
# Support Vector Machine Precision: 0.935797390613
# Support Vector Machine Area Under ROC Curve: 0.930373400722
# Support Vector Machine Area Under Precision Recall Curve: 0.846941109153
# Support Vector Machine MCC: 0.881670940088
#
# C: 0.125, gamma: 0.125
# Support Vector Machine Accuracy Score: 0.989252491374
# Support Vector Machine F-Measure: 0.975335518531
# Support Vector Machine Sensitivity: 0.998550724638
# Support Vector Machine Specificity: 0.9867465356
# Support Vector Machine Precision: 0.953299568596
# Support Vector Machine Area Under ROC Curve: 0.992648630119
# Support Vector Machine Area Under Precision Recall Curve: 0.952223008317
# Support Vector Machine MCC: 0.968949588559
#
# C: 0.125, gamma: 0.5
# Support Vector Machine Accuracy Score: 0.988945742186
# Support Vector Machine F-Measure: 0.974648666626
# Support Vector Machine Sensitivity: 0.998550724638
# Support Vector Machine Specificity: 0.986357051297
# Support Vector Machine Precision: 0.951991362841
# Support Vector Machine Area Under ROC Curve: 0.992453887967
# Support Vector Machine Area Under Precision Recall Curve: 0.950914533684
# Support Vector Machine MCC: 0.968092393919
#
# C: 0.125, gamma: 2
# Support Vector Machine Accuracy Score: 0.98925272625
# Support Vector Machine F-Measure: 0.975340405431
# Support Vector Machine Sensitivity: 0.998550724638
# Support Vector Machine Specificity: 0.986746914844
# Support Vector Machine Precision: 0.953323031764
# Support Vector Machine Area Under ROC Curve: 0.992648819741
# Support Vector Machine Area Under Precision Recall Curve: 0.952241513171
# Support Vector Machine MCC: 0.968959976155
#
# C: 0.125, gamma: 8
# Support Vector Machine Accuracy Score: 0.98925272625
# Support Vector Machine F-Measure: 0.975340405431
# Support Vector Machine Sensitivity: 0.998550724638
# Support Vector Machine Specificity: 0.986746914844
# Support Vector Machine Precision: 0.953323031764
# Support Vector Machine Area Under ROC Curve: 0.992648819741
# Support Vector Machine Area Under Precision Recall Curve: 0.952241513171
# Support Vector Machine MCC: 0.968959976155
#
# C: 0.125, gamma: 32
# Support Vector Machine Accuracy Score: 0.989099116419
# Support Vector Machine F-Measure: 0.974976907718
# Support Vector Machine Sensitivity: 0.997826086957
# Support Vector Machine Specificity: 0.986746914844
# Support Vector Machine Precision: 0.9532984085
# Support Vector Machine Area Under ROC Curve: 0.9922865009
# Support Vector Machine Area Under Precision Recall Curve: 0.951671377468
# Support Vector Machine MCC: 0.968490011825
#
# C: 0.5, gamma: 3.0517578125e-05
# Support Vector Machine Accuracy Score: 0.787688495819
# Support Vector Machine F-Measure: 0.0
# Support Vector Machine Sensitivity: 0.0
# Support Vector Machine Specificity: 1.0
# Support Vector Machine Precision: 0.0
# Support Vector Machine Area Under ROC Curve: 0.5
# Support Vector Machine Area Under Precision Recall Curve: 0.212311504181
# Support Vector Machine MCC: 0.0
#
# C: 0.5, gamma: 0.0001220703125
# Support Vector Machine Accuracy Score: 0.787688495819
# Support Vector Machine F-Measure: 0.0
# Support Vector Machine Sensitivity: 0.0
# Support Vector Machine Specificity: 1.0
# Support Vector Machine Precision: 0.0
# Support Vector Machine Area Under ROC Curve: 0.5
# Support Vector Machine Area Under Precision Recall Curve: 0.212311504181
# Support Vector Machine MCC: 0.0
#
# C: 0.5, gamma: 0.00048828125
# Support Vector Machine Accuracy Score: 0.787688495819
# Support Vector Machine F-Measure: 0.0
# Support Vector Machine Sensitivity: 0.0
# Support Vector Machine Specificity: 1.0
# Support Vector Machine Precision: 0.0
# Support Vector Machine Area Under ROC Curve: 0.5
# Support Vector Machine Area Under Precision Recall Curve: 0.212311504181
# Support Vector Machine MCC: 0.0
#
# C: 0.5, gamma: 0.001953125
# Support Vector Machine Accuracy Score: 0.787688495819
# Support Vector Machine F-Measure: 0.0
# Support Vector Machine Sensitivity: 0.0
# Support Vector Machine Specificity: 1.0
# Support Vector Machine Precision: 0.0
# Support Vector Machine Area Under ROC Curve: 0.5
# Support Vector Machine Area Under Precision Recall Curve: 0.212311504181
# Support Vector Machine MCC: 0.0
#
# C: 0.5, gamma: 0.0078125
# Support Vector Machine Accuracy Score: 0.961009002091
# Support Vector Machine F-Measure: 0.905264958548
# Support Vector Machine Sensitivity: 0.877119174226
# Support Vector Machine Specificity: 0.983627627218
# Support Vector Machine Precision: 0.935797390613
# Support Vector Machine Area Under ROC Curve: 0.930373400722
# Support Vector Machine Area Under Precision Recall Curve: 0.846941109153
# Support Vector Machine MCC: 0.881670940088
#
# C: 0.5, gamma: 0.03125
# Support Vector Machine Accuracy Score: 0.989252491374
# Support Vector Machine F-Measure: 0.975335518531
# Support Vector Machine Sensitivity: 0.998550724638
# Support Vector Machine Specificity: 0.9867465356
# Support Vector Machine Precision: 0.953299568596
# Support Vector Machine Area Under ROC Curve: 0.992648630119
# Support Vector Machine Area Under Precision Recall Curve: 0.952223008317
# Support Vector Machine MCC: 0.968949588559
#
# C: 0.5, gamma: 0.125
# Support Vector Machine Accuracy Score: 0.988792132355
# Support Vector Machine F-Measure: 0.974310144264
# Support Vector Machine Sensitivity: 0.998550724638
# Support Vector Machine Specificity: 0.986162119523
# Support Vector Machine Precision: 0.951353025314
# Support Vector Machine Area Under ROC Curve: 0.99235642208
# Support Vector Machine Area Under Precision Recall Curve: 0.950280821792
# Support Vector Machine MCC: 0.967670688953
#
# C: 0.5, gamma: 0.5
# Support Vector Machine Accuracy Score: 0.988945742186
# Support Vector Machine F-Measure: 0.974648666626
# Support Vector Machine Sensitivity: 0.998550724638
# Support Vector Machine Specificity: 0.986357051297
# Support Vector Machine Precision: 0.951991362841
# Support Vector Machine Area Under ROC Curve: 0.992453887967
# Support Vector Machine Area Under Precision Recall Curve: 0.950914533684
# Support Vector Machine MCC: 0.968092393919
#
# C: 0.5, gamma: 2
# Support Vector Machine Accuracy Score: 0.98925272625
# Support Vector Machine F-Measure: 0.975340405431
# Support Vector Machine Sensitivity: 0.998550724638
# Support Vector Machine Specificity: 0.986746914844
# Support Vector Machine Precision: 0.953323031764
# Support Vector Machine Area Under ROC Curve: 0.992648819741
# Support Vector Machine Area Under Precision Recall Curve: 0.952241513171
# Support Vector Machine MCC: 0.968959976155
#
# C: 0.5, gamma: 8
# Support Vector Machine Accuracy Score: 0.98925272625
# Support Vector Machine F-Measure: 0.975340405431
# Support Vector Machine Sensitivity: 0.998550724638
# Support Vector Machine Specificity: 0.986746914844
# Support Vector Machine Precision: 0.953323031764
# Support Vector Machine Area Under ROC Curve: 0.992648819741
# Support Vector Machine Area Under Precision Recall Curve: 0.952241513171
# Support Vector Machine MCC: 0.968959976155
#
# C: 0.5, gamma: 32
# Support Vector Machine Accuracy Score: 0.989099116419
# Support Vector Machine F-Measure: 0.974976907718
# Support Vector Machine Sensitivity: 0.997826086957
# Support Vector Machine Specificity: 0.986746914844
# Support Vector Machine Precision: 0.9532984085
# Support Vector Machine Area Under ROC Curve: 0.9922865009
# Support Vector Machine Area Under Precision Recall Curve: 0.951671377468
# Support Vector Machine MCC: 0.968490011825
#
# C: 2, gamma: 3.0517578125e-05
# Support Vector Machine Accuracy Score: 0.787688495819
# Support Vector Machine F-Measure: 0.0
# Support Vector Machine Sensitivity: 0.0
# Support Vector Machine Specificity: 1.0
# Support Vector Machine Precision: 0.0
# Support Vector Machine Area Under ROC Curve: 0.5
# Support Vector Machine Area Under Precision Recall Curve: 0.212311504181
# Support Vector Machine MCC: 0.0
#
# C: 2, gamma: 0.0001220703125
# Support Vector Machine Accuracy Score: 0.787688495819
# Support Vector Machine F-Measure: 0.0
# Support Vector Machine Sensitivity: 0.0
# Support Vector Machine Specificity: 1.0
# Support Vector Machine Precision: 0.0
# Support Vector Machine Area Under ROC Curve: 0.5
# Support Vector Machine Area Under Precision Recall Curve: 0.212311504181
# Support Vector Machine MCC: 0.0
#
# C: 2, gamma: 0.00048828125
# Support Vector Machine Accuracy Score: 0.787688495819
# Support Vector Machine F-Measure: 0.0
# Support Vector Machine Sensitivity: 0.0
# Support Vector Machine Specificity: 1.0
# Support Vector Machine Precision: 0.0
# Support Vector Machine Area Under ROC Curve: 0.5
# Support Vector Machine Area Under Precision Recall Curve: 0.212311504181
# Support Vector Machine MCC: 0.0
#
# C: 2, gamma: 0.001953125
# Support Vector Machine Accuracy Score: 0.961009002091
# Support Vector Machine F-Measure: 0.905264958548
# Support Vector Machine Sensitivity: 0.877119174226
# Support Vector Machine Specificity: 0.983627627218
# Support Vector Machine Precision: 0.935797390613
# Support Vector Machine Area Under ROC Curve: 0.930373400722
# Support Vector Machine Area Under Precision Recall Curve: 0.846941109153
# Support Vector Machine MCC: 0.881670940088
#
# C: 2, gamma: 0.0078125
# Support Vector Machine Accuracy Score: 0.989252491374
# Support Vector Machine F-Measure: 0.975335518531
# Support Vector Machine Sensitivity: 0.998550724638
# Support Vector Machine Specificity: 0.9867465356
# Support Vector Machine Precision: 0.953299568596
# Support Vector Machine Area Under ROC Curve: 0.992648630119
# Support Vector Machine Area Under Precision Recall Curve: 0.952223008317
# Support Vector Machine MCC: 0.968949588559
#
# C: 2, gamma: 0.03125
# Support Vector Machine Accuracy Score: 0.988638522524
# Support Vector Machine F-Measure: 0.973946646552
# Support Vector Machine Sensitivity: 0.997826086957
# Support Vector Machine Specificity: 0.986162119523
# Support Vector Machine Precision: 0.95132840205
# Support Vector Machine Area Under ROC Curve: 0.99199410324
# Support Vector Machine Area Under Precision Recall Curve: 0.949710686089
# Support Vector Machine MCC: 0.967200724623
#
# C: 2, gamma: 0.125
# Support Vector Machine Accuracy Score: 0.988638522524
# Support Vector Machine F-Measure: 0.973946646552
# Support Vector Machine Sensitivity: 0.997826086957
# Support Vector Machine Specificity: 0.986162119523
# Support Vector Machine Precision: 0.95132840205
# Support Vector Machine Area Under ROC Curve: 0.99199410324
# Support Vector Machine Area Under Precision Recall Curve: 0.949710686089
# Support Vector Machine MCC: 0.967200724623
#
# C: 2, gamma: 0.5
# Support Vector Machine Accuracy Score: 0.988945742186
# Support Vector Machine F-Measure: 0.974648666626
# Support Vector Machine Sensitivity: 0.998550724638
# Support Vector Machine Specificity: 0.986357051297
# Support Vector Machine Precision: 0.951991362841
# Support Vector Machine Area Under ROC Curve: 0.992453887967
# Support Vector Machine Area Under Precision Recall Curve: 0.950914533684
# Support Vector Machine MCC: 0.968092393919
#
# C: 2, gamma: 2
# Support Vector Machine Accuracy Score: 0.989406336081
# Support Vector Machine F-Measure: 0.975703948697
# Support Vector Machine Sensitivity: 0.999275362319
# Support Vector Machine Specificity: 0.986746914844
# Support Vector Machine Precision: 0.953343009788
# Support Vector Machine Area Under ROC Curve: 0.993011138582
# Support Vector Machine Area Under Precision Recall Curve: 0.952811961948
# Support Vector Machine MCC: 0.969428029077
#
# C: 2, gamma: 8
# Support Vector Machine Accuracy Score: 0.98925272625
# Support Vector Machine F-Measure: 0.975340405431
# Support Vector Machine Sensitivity: 0.998550724638
# Support Vector Machine Specificity: 0.986746914844
# Support Vector Machine Precision: 0.953323031764
# Support Vector Machine Area Under ROC Curve: 0.992648819741
# Support Vector Machine Area Under Precision Recall Curve: 0.952241513171
# Support Vector Machine MCC: 0.968959976155
#
# C: 2, gamma: 32
# Support Vector Machine Accuracy Score: 0.990020069333
# Support Vector Machine F-Measure: 0.977035328485
# Support Vector Machine Sensitivity: 0.997101449275
# Support Vector Machine Specificity: 0.988111058017
# Support Vector Machine Precision: 0.957888169981
# Support Vector Machine Area Under ROC Curve: 0.992606253646
# Support Vector Machine Area Under Precision Recall Curve: 0.955744364494
# Support Vector Machine MCC: 0.971037225719
#
# C: 8, gamma: 3.0517578125e-05
# Support Vector Machine Accuracy Score: 0.787688495819
# Support Vector Machine F-Measure: 0.0
# Support Vector Machine Sensitivity: 0.0
# Support Vector Machine Specificity: 1.0
# Support Vector Machine Precision: 0.0
# Support Vector Machine Area Under ROC Curve: 0.5
# Support Vector Machine Area Under Precision Recall Curve: 0.212311504181
# Support Vector Machine MCC: 0.0
#
# C: 8, gamma: 0.0001220703125
# Support Vector Machine Accuracy Score: 0.787688495819
# Support Vector Machine F-Measure: 0.0
# Support Vector Machine Sensitivity: 0.0
# Support Vector Machine Specificity: 1.0
# Support Vector Machine Precision: 0.0
# Support Vector Machine Area Under ROC Curve: 0.5
# Support Vector Machine Area Under Precision Recall Curve: 0.212311504181
# Support Vector Machine MCC: 0.0
#
# C: 8, gamma: 0.00048828125
# Support Vector Machine Accuracy Score: 0.961009002091
# Support Vector Machine F-Measure: 0.905264958548
# Support Vector Machine Sensitivity: 0.877119174226
# Support Vector Machine Specificity: 0.983627627218
# Support Vector Machine Precision: 0.935797390613
# Support Vector Machine Area Under ROC Curve: 0.930373400722
# Support Vector Machine Area Under Precision Recall Curve: 0.846941109153
# Support Vector Machine MCC: 0.881670940088
#
# C: 8, gamma: 0.001953125
# Support Vector Machine Accuracy Score: 0.989252491374
# Support Vector Machine F-Measure: 0.975335518531
# Support Vector Machine Sensitivity: 0.998550724638
# Support Vector Machine Specificity: 0.9867465356
# Support Vector Machine Precision: 0.953299568596
# Support Vector Machine Area Under ROC Curve: 0.992648630119
# Support Vector Machine Area Under Precision Recall Curve: 0.952223008317
# Support Vector Machine MCC: 0.968949588559
#
# C: 8, gamma: 0.0078125
# Support Vector Machine Accuracy Score: 0.988638522524
# Support Vector Machine F-Measure: 0.973946646552
# Support Vector Machine Sensitivity: 0.997826086957
# Support Vector Machine Specificity: 0.986162119523
# Support Vector Machine Precision: 0.95132840205
# Support Vector Machine Area Under ROC Curve: 0.99199410324
# Support Vector Machine Area Under Precision Recall Curve: 0.949710686089
# Support Vector Machine MCC: 0.967200724623
#
# C: 8, gamma: 0.03125
# Support Vector Machine Accuracy Score: 0.988638522524
# Support Vector Machine F-Measure: 0.973946646552
# Support Vector Machine Sensitivity: 0.997826086957
# Support Vector Machine Specificity: 0.986162119523
# Support Vector Machine Precision: 0.95132840205
# Support Vector Machine Area Under ROC Curve: 0.99199410324
# Support Vector Machine Area Under Precision Recall Curve: 0.949710686089
# Support Vector Machine MCC: 0.967200724623
#
# C: 8, gamma: 0.125
# Support Vector Machine Accuracy Score: 0.988638522524
# Support Vector Machine F-Measure: 0.973946646552
# Support Vector Machine Sensitivity: 0.997826086957
# Support Vector Machine Specificity: 0.986162119523
# Support Vector Machine Precision: 0.95132840205
# Support Vector Machine Area Under ROC Curve: 0.99199410324
# Support Vector Machine Area Under Precision Recall Curve: 0.949710686089
# Support Vector Machine MCC: 0.967200724623
#
# C: 8, gamma: 0.5
# Support Vector Machine Accuracy Score: 0.98925272625
# Support Vector Machine F-Measure: 0.975340405431
# Support Vector Machine Sensitivity: 0.998550724638
# Support Vector Machine Specificity: 0.986746914844
# Support Vector Machine Precision: 0.953323031764
# Support Vector Machine Area Under ROC Curve: 0.992648819741
# Support Vector Machine Area Under Precision Recall Curve: 0.952241513171
# Support Vector Machine MCC: 0.968959976155
#
# C: 8, gamma: 2
# Support Vector Machine Accuracy Score: 0.98925272625
# Support Vector Machine F-Measure: 0.975353160695
# Support Vector Machine Sensitivity: 0.999275362319
# Support Vector Machine Specificity: 0.986551983071
# Support Vector Machine Precision: 0.9526634077
# Support Vector Machine Area Under ROC Curve: 0.992913672695
# Support Vector Machine Area Under Precision Recall Curve: 0.95213235986
# Support Vector Machine MCC: 0.968987913137
#
# C: 8, gamma: 8
# Support Vector Machine Accuracy Score: 0.988945506588
# Support Vector Machine F-Measure: 0.974626165271
# Support Vector Machine Sensitivity: 0.997826086957
# Support Vector Machine Specificity: 0.986551983071
# Support Vector Machine Precision: 0.952614161172
# Support Vector Machine Area Under ROC Curve: 0.992189035014
# Support Vector Machine Area Under Precision Recall Curve: 0.950992088454
# Support Vector Machine MCC: 0.968047984476
#
# C: 8, gamma: 32
# Support Vector Machine Accuracy Score: 0.992322804654
# Support Vector Machine F-Measure: 0.982151713351
# Support Vector Machine Sensitivity: 0.99347826087
# Support Vector Machine Specificity: 0.992008935005
# Support Vector Machine Precision: 0.971184560273
# Support Vector Machine Area Under ROC Curve: 0.992743597937
# Support Vector Machine Area Under Precision Recall Curve: 0.966235463235
# Support Vector Machine MCC: 0.977408057906
#
# C: 32, gamma: 3.0517578125e-05
# Support Vector Machine Accuracy Score: 0.787688495819
# Support Vector Machine F-Measure: 0.0
# Support Vector Machine Sensitivity: 0.0
# Support Vector Machine Specificity: 1.0
# Support Vector Machine Precision: 0.0
# Support Vector Machine Area Under ROC Curve: 0.5
# Support Vector Machine Area Under Precision Recall Curve: 0.212311504181
# Support Vector Machine MCC: 0.0
#
# C: 32, gamma: 0.0001220703125
# Support Vector Machine Accuracy Score: 0.961009002091
# Support Vector Machine F-Measure: 0.905264958548
# Support Vector Machine Sensitivity: 0.877119174226
# Support Vector Machine Specificity: 0.983627627218
# Support Vector Machine Precision: 0.935797390613
# Support Vector Machine Area Under ROC Curve: 0.930373400722
# Support Vector Machine Area Under Precision Recall Curve: 0.846941109153
# Support Vector Machine MCC: 0.881670940088
#
# C: 32, gamma: 0.00048828125
# Support Vector Machine Accuracy Score: 0.989252491374
# Support Vector Machine F-Measure: 0.975335518531
# Support Vector Machine Sensitivity: 0.998550724638
# Support Vector Machine Specificity: 0.9867465356
# Support Vector Machine Precision: 0.953299568596
# Support Vector Machine Area Under ROC Curve: 0.992648630119
# Support Vector Machine Area Under Precision Recall Curve: 0.952223008317
# Support Vector Machine MCC: 0.968949588559
#
# C: 32, gamma: 0.001953125
# Support Vector Machine Accuracy Score: 0.988638522524
# Support Vector Machine F-Measure: 0.973946646552
# Support Vector Machine Sensitivity: 0.997826086957
# Support Vector Machine Specificity: 0.986162119523
# Support Vector Machine Precision: 0.95132840205
# Support Vector Machine Area Under ROC Curve: 0.99199410324
# Support Vector Machine Area Under Precision Recall Curve: 0.949710686089
# Support Vector Machine MCC: 0.967200724623
#
# C: 32, gamma: 0.0078125
# Support Vector Machine Accuracy Score: 0.988638522524
# Support Vector Machine F-Measure: 0.973946646552
# Support Vector Machine Sensitivity: 0.997826086957
# Support Vector Machine Specificity: 0.986162119523
# Support Vector Machine Precision: 0.95132840205
# Support Vector Machine Area Under ROC Curve: 0.99199410324
# Support Vector Machine Area Under Precision Recall Curve: 0.949710686089
# Support Vector Machine MCC: 0.967200724623
#
# C: 32, gamma: 0.03125
# Support Vector Machine Accuracy Score: 0.988638522524
# Support Vector Machine F-Measure: 0.973946646552
# Support Vector Machine Sensitivity: 0.997826086957
# Support Vector Machine Specificity: 0.986162119523
# Support Vector Machine Precision: 0.95132840205
# Support Vector Machine Area Under ROC Curve: 0.99199410324
# Support Vector Machine Area Under Precision Recall Curve: 0.949710686089
# Support Vector Machine MCC: 0.967200724623
#
# C: 32, gamma: 0.125
# Support Vector Machine Accuracy Score: 0.989099352017
# Support Vector Machine F-Measure: 0.974989581373
# Support Vector Machine Sensitivity: 0.998550724638
# Support Vector Machine Specificity: 0.986551983071
# Support Vector Machine Precision: 0.952638505023
# Support Vector Machine Area Under ROC Curve: 0.992551353854
# Support Vector Machine Area Under Precision Recall Curve: 0.95155698643
# Support Vector Machine MCC: 0.968518024315
#
# C: 32, gamma: 0.5
# Support Vector Machine Accuracy Score: 0.989406336081
# Support Vector Machine F-Measure: 0.975703948697
# Support Vector Machine Sensitivity: 0.999275362319
# Support Vector Machine Specificity: 0.986746914844
# Support Vector Machine Precision: 0.953343009788
# Support Vector Machine Area Under ROC Curve: 0.993011138582
# Support Vector Machine Area Under Precision Recall Curve: 0.952811961948
# Support Vector Machine MCC: 0.969428029077
#
# C: 32, gamma: 2
# Support Vector Machine Accuracy Score: 0.98925272625
# Support Vector Machine F-Measure: 0.975353160695
# Support Vector Machine Sensitivity: 0.999275362319
# Support Vector Machine Specificity: 0.986551983071
# Support Vector Machine Precision: 0.9526634077
# Support Vector Machine Area Under ROC Curve: 0.992913672695
# Support Vector Machine Area Under Precision Recall Curve: 0.95213235986
# Support Vector Machine MCC: 0.968987913137
#
# C: 32, gamma: 8
# Support Vector Machine Accuracy Score: 0.990020069333
# Support Vector Machine F-Measure: 0.977025358455
# Support Vector Machine Sensitivity: 0.997101449275
# Support Vector Machine Specificity: 0.988111058017
# Support Vector Machine Precision: 0.957855058415
# Support Vector Machine Area Under ROC Curve: 0.992606253646
# Support Vector Machine Area Under Precision Recall Curve: 0.955706498361
# Support Vector Machine MCC: 0.971022496347
#
# C: 32, gamma: 32
# Support Vector Machine Accuracy Score: 0.993398073472
# Support Vector Machine F-Measure: 0.984537609021
# Support Vector Machine Sensitivity: 0.989886351788
# Support Vector Machine Specificity: 0.994348116292
# Support Vector Machine Precision: 0.979412940487
# Support Vector Machine Area Under ROC Curve: 0.99211723404
# Support Vector Machine Area Under Precision Recall Curve: 0.971625186935
# Support Vector Machine MCC: 0.980431560896
#
# C: 128, gamma: 3.0517578125e-05
# Support Vector Machine Accuracy Score: 0.961009002091
# Support Vector Machine F-Measure: 0.905264958548
# Support Vector Machine Sensitivity: 0.877119174226
# Support Vector Machine Specificity: 0.983627627218
# Support Vector Machine Precision: 0.935797390613
# Support Vector Machine Area Under ROC Curve: 0.930373400722
# Support Vector Machine Area Under Precision Recall Curve: 0.846941109153
# Support Vector Machine MCC: 0.881670940088
#
# C: 128, gamma: 0.0001220703125
# Support Vector Machine Accuracy Score: 0.989252491374
# Support Vector Machine F-Measure: 0.975335518531
# Support Vector Machine Sensitivity: 0.998550724638
# Support Vector Machine Specificity: 0.9867465356
# Support Vector Machine Precision: 0.953299568596
# Support Vector Machine Area Under ROC Curve: 0.992648630119
# Support Vector Machine Area Under Precision Recall Curve: 0.952223008317
# Support Vector Machine MCC: 0.968949588559
#
# C: 128, gamma: 0.00048828125
# Support Vector Machine Accuracy Score: 0.988638522524
# Support Vector Machine F-Measure: 0.973946646552
# Support Vector Machine Sensitivity: 0.997826086957
# Support Vector Machine Specificity: 0.986162119523
# Support Vector Machine Precision: 0.95132840205
# Support Vector Machine Area Under ROC Curve: 0.99199410324
# Support Vector Machine Area Under Precision Recall Curve: 0.949710686089
# Support Vector Machine MCC: 0.967200724623
#
# C: 128, gamma: 0.001953125
# Support Vector Machine Accuracy Score: 0.988638522524
# Support Vector Machine F-Measure: 0.973946646552
# Support Vector Machine Sensitivity: 0.997826086957
# Support Vector Machine Specificity: 0.986162119523
# Support Vector Machine Precision: 0.95132840205
# Support Vector Machine Area Under ROC Curve: 0.99199410324
# Support Vector Machine Area Under Precision Recall Curve: 0.949710686089
# Support Vector Machine MCC: 0.967200724623
#
# C: 128, gamma: 0.0078125
# Support Vector Machine Accuracy Score: 0.988638522524
# Support Vector Machine F-Measure: 0.973946646552
# Support Vector Machine Sensitivity: 0.997826086957
# Support Vector Machine Specificity: 0.986162119523
# Support Vector Machine Precision: 0.95132840205
# Support Vector Machine Area Under ROC Curve: 0.99199410324
# Support Vector Machine Area Under Precision Recall Curve: 0.949710686089
# Support Vector Machine MCC: 0.967200724623
#
# C: 128, gamma: 0.03125
# Support Vector Machine Accuracy Score: 0.988945742186
# Support Vector Machine F-Measure: 0.97462608366
# Support Vector Machine Sensitivity: 0.997826086957
# Support Vector Machine Specificity: 0.986551983071
# Support Vector Machine Precision: 0.952613881759
# Support Vector Machine Area Under ROC Curve: 0.992189035014
# Support Vector Machine Area Under Precision Recall Curve: 0.950986850727
# Support Vector Machine MCC: 0.968048059984
#
# C: 128, gamma: 0.125
# Support Vector Machine Accuracy Score: 0.98925272625
# Support Vector Machine F-Measure: 0.975340405431
# Support Vector Machine Sensitivity: 0.998550724638
# Support Vector Machine Specificity: 0.986746914844
# Support Vector Machine Precision: 0.953323031764
# Support Vector Machine Area Under ROC Curve: 0.992648819741
# Support Vector Machine Area Under Precision Recall Curve: 0.952241513171
# Support Vector Machine MCC: 0.968959976155
#
# C: 128, gamma: 0.5
# Support Vector Machine Accuracy Score: 0.98925272625
# Support Vector Machine F-Measure: 0.975353160695
# Support Vector Machine Sensitivity: 0.999275362319
# Support Vector Machine Specificity: 0.986551983071
# Support Vector Machine Precision: 0.9526634077
# Support Vector Machine Area Under ROC Curve: 0.992913672695
# Support Vector Machine Area Under Precision Recall Curve: 0.95213235986
# Support Vector Machine MCC: 0.968987913137
#
# C: 128, gamma: 2
# Support Vector Machine Accuracy Score: 0.988945506588
# Support Vector Machine F-Measure: 0.974626165271
# Support Vector Machine Sensitivity: 0.997826086957
# Support Vector Machine Specificity: 0.986551983071
# Support Vector Machine Precision: 0.952614161172
# Support Vector Machine Area Under ROC Curve: 0.992189035014
# Support Vector Machine Area Under Precision Recall Curve: 0.950992088454
# Support Vector Machine MCC: 0.968047984476
#
# C: 128, gamma: 8
# Support Vector Machine Accuracy Score: 0.989866459502
# Support Vector Machine F-Measure: 0.976659255025
# Support Vector Machine Sensitivity: 0.996376811594
# Support Vector Machine Specificity: 0.988111058017
# Support Vector Machine Precision: 0.957830085885
# Support Vector Machine Area Under ROC Curve: 0.992243934806
# Support Vector Machine Area Under Precision Recall Curve: 0.955136375312
# Support Vector Machine MCC: 0.970552117726
#
# C: 128, gamma: 32
# Support Vector Machine Accuracy Score: 0.991710247949
# Support Vector Machine F-Measure: 0.980552698112
# Support Vector Machine Sensitivity: 0.984110103222
# Support Vector Machine Specificity: 0.993763700215
# Support Vector Machine Precision: 0.977229110982
# Support Vector Machine Area Under ROC Curve: 0.988936901718
# Support Vector Machine Area Under Precision Recall Curve: 0.965057325779
# Support Vector Machine MCC: 0.975379549417
#
# C: 512, gamma: 3.0517578125e-05
# Support Vector Machine Accuracy Score: 0.989252491374
# Support Vector Machine F-Measure: 0.975335518531
# Support Vector Machine Sensitivity: 0.998550724638
# Support Vector Machine Specificity: 0.9867465356
# Support Vector Machine Precision: 0.953299568596
# Support Vector Machine Area Under ROC Curve: 0.992648630119
# Support Vector Machine Area Under Precision Recall Curve: 0.952223008317
# Support Vector Machine MCC: 0.968949588559
#
# C: 512, gamma: 0.0001220703125
# Support Vector Machine Accuracy Score: 0.988638522524
# Support Vector Machine F-Measure: 0.973946646552
# Support Vector Machine Sensitivity: 0.997826086957
# Support Vector Machine Specificity: 0.986162119523
# Support Vector Machine Precision: 0.95132840205
# Support Vector Machine Area Under ROC Curve: 0.99199410324
# Support Vector Machine Area Under Precision Recall Curve: 0.949710686089
# Support Vector Machine MCC: 0.967200724623
#
# C: 512, gamma: 0.00048828125
# Support Vector Machine Accuracy Score: 0.988638522524
# Support Vector Machine F-Measure: 0.973946646552
# Support Vector Machine Sensitivity: 0.997826086957
# Support Vector Machine Specificity: 0.986162119523
# Support Vector Machine Precision: 0.95132840205
# Support Vector Machine Area Under ROC Curve: 0.99199410324
# Support Vector Machine Area Under Precision Recall Curve: 0.949710686089
# Support Vector Machine MCC: 0.967200724623
#
# C: 512, gamma: 0.001953125
# Support Vector Machine Accuracy Score: 0.988638522524
# Support Vector Machine F-Measure: 0.973946646552
# Support Vector Machine Sensitivity: 0.997826086957
# Support Vector Machine Specificity: 0.986162119523
# Support Vector Machine Precision: 0.95132840205
# Support Vector Machine Area Under ROC Curve: 0.99199410324
# Support Vector Machine Area Under Precision Recall Curve: 0.949710686089
# Support Vector Machine MCC: 0.967200724623
#
# C: 512, gamma: 0.0078125
# Support Vector Machine Accuracy Score: 0.988945742186
# Support Vector Machine F-Measure: 0.97462608366
# Support Vector Machine Sensitivity: 0.997826086957
# Support Vector Machine Specificity: 0.986551983071
# Support Vector Machine Precision: 0.952613881759
# Support Vector Machine Area Under ROC Curve: 0.992189035014
# Support Vector Machine Area Under Precision Recall Curve: 0.950986850727
# Support Vector Machine MCC: 0.968048059984
#
# C: 512, gamma: 0.03125
# Support Vector Machine Accuracy Score: 0.988945742186
# Support Vector Machine F-Measure: 0.97462608366
# Support Vector Machine Sensitivity: 0.997826086957
# Support Vector Machine Specificity: 0.986551983071
# Support Vector Machine Precision: 0.952613881759
# Support Vector Machine Area Under ROC Curve: 0.992189035014
# Support Vector Machine Area Under Precision Recall Curve: 0.950986850727
# Support Vector Machine MCC: 0.968048059984
#
# C: 512, gamma: 0.125
# Support Vector Machine Accuracy Score: 0.989406336081
# Support Vector Machine F-Measure: 0.975703948697
# Support Vector Machine Sensitivity: 0.999275362319
# Support Vector Machine Specificity: 0.986746914844
# Support Vector Machine Precision: 0.953343009788
# Support Vector Machine Area Under ROC Curve: 0.993011138582
# Support Vector Machine Area Under Precision Recall Curve: 0.952811961948
# Support Vector Machine MCC: 0.969428029077
#
# C: 512, gamma: 0.5
# Support Vector Machine Accuracy Score: 0.98925272625
# Support Vector Machine F-Measure: 0.975353160695
# Support Vector Machine Sensitivity: 0.999275362319
# Support Vector Machine Specificity: 0.986551983071
# Support Vector Machine Precision: 0.9526634077
# Support Vector Machine Area Under ROC Curve: 0.992913672695
# Support Vector Machine Area Under Precision Recall Curve: 0.95213235986
# Support Vector Machine MCC: 0.968987913137
#
# C: 512, gamma: 2
# Support Vector Machine Accuracy Score: 0.989866459502
# Support Vector Machine F-Measure: 0.976682025874
# Support Vector Machine Sensitivity: 0.997101449275
# Support Vector Machine Specificity: 0.987916126243
# Support Vector Machine Precision: 0.957198928147
# Support Vector Machine Area Under ROC Curve: 0.992508787759
# Support Vector Machine Area Under Precision Recall Curve: 0.95505512266
# Support Vector Machine MCC: 0.97059287267
#
# C: 512, gamma: 8
# Support Vector Machine Accuracy Score: 0.989867402615
# Support Vector Machine F-Measure: 0.97643730569
# Support Vector Machine Sensitivity: 0.986987801063
# Support Vector Machine Specificity: 0.990644791833
# Support Vector Machine Precision: 0.966205026768
# Support Vector Machine Area Under ROC Curve: 0.988816296448
# Support Vector Machine Area Under Precision Recall Curve: 0.956500431668
# Support Vector Machine MCC: 0.970113253915
#
# C: 512, gamma: 32
# Support Vector Machine Accuracy Score: 0.991710012351
# Support Vector Machine F-Measure: 0.980569979694
# Support Vector Machine Sensitivity: 0.983385465541
# Support Vector Machine Specificity: 0.993958631989
# Support Vector Machine Precision: 0.978044594099
# Support Vector Machine Area Under ROC Curve: 0.988672048765
# Support Vector Machine Area Under Precision Recall Curve: 0.965308368157
# Support Vector Machine MCC: 0.975417988161
#
# C: 2048, gamma: 3.0517578125e-05
# Support Vector Machine Accuracy Score: 0.988638522524
# Support Vector Machine F-Measure: 0.973946646552
# Support Vector Machine Sensitivity: 0.997826086957
# Support Vector Machine Specificity: 0.986162119523
# Support Vector Machine Precision: 0.95132840205
# Support Vector Machine Area Under ROC Curve: 0.99199410324
# Support Vector Machine Area Under Precision Recall Curve: 0.949710686089
# Support Vector Machine MCC: 0.967200724623
#
# C: 2048, gamma: 0.0001220703125
# Support Vector Machine Accuracy Score: 0.988638522524
# Support Vector Machine F-Measure: 0.973946646552
# Support Vector Machine Sensitivity: 0.997826086957
# Support Vector Machine Specificity: 0.986162119523
# Support Vector Machine Precision: 0.95132840205
# Support Vector Machine Area Under ROC Curve: 0.99199410324
# Support Vector Machine Area Under Precision Recall Curve: 0.949710686089
# Support Vector Machine MCC: 0.967200724623
#
# C: 2048, gamma: 0.00048828125
# Support Vector Machine Accuracy Score: 0.988638522524
# Support Vector Machine F-Measure: 0.973946646552
# Support Vector Machine Sensitivity: 0.997826086957
# Support Vector Machine Specificity: 0.986162119523
# Support Vector Machine Precision: 0.95132840205
# Support Vector Machine Area Under ROC Curve: 0.99199410324
# Support Vector Machine Area Under Precision Recall Curve: 0.949710686089
# Support Vector Machine MCC: 0.967200724623
#
# C: 2048, gamma: 0.001953125
# Support Vector Machine Accuracy Score: 0.988945742186
# Support Vector Machine F-Measure: 0.97462608366
# Support Vector Machine Sensitivity: 0.997826086957
# Support Vector Machine Specificity: 0.986551983071
# Support Vector Machine Precision: 0.952613881759
# Support Vector Machine Area Under ROC Curve: 0.992189035014
# Support Vector Machine Area Under Precision Recall Curve: 0.950986850727
# Support Vector Machine MCC: 0.968048059984
#
# C: 2048, gamma: 0.0078125
# Support Vector Machine Accuracy Score: 0.988945742186
# Support Vector Machine F-Measure: 0.97462608366
# Support Vector Machine Sensitivity: 0.997826086957
# Support Vector Machine Specificity: 0.986551983071
# Support Vector Machine Precision: 0.952613881759
# Support Vector Machine Area Under ROC Curve: 0.992189035014
# Support Vector Machine Area Under Precision Recall Curve: 0.950986850727
# Support Vector Machine MCC: 0.968048059984
#
# C: 2048, gamma: 0.03125
# Support Vector Machine Accuracy Score: 0.989099352017
# Support Vector Machine F-Measure: 0.974989581373
# Support Vector Machine Sensitivity: 0.998550724638
# Support Vector Machine Specificity: 0.986551983071
# Support Vector Machine Precision: 0.952638505023
# Support Vector Machine Area Under ROC Curve: 0.992551353854
# Support Vector Machine Area Under Precision Recall Curve: 0.95155698643
# Support Vector Machine MCC: 0.968518024315
#
# C: 2048, gamma: 0.125
# Support Vector Machine Accuracy Score: 0.98925272625
# Support Vector Machine F-Measure: 0.975353160695
# Support Vector Machine Sensitivity: 0.999275362319
# Support Vector Machine Specificity: 0.986551983071
# Support Vector Machine Precision: 0.9526634077
# Support Vector Machine Area Under ROC Curve: 0.992913672695
# Support Vector Machine Area Under Precision Recall Curve: 0.95213235986
# Support Vector Machine MCC: 0.968987913137
#
# C: 2048, gamma: 0.5
# Support Vector Machine Accuracy Score: 0.989099116419
# Support Vector Machine F-Measure: 0.974989662983
# Support Vector Machine Sensitivity: 0.998550724638
# Support Vector Machine Specificity: 0.986551983071
# Support Vector Machine Precision: 0.952638784436
# Support Vector Machine Area Under ROC Curve: 0.992551353854
# ...
# Support Vector Machine Precision: 0.956519326059
# Support Vector Machine Area Under ROC Curve: 0.992411321872
# Support Vector Machine Area Under Precision Recall Curve: 0.954375520572
# Support Vector Machine MCC: 0.97015275673
#
# C: 32768, gamma: 2
# Support Vector Machine Accuracy Score: 0.988791897479
# Support Vector Machine F-Measure: 0.974083063692
# Support Vector Machine Sensitivity: 0.990595349807
# Support Vector Machine Specificity: 0.988305989791
# Support Vector Machine Precision: 0.958218666414
# Support Vector Machine Area Under ROC Curve: 0.989450669799
# Support Vector Machine Area Under Precision Recall Curve: 0.95123005519
# Support Vector Machine MCC: 0.96719830296
#
# C: 32768, gamma: 8
# Support Vector Machine Accuracy Score: 0.99186385778
# Support Vector Machine F-Measure: 0.980976940912
# Support Vector Machine Sensitivity: 0.986284016265
# Support Vector Machine Specificity: 0.993373836667
# Support Vector Machine Precision: 0.976040116439
# Support Vector Machine Area Under ROC Curve: 0.989828926466
# Support Vector Machine Area Under Precision Recall Curve: 0.965502945893
# Support Vector Machine MCC: 0.975952679433
#
# C: 32768, gamma: 32
# Support Vector Machine Accuracy Score: 0.991249417734
# Support Vector Machine F-Measure: 0.979495256606
# Support Vector Machine Sensitivity: 0.982650401418
# Support Vector Machine Specificity: 0.993569147685
# Support Vector Machine Precision: 0.976617722697
# Support Vector Machine Area Under ROC Curve: 0.988109774552
# Support Vector Machine Area Under Precision Recall Curve: 0.963342915169
# Support Vector Machine MCC: 0.974045211694
#
# Optimum Accuracy for Support Vector Machine: 0.993398073472
# Optimum Parameters:C:32, gamma:32
#
#
# n_neighbors: 1
# K-Nearest Neighbour Accuracy Score: 0.992785046292
# K-Nearest Neighbour F-Measure: 0.982891404253
# K-Nearest Neighbour Sensitivity: 0.979042852674
# K-Nearest Neighbour Specificity: 0.996492365804
# K-Nearest Neighbour Precision: 0.986959896435
# K-Nearest Neighbour Area Under ROC Curve: 0.987767609239
# K-Nearest Neighbour Area Under Precision Recall Curve: 0.970691556941
# K-Nearest Neighbour MCC: 0.978407849225
#
# n_neighbors: 5
# K-Nearest Neighbour Accuracy Score: 0.991403498761
# K-Nearest Neighbour F-Measure: 0.979784244735
# K-Nearest Neighbour Sensitivity: 0.981221978939
# K-Nearest Neighbour Specificity: 0.994153563762
# K-Nearest Neighbour Precision: 0.978554758849
# K-Nearest Neighbour Area Under ROC Curve: 0.98768777135
# K-Nearest Neighbour Area Under Precision Recall Curve: 0.964118826446
# K-Nearest Neighbour MCC: 0.974408905341
#
# n_neighbors: 10
# K-Nearest Neighbour Accuracy Score: 0.992630728224
# K-Nearest Neighbour F-Measure: 0.982740879615
# K-Nearest Neighbour Sensitivity: 0.987702012303
# K-Nearest Neighbour Specificity: 0.993958631989
# K-Nearest Neighbour Precision: 0.977894413679
# K-Nearest Neighbour Area Under ROC Curve: 0.990830322146
# K-Nearest Neighbour Area Under Precision Recall Curve: 0.968521846465
# K-Nearest Neighbour MCC: 0.978102722891
#
# n_neighbors: 15
# K-Nearest Neighbour Accuracy Score: 0.992015819147
# K-Nearest Neighbour F-Measure: 0.981435122267
# K-Nearest Neighbour Sensitivity: 0.992758836409
# K-Nearest Neighbour Specificity: 0.991814761721
# K-Nearest Neighbour Precision: 0.970465987997
# K-Nearest Neighbour Area Under ROC Curve: 0.992286799065
# K-Nearest Neighbour Area Under Precision Recall Curve: 0.964981308466
# K-Nearest Neighbour MCC: 0.976494163745
#
# n_neighbors: 20
# K-Nearest Neighbour Accuracy Score: 0.991861738842
# K-Nearest Neighbour F-Measure: 0.981074202172
# K-Nearest Neighbour Sensitivity: 0.992753623188
# K-Nearest Neighbour Specificity: 0.991619450702
# K-Nearest Neighbour Precision: 0.969752057453
# K-Nearest Neighbour Area Under ROC Curve: 0.992186536945
# K-Nearest Neighbour Area Under Precision Recall Curve: 0.964288135638
# K-Nearest Neighbour MCC: 0.976036383514
#
# n_neighbors: 25
# K-Nearest Neighbour Accuracy Score: 0.991708599485
# K-Nearest Neighbour F-Measure: 0.980710093139
# K-Nearest Neighbour Sensitivity: 0.992753623188
# K-Nearest Neighbour Specificity: 0.991424898173
# K-Nearest Neighbour Precision: 0.969075990929
# K-Nearest Neighbour Area Under ROC Curve: 0.992089260681
# K-Nearest Neighbour Area Under Precision Recall Curve: 0.963593143804
# K-Nearest Neighbour MCC: 0.975596555799
#
# n_neighbors: 30
# K-Nearest Neighbour Accuracy Score: 0.989406336081
# K-Nearest Neighbour F-Measure: 0.97523603413
# K-Nearest Neighbour Sensitivity: 0.983364612658
# K-Nearest Neighbour Specificity: 0.991035034625
# K-Nearest Neighbour Precision: 0.96736793203
# K-Nearest Neighbour Area Under ROC Curve: 0.987199823641
# K-Nearest Neighbour Area Under Precision Recall Curve: 0.954828556306
# K-Nearest Neighbour MCC: 0.96860397072
#
# n_neighbors: 35
# K-Nearest Neighbour Accuracy Score: 0.98863899372
# K-Nearest Neighbour F-Measure: 0.973576022195
# K-Nearest Neighbour Sensitivity: 0.98553331248
# K-Nearest Neighbour Specificity: 0.989475580434
# K-Nearest Neighbour Precision: 0.962062082824
# K-Nearest Neighbour Area Under ROC Curve: 0.987504446457
# K-Nearest Neighbour Area Under Precision Recall Curve: 0.95123126204
# K-Nearest Neighbour MCC: 0.966521159947
#
# n_neighbors: 40
# K-Nearest Neighbour Accuracy Score: 0.988638758122
# K-Nearest Neighbour F-Measure: 0.973693746638
# K-Nearest Neighbour Sensitivity: 0.988431863205
# K-Nearest Neighbour Specificity: 0.988695853338
# K-Nearest Neighbour Precision: 0.959522730479
# K-Nearest Neighbour Area Under ROC Curve: 0.988563858272
# K-Nearest Neighbour Area Under Precision Recall Curve: 0.950909378534
# K-Nearest Neighbour MCC: 0.966681336642
#
# n_neighbors: 45
# K-Nearest Neighbour Accuracy Score: 0.988178399825
# K-Nearest Neighbour F-Measure: 0.97274943238
# K-Nearest Neighbour Sensitivity: 0.991325200709
# K-Nearest Neighbour Specificity: 0.987331710166
# K-Nearest Neighbour Precision: 0.955005661761
# K-Nearest Neighbour Area Under ROC Curve: 0.989328455438
# K-Nearest Neighbour Area Under Precision Recall Curve: 0.948590648396
# K-Nearest Neighbour MCC: 0.965543167821
#
# n_neighbors: 50
# K-Nearest Neighbour Accuracy Score: 0.987871180162
# K-Nearest Neighbour F-Measure: 0.972043130794
# K-Nearest Neighbour Sensitivity: 0.991325200709
# K-Nearest Neighbour Specificity: 0.986941846618
# K-Nearest Neighbour Precision: 0.953614348645
# K-Nearest Neighbour Area Under ROC Curve: 0.989133523664
# K-Nearest Neighbour Area Under Precision Recall Curve: 0.94722419142
# K-Nearest Neighbour MCC: 0.964649142873
#
# n_neighbors: 55
# K-Nearest Neighbour Accuracy Score: 0.988024318798
# K-Nearest Neighbour F-Measure: 0.972453545782
# K-Nearest Neighbour Sensitivity: 0.993488687311
# K-Nearest Neighbour Specificity: 0.986551983071
# K-Nearest Neighbour Precision: 0.952438222334
# K-Nearest Neighbour Area Under ROC Curve: 0.990020335191
# K-Nearest Neighbour Area Under Precision Recall Curve: 0.947605170941
# K-Nearest Neighbour MCC: 0.96522175534
#
# n_neighbors: 60
# K-Nearest Neighbour Accuracy Score: 0.988484912693
# K-Nearest Neighbour F-Measure: 0.973615066126
# K-Nearest Neighbour Sensitivity: 0.997826086957
# K-Nearest Neighbour Specificity: 0.985967187749
# K-Nearest Neighbour Precision: 0.950729269237
# K-Nearest Neighbour Area Under ROC Curve: 0.991896637353
# K-Nearest Neighbour Area Under Precision Recall Curve: 0.949102238205
# K-Nearest Neighbour MCC: 0.966796149927
#
# n_neighbors: 65
# K-Nearest Neighbour Accuracy Score: 0.98863805205
# K-Nearest Neighbour F-Measure: 0.97398825188
# K-Nearest Neighbour Sensitivity: 0.998550724638
# K-Nearest Neighbour Specificity: 0.985966808504
# K-Nearest Neighbour Precision: 0.950789162495
# K-Nearest Neighbour Area Under ROC Curve: 0.992258766571
# K-Nearest Neighbour Area Under Precision Recall Curve: 0.949712602216
# K-Nearest Neighbour MCC: 0.967281502621
#
# n_neighbors: 70
# K-Nearest Neighbour Accuracy Score: 0.988484442219
# K-Nearest Neighbour F-Measure: 0.973654337827
# K-Nearest Neighbour Sensitivity: 0.998550724638
# K-Nearest Neighbour Specificity: 0.98577187673
# K-Nearest Neighbour Precision: 0.95017171283
# K-Nearest Neighbour Area Under ROC Curve: 0.992161300684
# K-Nearest Neighbour Area Under Precision Recall Curve: 0.949095152551
# K-Nearest Neighbour MCC: 0.966869084895
#
# n_neighbors: 75
# K-Nearest Neighbour Accuracy Score: 0.988330832388
# K-Nearest Neighbour F-Measure: 0.973310934652
# K-Nearest Neighbour Sensitivity: 0.998550724638
# K-Nearest Neighbour Specificity: 0.985576944956
# K-Nearest Neighbour Precision: 0.949519846982
# K-Nearest Neighbour Area Under ROC Curve: 0.992063834797
# K-Nearest Neighbour Area Under Precision Recall Curve: 0.948443286703
# K-Nearest Neighbour MCC: 0.966441246582
#
# n_neighbors: 80
# K-Nearest Neighbour Accuracy Score: 0.988177222557
# K-Nearest Neighbour F-Measure: 0.97296014665
# K-Nearest Neighbour Sensitivity: 0.998550724638
# K-Nearest Neighbour Specificity: 0.985382013183
# K-Nearest Neighbour Precision: 0.948840244894
# K-Nearest Neighbour Area Under ROC Curve: 0.99196636891
# K-Nearest Neighbour Area Under Precision Recall Curve: 0.947763684615
# K-Nearest Neighbour MCC: 0.966001130642
#
# n_neighbors: 85
# K-Nearest Neighbour Accuracy Score: 0.988177222557
# K-Nearest Neighbour F-Measure: 0.97296014665
# K-Nearest Neighbour Sensitivity: 0.998550724638
# K-Nearest Neighbour Specificity: 0.985382013183
# K-Nearest Neighbour Precision: 0.948840244894
# K-Nearest Neighbour Area Under ROC Curve: 0.99196636891
# K-Nearest Neighbour Area Under Precision Recall Curve: 0.947763684615
# K-Nearest Neighbour MCC: 0.966001130642
#
# n_neighbors: 90
# K-Nearest Neighbour Accuracy Score: 0.988023848324
# K-Nearest Neighbour F-Measure: 0.972609322592
# K-Nearest Neighbour Sensitivity: 0.998550724638
# K-Nearest Neighbour Specificity: 0.985187081409
# K-Nearest Neighbour Precision: 0.948155718154
# K-Nearest Neighbour Area Under ROC Curve: 0.991868903023
# K-Nearest Neighbour Area Under Precision Recall Curve: 0.947079157875
# K-Nearest Neighbour MCC: 0.965559178801
#
# n_neighbors: 95
# K-Nearest Neighbour Accuracy Score: 0.987870708967
# K-Nearest Neighbour F-Measure: 0.972263430988
# K-Nearest Neighbour Sensitivity: 0.998550724638
# K-Nearest Neighbour Specificity: 0.984992528879
# K-Nearest Neighbour Precision: 0.947490009341
# K-Nearest Neighbour Area Under ROC Curve: 0.991771626759
# K-Nearest Neighbour Area Under Precision Recall Curve: 0.946413449062
# K-Nearest Neighbour MCC: 0.965125703147
#
# n_neighbors: 100
# K-Nearest Neighbour Accuracy Score: 0.987870708967
# K-Nearest Neighbour F-Measure: 0.972263430988
# K-Nearest Neighbour Sensitivity: 0.998550724638
# K-Nearest Neighbour Specificity: 0.984992528879
# K-Nearest Neighbour Precision: 0.947490009341
# K-Nearest Neighbour Area Under ROC Curve: 0.991771626759
# K-Nearest Neighbour Area Under Precision Recall Curve: 0.946413449062
# K-Nearest Neighbour MCC: 0.965125703147
#
# Optimum Accuracy for K-Nearest Neighbour: 0.992785046292
# Optimum Parameters:n_neighbors=1
#
#
# n_estimators: 5
# Random Forest Accuracy Score: 0.992629318966
# Random Forest F-Measure: 0.985576348177
# Random Forest Sensitivity: 0.986977374622
# Random Forest Specificity: 0.994932532369
# Random Forest Precision: 0.982031096875
# Random Forest Area Under ROC Curve: 0.990268286963
# Random Forest Area Under Precision Recall Curve: 0.966274865675
# Random Forest MCC: 0.975739701555
#
# n_estimators: 10
# Random Forest Accuracy Score: 0.993398544667
# Random Forest F-Measure: 0.984035885653
# Random Forest Sensitivity: 0.981206339276
# Random Forest Specificity: 0.996296675541
# Random Forest Precision: 0.98486971061
# Random Forest Area Under ROC Curve: 0.989276189718
# Random Forest Area Under Precision Recall Curve: 0.969323317214
# Random Forest MCC: 0.978906514546
#
# n_estimators: 25
# Random Forest Accuracy Score: 0.992630260636
# Random Forest F-Measure: 0.985174298866
# Random Forest Sensitivity: 0.986257950162
# Random Forest Specificity: 0.99551732769
# Random Forest Precision: 0.983467316183
# Random Forest Area Under ROC Curve: 0.989056319847
# Random Forest Area Under Precision Recall Curve: 0.96964927213
# Random Forest MCC: 0.979836117277
#
# n_estimators: 50
# Random Forest Accuracy Score: 0.993090854531
# Random Forest F-Measure: 0.985880662045
# Random Forest Sensitivity: 0.98338025232
# Random Forest Specificity: 0.995322395916
# Random Forest Precision: 0.983492515352
# Random Forest Area Under ROC Curve: 0.989805895625
# Random Forest Area Under Precision Recall Curve: 0.97416729466
# Random Forest MCC: 0.979363227104
#
# n_estimators: 75
# Random Forest Accuracy Score: 0.993245169713
# Random Forest F-Measure: 0.984080841153
# Random Forest Sensitivity: 0.986263163382
# Random Forest Specificity: 0.996102123012
# Random Forest Precision: 0.983471456582
# Random Forest Area Under ROC Curve: 0.990890245536
# Random Forest Area Under Precision Recall Curve: 0.971903381133
# Random Forest MCC: 0.979839483072
#
# n_estimators: 100
# Random Forest Accuracy Score: 0.992937479576
# Random Forest F-Measure: 0.98483716952
# Random Forest Sensitivity: 0.98338025232
# Random Forest Specificity: 0.99551732769
# Random Forest Precision: 0.983471382107
# Random Forest Area Under ROC Curve: 0.989448790005
# Random Forest Area Under Precision Recall Curve: 0.971765863724
# Random Forest MCC: 0.981220201029
#
# n_estimators: 150
# Random Forest Accuracy Score: 0.993704351464
# Random Forest F-Measure: 0.984085950349
# Random Forest Sensitivity: 0.987702012303
# Random Forest Specificity: 0.99551732769
# Random Forest Precision: 0.983466243361
# Random Forest Area Under ROC Curve: 0.99151220411
# Random Forest Area Under Precision Recall Curve: 0.971067327717
# Random Forest MCC: 0.979849198107
#
# n_estimators: 200
# Random Forest Accuracy Score: 0.993397838595
# Random Forest F-Measure: 0.985564432129
# Random Forest Sensitivity: 0.984824314461
# Random Forest Specificity: 0.99551732769
# Random Forest Precision: 0.984165258617
# Random Forest Area Under ROC Curve: 0.990530533306
# Random Forest Area Under Precision Recall Curve: 0.971072002852
# Random Forest MCC: 0.978921535689
#
# n_estimators: 250
# Random Forest Accuracy Score: 0.993244228764
# Random Forest F-Measure: 0.983722342318
# Random Forest Sensitivity: 0.984824314461
# Random Forest Specificity: 0.99551732769
# Random Forest Precision: 0.982762831028
# Random Forest Area Under ROC Curve: 0.990530533306
# Random Forest Area Under Precision Recall Curve: 0.972336551581
# Random Forest MCC: 0.979849198107
#
# n_estimators: 300
# Random Forest Accuracy Score: 0.993704822659
# Random Forest F-Measure: 0.984099078015
# Random Forest Sensitivity: 0.985543738922
# Random Forest Specificity: 0.99551732769
# Random Forest Precision: 0.983456111649
# Random Forest Area Under ROC Curve: 0.990170821076
# Random Forest Area Under Precision Recall Curve: 0.972336551581
# Random Forest MCC: 0.980763126371
#
# n_estimators: 350
# Random Forest Accuracy Score: 0.993244464362
# Random Forest F-Measure: 0.983727554728
# Random Forest Sensitivity: 0.985543738922
# Random Forest Specificity: 0.99551732769
# Random Forest Precision: 0.983481883023
# Random Forest Area Under ROC Curve: 0.990168214465
# Random Forest Area Under Precision Recall Curve: 0.971199851002
# Random Forest MCC: 0.979855723724
#
# n_estimators: 400
# Random Forest Accuracy Score: 0.993397838595
# Random Forest F-Measure: 0.98445480924
# Random Forest Sensitivity: 0.984824314461
# Random Forest Specificity: 0.995322395916
# Random Forest Precision: 0.983481883023
# Random Forest Area Under ROC Curve: 0.990265680352
# Random Forest Area Under Precision Recall Curve: 0.971071876251
# Random Forest MCC: 0.980763126371
#
# n_estimators: 450
# Random Forest Accuracy Score: 0.993244228764
# Random Forest F-Measure: 0.984085950349
# Random Forest Sensitivity: 0.984819101241
# Random Forest Specificity: 0.99551732769
# Random Forest Precision: 0.984159896447
# Random Forest Area Under ROC Curve: 0.990530533306
# Random Forest Area Under Precision Recall Curve: 0.971194874202
# Random Forest MCC: 0.979849198107
#
# n_estimators: 500
# Random Forest Accuracy Score: 0.993244228764
# Random Forest F-Measure: 0.984093826137
# Random Forest Sensitivity: 0.985543738922
# Random Forest Specificity: 0.99551732769
# Random Forest Precision: 0.983466243361
# Random Forest Area Under ROC Curve: 0.990168214465
# Random Forest Area Under Precision Recall Curve: 0.971638015575
# Random Forest MCC: 0.979382313354
#
# Optimum Accuracy for Random Forest: 0.993704822659
# Optimum Parameters:n_estimators=300

# %%
classifiers = [
    ("K-Nearest Neighbour",KNeighborsClassifier(n_neighbors=opt_params["n_neighbors"])),
    ("Random Forest",RandomForestClassifier(n_estimators=opt_params["rf_estimators"], random_state=42)),
    ("Support Vector Machine",SVC(kernel="rbf", C=opt_params["svm_c"],gamma=opt_params["svm_gamma"], random_state=42)),
    ("AdaBoostClassifier",AdaBoostClassifier(n_estimators=opt_params["ab_estimators"], random_state=42))
]

def dump_metrics_without_cv(features, label, validation, name, model):
    model.fit(features, label)
    preds = model.predict(validation)
    
    print("Accuracy of {} with optimal hyperparameters on validation set: {}".format(name, accuracy_score(y_validation, preds)))
    print("F-Score of {} with optimal hyperparameters on validation set: {}".format(name, f1_score(y_validation, preds)))
    print("Sensitivity of {} with optimal hyperparameters on validation set: {}".format(name, recall_score(y_validation, preds)))
    print("Specificity of {} with optimal hyperparameters on validation set: {}".format(name, recall_score(y_validation, preds,pos_label=0)))
    print("Precision of {} with optimal hyperparameters on validation set: {}".format(name, precision_score(y_validation, preds)))
    print("ROC-Auc Score of {} with optimal hyperparameters on validation set: {}".format(name, roc_auc_score(y_validation, preds)))
    print("Precision-Recall Score of {} with optimal hyperparameters on validation set: {}".format(name, average_precision_score(y_validation, preds)))
    print("MCC of {} with optimal hyperparameters on validation set: {}\n\n".format(name, matthews_corrcoef(y_validation, preds)))

optimum_x_validation = best_selector.transform(normalized_x_validation_train_two)
    
for name,model in classifiers:
    dump_metrics_without_cv(optimum_x_train_two, y_train_two, optimum_x_validation, name, model)
# Out:
# Accuracy of K-Nearest Neighbour with optimal hyperparameters on validation set: 0.993861264579
# F-Score of K-Nearest Neighbour with optimal hyperparameters on validation set: 0.985673352436
# Sensitivity of K-Nearest Neighbour with optimal hyperparameters on validation set: 0.994219653179
# Specificity of K-Nearest Neighbour with optimal hyperparameters on validation set: 0.993764614186
# Precision of K-Nearest Neighbour with optimal hyperparameters on validation set: 0.977272727273
# ROC-Auc Score of K-Nearest Neighbour with optimal hyperparameters on validation set: 0.993992133682
# Precision-Recall Score of K-Nearest Neighbour with optimal hyperparameters on validation set: 0.972851499055
# MCC of K-Nearest Neighbour with optimal hyperparameters on validation set: 0.981826220594
#
#
# Accuracy of Random Forest with optimal hyperparameters on validation set: 0.993861264579
# F-Score of Random Forest with optimal hyperparameters on validation set: 0.985714285714
# Sensitivity of Random Forest with optimal hyperparameters on validation set: 0.99710982659
# Specificity of Random Forest with optimal hyperparameters on validation set: 0.992985190959
# Precision of Random Forest with optimal hyperparameters on validation set: 0.974576271186
# ROC-Auc Score of Random Forest with optimal hyperparameters on validation set: 0.995047508774
# Precision-Recall Score of Random Forest with optimal hyperparameters on validation set: 0.972373450303
# MCC of Random Forest with optimal hyperparameters on validation set: 0.981909652265
#
#
# Accuracy of Support Vector Machine with optimal hyperparameters on validation set: 0.992633517495
# F-Score of Support Vector Machine with optimal hyperparameters on validation set: 0.982905982906
# Sensitivity of Support Vector Machine with optimal hyperparameters on validation set: 0.99710982659
# Specificity of Support Vector Machine with optimal hyperparameters on validation set: 0.991426344505
# Precision of Support Vector Machine with optimal hyperparameters on validation set: 0.969101123596
# ROC-Auc Score of Support Vector Machine with optimal hyperparameters on validation set: 0.994268085547
# Precision-Recall Score of Support Vector Machine with optimal hyperparameters on validation set: 0.966914126838
# MCC of Support Vector Machine with optimal hyperparameters on validation set: 0.978373636978
#
#
# Accuracy of AdaBoostClassifier with optimal hyperparameters on validation set: 0.992019643953
# F-Score of AdaBoostClassifier with optimal hyperparameters on validation set: 0.981455064194
# Sensitivity of AdaBoostClassifier with optimal hyperparameters on validation set: 0.994219653179
# Specificity of AdaBoostClassifier with optimal hyperparameters on validation set: 0.991426344505
# Precision of AdaBoostClassifier with optimal hyperparameters on validation set: 0.969014084507
# ROC-Auc Score of AdaBoostClassifier with optimal hyperparameters on validation set: 0.992822998842
# Precision-Recall Score of AdaBoostClassifier with optimal hyperparameters on validation set: 0.964640594108
# MCC of AdaBoostClassifier with optimal hyperparameters on validation set: 0.976502703087

# %% [markdown]
# ### 8. Implement a stacking ensemble, which combines the best performing classifiers obtained in step 7 by a meta-learner (which can be logistic regression). Here you will use the optimum hyper-parameters you found in step 7 to train the models you selected in stacking. You can try different combinations of classifiers for this purpose. Perform cross-validation and report the same accuracy measures as in step 5. Then train the model on the train set 2 and test on validation set. Report the accuracy measures on validation data.

# %%
classifiers_for_stacking = [
    KNeighborsClassifier(n_neighbors=opt_params["n_neighbors"]),
    RandomForestClassifier(n_estimators=opt_params["rf_estimators"], random_state=42),
    SVC(kernel="rbf", C=opt_params["svm_c"],gamma=opt_params["svm_gamma"], random_state=42, probability=True),
    AdaBoostClassifier(n_estimators=opt_params["ab_estimators"], random_state=42)
]

lr = LogisticRegression(random_state=42)

print("Scores with optimum data:\n")

sclf = StackingClassifier(classifiers=classifiers_for_stacking, meta_classifier=lr)
dump_metrics_with_cv(optimum_x_train_two, y_train_two, "Stacking Ensemble", sclf)

print("Scores with validation data:\n")
dump_metrics_without_cv(optimum_x_train_two, y_train_two, optimum_x_validation, "Stacking Ensemble", sclf)
# Out:
# Scores with optimum data:
#
# Stacking Ensemble Accuracy Score: 0.99385843249
# Stacking Ensemble F-Measure: 0.985506424635
# Stacking Ensemble Sensitivity: 0.984819101241
# Stacking Ensemble Specificity: 0.996297054786
# Stacking Ensemble Precision: 0.986319613392
# Stacking Ensemble Area Under ROC Curve: 0.990558078013
# Stacking Ensemble Area Under Precision Recall Curve: 0.974545983136
# Stacking Ensemble MCC: 0.981660582814
#
# Scores with validation data:
#
# Accuracy of Stacking Ensemble with optimal hyperparameters on validation set: 0.993861264579
# F-Score of Stacking Ensemble with optimal hyperparameters on validation set: 0.985714285714
# Sensitivity of Stacking Ensemble with optimal hyperparameters on validation set: 0.99710982659
# Specificity of Stacking Ensemble with optimal hyperparameters on validation set: 0.992985190959
# Precision of Stacking Ensemble with optimal hyperparameters on validation set: 0.974576271186
# ROC-Auc Score of Stacking Ensemble with optimal hyperparameters on validation set: 0.995047508774
# Precision-Recall Score of Stacking Ensemble with optimal hyperparameters on validation set: 0.972373450303
# MCC of Stacking Ensemble with optimal hyperparameters on validation set: 0.981909652265

# %% [markdown]
# ### 9. Generate ROC curves for the methods compared and combine these in a single plot. Comment on the accuracy results. Which methods give the best performance? Can you suggest other methods to further improve the accuracy?

# %%
result_table = pd.DataFrame(columns=['classifiers', 'fpr','tpr','auc'])

optimal_classifiers = [
    KNeighborsClassifier(n_neighbors=opt_params["n_neighbors"]),
    RandomForestClassifier(n_estimators=opt_params["rf_estimators"], random_state=42),
    SVC(kernel="rbf", C=opt_params["svm_c"],gamma=opt_params["svm_gamma"], random_state=42, probability=True),
    AdaBoostClassifier(n_estimators=opt_params["ab_estimators"], random_state=42),
    StackingClassifier(classifiers=classifiers_for_stacking, meta_classifier=lr)
]

for cls in optimal_classifiers:
    model = cls.fit(optimum_x_train_two, y_train_two)
    yproba = model.predict_proba(optimum_x_validation)[::,1]
    
    fpr, tpr, _ = roc_curve(y_validation,  yproba)
    auc = roc_auc_score(y_validation, yproba)
    
    result_table = result_table.append({'classifiers':cls.__class__.__name__,
                                        'fpr':fpr, 
                                        'tpr':tpr, 
                                        'auc':auc}, ignore_index=True)

result_table.set_index('classifiers', inplace=True)

fig = plt.figure(figsize=(8,6))

for i in result_table.index:
    plt.plot(result_table.loc[i]['fpr'], 
             result_table.loc[i]['tpr'], 
             label="{}, AUC={:.3f}".format(i, result_table.loc[i]['auc']))
    
plt.plot([0,1], [0,1], color='orange', linestyle='--')

plt.xticks(np.arange(0.0, 1.1, step=0.1))
plt.xlabel("False Positive Rate", fontsize=15)

plt.yticks(np.arange(0.0, 1.1, step=0.1))
plt.ylabel("True Positive Rate", fontsize=15)

plt.title('ROC Curve Analysis', fontweight='bold', fontsize=15)
plt.legend(prop={'size':13}, loc='lower right')

plt.show()

# %% [markdown]
# ### 10. Train the method that gives the most accurate predictions so far (i.e. the highest overall accuracy) on the original train set after applying the best feature selection and normalization strategy and compute predictions on the samples of the test set(s) for which the true labels are available. Report the same accuracy measures as in step 5.

# %%
clf = RandomForestClassifier(n_estimators=opt_params["rf_estimators"], random_state=42)

best_selector.fit(normalized_x_train, y=y_train)
optimum_x_train = best_selector.transform(normalized_x_train)
optimum_x_test = best_selector.transform(normalized_x_test)
optimum_x_test2 = best_selector.transform(normalized_x_test2)

clf.fit(optimum_x_train, y_train)

preds = clf.predict(optimum_x_test)

print("Accuracy of RandomForest with optimal hyperparameters on test set: {}".format(accuracy_score(y_test, preds)))
print("F-Score of RandomForest with optimal hyperparameters on test set: {}".format(f1_score(y_test, preds)))
print("Sensitivity of RandomForest with optimal hyperparameters on test set: {}".format(recall_score(y_test, preds)))
print("Specificity of RandomForest with optimal hyperparameters on test set: {}".format(recall_score(y_test, preds,pos_label=0)))
print("Precision of RandomForest with optimal hyperparameters on test set: {}".format(precision_score(y_test, preds)))
print("ROC-Auc Score of RandomForest with optimal hyperparameters on test set: {}".format(roc_auc_score(y_test, preds)))
print("MCC of RandomForest with optimal hyperparameters on test set: {}\n\n".format(matthews_corrcoef(y_test, preds)))

preds = clf.predict(optimum_x_test2)

print("Accuracy of RandomForest with optimal hyperparameters on test set2: {}".format(accuracy_score(y_test2, preds)))
print("F-Score of RandomForest with optimal hyperparameters on test set2: {}".format(f1_score(y_test2, preds)))
print("Sensitivity of RandomForest with optimal hyperparameters on test set2: {}".format(recall_score(y_test2, preds)))
print("Specificity of RandomForest with optimal hyperparameters on test set2: {}".format(recall_score(y_test2, preds,pos_label=0)))
print("Precision of RandomForest with optimal hyperparameters on test set2: {}".format(precision_score(y_test2, preds)))
print("ROC-Auc Score of RandomForest with optimal hyperparameters on test set2: {}".format(roc_auc_score(y_test2, preds)))
print("MCC of RandomForest with optimal hyperparameters on test set2: {}\n\n".format(matthews_corrcoef(y_test2, preds)))
# Out:
# Accuracy of RandomForest with optimal hyperparameters on test set: 0.978986866792
# F-Score of RandomForest with optimal hyperparameters on test set: 0.971971971972
# Sensitivity of RandomForest with optimal hyperparameters on test set: 0.998971193416
# Specificity of RandomForest with optimal hyperparameters on test set: 0.967513290018
# Precision of RandomForest with optimal hyperparameters on test set: 0.946393762183
# ROC-Auc Score of RandomForest with optimal hyperparameters on test set: 0.983242241717
# MCC of RandomForest with optimal hyperparameters on test set: 0.956078033949
#
#
# Accuracy of RandomForest with optimal hyperparameters on test set2: 0.993334700574
# F-Score of RandomForest with optimal hyperparameters on test set2: 0.984326018809
# Sensitivity of RandomForest with optimal hyperparameters on test set2: 0.996095656418
# Specificity of RandomForest with optimal hyperparameters on test set2: 0.992600285603
# Precision of RandomForest with optimal hyperparameters on test set2: 0.972831267874
# ROC-Auc Score of RandomForest with optimal hyperparameters on test set2: 0.99434797101
# MCC of RandomForest with optimal hyperparameters on test set2: 0.980204538224

# %% [markdown]
# ### 11. Do literature review and find publications on the same topic. Which methods performed the best? Compare them with the methods you developed in this project. Can you improve your methods using the techniques implemented in the literature? Suggest ideas for improvement.

# %% [markdown]
# ## Publications
#
# 1. Accurate occupancy detection of an office room from light, temperature, humidity and CO2 measurements using statistical learning models. Luis M. Candanedo, VÃ©ronique Feldheim. Energy and Buildings. Volume 112, 15 January 2016, Pages 28-39.
#
# 2. Richardson, Ian & Thomson, Murray & Infield, David. (2008). A high-resolution domestic building occupancy model for energy demand simulations. Energy and Buildings. 40. 1560-1566. 10.1016/j.enbuild.2008.02.006.
#
# 3. S. Meyn, A. Surana, Y. Lin, S.M. Oggianu, S. Narayanan, T.A. Frewen, A sensor-utility-network method for estimation of occupancy in buildings, in: Decision and Control, 2009 held jointly with the 2009 28th Chinese Control Conference. CDC/CCC 2009. Proceedings of the 48th IEEE Conference on, IEEE, Shanghai, P.R. China, 2009, pp. 1494–1500.
#
# 4. ] V.L. Erickson, Y. Lin, A. Kamthe, R. Brahme, A. Surana, A.E. Cerpa, M.D. Sohn, S. Narayanan, Energy efficient building environment control strategies using real-time occupancy measurements, in: Proceedings of the first ACM workshop on embedded sensing systems for energy-efficiency in buildings, ACM, Berkeley, California, 2009, pp. 19–24.
#
# 5. ] C. Liao, P. Barooah, An integrated approach to occupancy modeling and estimation in commercial buildings, in: American Control Conference (ACC), IEEE, Baltimore, MD, 2010, pp. 3130–3135.
#
# ## Methods implemented in the literature
#
# Linear Discrimant Analysis performed the best in the publications. Since this is a very well established problem, almost all methods that I have performed was already performed by other researchers. So, the results are very similiar because of that. I can definitely improve my methods using the tecniques implemented in the literature. For instance, I can use bootstrap sampling for evaluating just like in the first article or I could take advantage of principle component analysis. I could also optimize the parameters of linear discriminant analysis which gives a fairly good accuracy.
